# %%
import pandas as pd
import os

# %%
egfr_pathways = "/Users/anb/Desktop/EGFR_Participating_Molecule.tsv"

egfr_pathways_df = pd.read_csv(
    egfr_pathways, comment="#", header=0, sep='\t', low_memory=False
)

# %%
egfr_pathways_df = egfr_pathways_df[['MoleculeType',	'Identifier',	'MoleculeName']].copy()

# %%
egfr_proteins = pd.DataFrame()

# %%
tempdf = egfr_pathways_df['MoleculeName'].str.split(' ', 1, expand=True)

# %%
egfr_proteins['proteins'] = tempdf[1]

# %%
egfr_proteins
# Out:
#    proteins
# 0     PLCG1
# 1      EREG
# 2       EGF
# 3      TGFA
# 4      EPGN
# 5       BTC
# 6      AREG
# 7      EGFR
# 8       CBL
# 9      GRB2
# 10      UBC
# 11      UBB
# 12    UBA52
# 13   RPS27A
# 14    PTPRK
# 15   PTPN12
# 16  SH3KBP1
# 17   SH3GL1
# 18   SH3GL3
# 19   SH3GL2
# 20    CDC42
# 21  ARHGEF7
# 22    SPRY2
# 23    SPRY1
# 24    STAM2
# 25     STAM
# 26      HGS
# 27    EPS15
# 28     EPN1
# 29  EPS15L1
# 30    PTPN3
# 31   ADAM12
# 32   ADAM17
# 33   ADAM10
# 34   PIK3CA
# 35   PIK3R1
# 36     GAB1
# 37   PTPN11
# 38      CSK
# 39      PXN
# 40      SRC
# 41     PAG1
# 42     SOS1
# 43     KRAS
# 44     NRAS
# 45     KRAS
# 46     HRAS
# 47    LRIG1
# 48      SRC
# 49     SHC1
# 50     AAMP

# %%
out_dir = "/Users/anb/Desktop/"

egfr_proteins.to_csv(os.path.join(out_dir, "egfr_proteins.tsv"), sep='\t', index=False, header=True)
