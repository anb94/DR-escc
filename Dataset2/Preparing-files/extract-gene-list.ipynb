# %%
import pandas as pd
import os

# %%
dataset = "/Users/anb/Documents/CMEB-Lab/ESCC-Drug-Repositioning/DR-escc-data/output/GSE23400/filtered_de_results05.tsv"

dataset_df = pd.read_csv(
    dataset, comment="#", header=0, sep='\t', low_memory=False
)

# %%
dataset_df
# Out:
#                ID   Gene.Symbol  ENTREZ_GENE_ID  \
# 0     202311_s_at        COL1A1            1277
# 1     219787_s_at          ECT2            1894
# 2     201897_s_at         CKS1B            1163
# 3       204023_at          RFC4            5984
# 4       203417_at         MFAP2            4237
# ...           ...           ...             ...
# 2557  215176_x_at  IGK /// IGKC  3514 /// 50802
# 2558    209800_at         KRT16            3868
# 2559    210397_at         DEFB1            1672
# 2560     41469_at           PI3            5266
# 2561    209301_at           CA2             760
#
#                                              Gene.Title  \
# 0                             collagen, type I, alpha 1
# 1                        epithelial cell transforming 2
# 2            CDC28 protein kinase regulatory subunit 1B
# 3           replication factor C (activator 1) 4, 37kDa
# 4                   microfibrillar-associated protein 2
# ...
