# %%
import os
import pandas as pd

# %% [markdown]
# Import the GSEA only arm files.

# %%
# Network Meta File

GSEA_net_meta_file = "/Users/anb/Desktop/zGZM9EpmbJ_app2result.txt.1"

GSEA_net_meta = pd.read_csv(
    GSEA_net_meta_file, comment="#", header=0, sep='\t', low_memory=False
)

# Network Top 500 file

GSEA_net_500_file = "/Users/anb/Desktop/SDEeRWPYFC_app2result.txt.2"

GSEA_net_500 = pd.read_csv(
    GSEA_net_500_file, comment="#", header=0, sep='\t', low_memory=False
)

# Overlap file

GSEA_overlap_file = "/Users/anb/Desktop/zXotFQTj3P_app3result.txt"

GSEA_overlap = pd.read_csv(
    GSEA_overlap_file, comment="#", header=0, sep='\t', low_memory=False
)

# %% [markdown]
# Import the wKDA arm files.

# %% [markdown]
# # wkda Network Meta File
#
# wkda_net_meta_file = "/Users/anb/Documents/CMEB-Lab/ESCC-Drug-Repositioning/DR-escc-data/output/GSE23400/1st-dual-arm-analysis/wKDA-arm/network-meta/Cru23plOJu_app2result.txt"
#
# wkda_net_meta = pd.read_csv(
#     wkda_net_meta_file, comment="#", header=0, sep='\t', low_memory=False
# )
#
# # Network Top 500 file
#
# wkda_net_500_file = "/Users/anb/Documents/CMEB-Lab/ESCC-Drug-Repositioning/DR-escc-data/output/GSE23400/1st-dual-arm-analysis/wKDA-arm/network-top500/wDlxSsVxjv-wkda-13-03-22-updated.tsv"
#
# wkda_net_500 = pd.read_csv(
#     wkda_net_500_file, comment="#", header=0, sep='\t', low_memory=False
# )
#
# # Overlap file
#
# wkda_overlap_file = "/Users/anb/Documents/CMEB-Lab/ESCC-Drug-Repositioning/DR-escc-data/output/GSE23400/1st-dual-arm-analysis/wKDA-arm/overlap/gklPh0nN48.KDA2PHARM_app3result.txt"
#
# wkda_overlap = pd.read_csv(
#     wkda_overlap_file, comment="#", header=0, sep='\t', low_memory=False
# )

# %% [markdown]
# Filter the loaded in datasets:
# - GSEA_net_meta
# - GSEA_net_500
# - GSEA_overlap
# - wkda_net_meta
# - wkda_net_500
# - wkda_overlap

# %% [markdown]
# Staring with GSEA_net_meta, make sure the data is loaded in correctly.

# %%
GSEA_net_meta
# Out:
#                                  Drug       Species                 Tissue  \
# 0                        Methotrexate  Homo sapiens  cardiovascular system
# 1                         Doxorubicin  Homo sapiens          immune system
# 2                         Fulvestrant  Homo sapiens                 breast
# 3                          Antibiotic  Homo sapiens             integument
# 4                           Tamoxifen  Homo sapiens               pancreas
# ...                               ...           ...                    ...
# 1242  Glucocorticoid receptor agonist  Homo sapiens   hematopoietic system
# 1243           H2 receptor antagonist  Homo sapiens                  liver
# 1244                     Antipruritic  Homo sapiens   hematopoietic system
# 1245                    Dexamethasone  Homo sapiens   hematopoietic system
# 1246                        Sorafenib  Homo sapiens          immune system
#
#                                                 Dataset  \
# 0                                              GSE32008
# 1                                              GSE79413
# 2     GSE74391, GSE22533, GSE85536, E-GEOD-14986, E-...
# 3            GSE43080, GSE37994, E-GEOD-13487, GSE39091
# 4                                              GSE55999
# ...                                                 ...
# 1242  GSE12841, GSE33135, GSE55876, GSE55877, GSE558...
# 1243  TG-GATEs_famotidine_in_vitro, TG-GATEs_cimetid...
# 1244  GSE12841, GSE33135, GSE55876, GSE55877, GSE558...
# 1245  GSE12841, GSE33135, GSE55876, GSE55877, GSE558...
# 1246  GSE31057, GSE31058, GSE31059, GSE31060, GSE654...
#
#                     DEG_method  \
# 0     Characteristic direction
# 1     Characteristic direction
# 2     Characteristic direction
# 3     Characteristic direction
# 4     Characteristic direction
# ...                        ...
# 1242  Characteristic direction
# 1243  Characteristic direction
# 1244  Characteristic direction
# 1245  Characteristic direction
# 1246  Characteristic direction
#
#                                                Genes_up  \
# 0     C3,DDIT3,AREG,SAT1,IL1RL1,CXCL8,TNFAIP3,ANKRA2...
# 1     PCDH8,FDXR,GAS6-AS1,TRIM22,MUC19,DDB2,WDR63,GP...
# 2     S100P,TSPAN1,ID1,ID2,ID3,SOCS2,TM4SF1,SYBU,C19...
# 3     C3,ABCA12,IFI44L,GPR1,GFI1,TCN1,CFB,MGAM,DUOX2...
# 4     CDKN1C,LOXL4,GDF15,LCN2,SPNS2,PTGDS,APOD,GJB2,...
# ...                                                 ...
# 1242  FKBP5,TSC22D3,PIK3IP1,DDIT4,PFKFB2,SOCS1,RUNX2...
# 1243  PSEN1,MBTD1,PCBD2,EXOC4,NEAT1,DBT,CLRN3,SLC22A...
# 1244  DDIT4,PIK3IP1,TSC22D3,GLUL,SESN1,SOCS1,TNFSF8,...
# 1245  DDIT4,PIK3IP1,TSC22D3,GLUL,SESN1,SOCS1,TNFSF8,...
# 1246  PSAT1,ASNS,RARRES3,GYPC,DDIT3,PPM1M,PQLC3,SMIM...
#
#                                              Genes_down  \
# 0     PLK1,HIST1H2BM,PRC1,BUB1,DEPDC1,KIF20A,TOP2A,C...
# 1     KIF20A,DLGAP5,CDC20,CCNB1,CENPE,NDC80,FAM83D,N...
# 2     FGFBP2,CDCA5,CENPF,CDC20,RBM24,TACC3,SLC18B1,R...
# 3     HYLS1,HMMR,DLGAP5,KIF14,DEPDC1,CDC45,BDKRB1,SP...
# 4     SLC25A18,UPK1B,MT1E,SOX21,CDS1,MXRA5,MT2A,FOXQ...
# ...                                                 ...
# 1242  OPRL1,HES1,BMP10,FAM222A-AS1,MEF2C,CPEB1,SNORD...
# 1243  EXO1,NANOS1,PRC1,BORA,HSPB9,PRTFDC1,DLGAP5,LIN...
# 1244  HES1,EGR2,ID3,MEF2C,OPRL1,BMP10,RGMA,FAM222A-A...
# 1245  HES1,EGR2,ID3,MEF2C,OPRL1,BMP10,RGMA,FAM222A-A...
# 1246  HIST1H1C,ANKRD37,HIST2H2AA3,HIST2H2AC,RRM2,SNO...
#
#                                          Genes_combined  \
# 0     C3,PLK1,DDIT3,HIST1H2BM,AREG,PRC1,SAT1,BUB1,IL...
# 1     PCDH8,KIF20A,FDXR,DLGAP5,GAS6-AS1,CDC20,TRIM22...
# 2     CEACAM6,FGFBP2,S100P,TSPAN1,ID1,PDZK1,STC2,ID2...
# 3     C3,ABCA12,HYLS1,HMMR,DLGAP5,KIF14,DEPDC1,CDC45...
# 4     CDKN1C,SLC25A18,LOXL4,UPK1B,GDF15,MT1E,LCN2,SO...
# ...                                                 ...
# 1242  FKBP5,TSC22D3,PIK3IP1,DDIT4,PFKFB2,SOCS1,RUNX2...
# 1243  PSEN1,EXO1,NANOS1,PRC1,HSPB9,BORA,MBTD1,PCBD2,...
# 1244  FKBP5,DDIT4,PIK3IP1,SMIM3,HES1,TSC22D3,GLUL,SE...
# 1245  FKBP5,DDIT4,PIK3IP1,SMIM3,HES1,TSC22D3,GLUL,SE...
# 1246  PSAT1,HIST1H1C,ASNS,ANKRD37,HIST2H2AA3,RARRES3...
#
#                                    SIDER_link   Z_score      Rank  \
# 0       http://sideeffects.embl.de/drugs/4112 -7.525615  1.000000
# 1       http://sideeffects.embl.de/drugs/1690 -7.265339  0.999198
# 2     http://sideeffects.embl.de/drugs/104741 -7.211470  0.998396
# 3                                        none -6.876405  0.997594
# 4       http://sideeffects.embl.de/drugs/5376 -6.833129  0.996792
# ...                                       ...       ...       ...
# 1242                                     none  3.985398  0.004010
# 1243                                     none  4.416911  0.003208
# 1244                                     none  4.490776  0.002406
# 1245    http://sideeffects.embl.de/drugs/3003  4.519348  0.001604
# 1246  http://sideeffects.embl.de/drugs/216239  5.039388  0.000802
#
#             Pvalue                   All_Drug_Gene_Input_Gene_Overlap  \
# 0     2.623639e-14  CXCL8,CEACAM1,MXD1,MMP10,EHF,PPP1R3C,DUSP5,HSP...
# 1     1.860516e-13  PLAC8,SERPINE1,CDC20,CEP55,TOP2A,PRC1,NUSAP1,D...
# 2     2.767545e-13  S100P,KLK11,IGFBP3,CYP4B1,CD24,KAT2B,PSCA,TMEM...
# 3     3.069100e-12  IGFBP3,IL1RN,MMP10,SERPINB4,HSPB8,S100P,CST1,T...
# 4     4.154103e-12  LCN2,IGFBP3,TMPRSS2,CLIC3,MAL,DUSP5,PRSS3,PTHL...
# ...            ...                                                ...
# 1242  9.999663e-01  ITGA6,CCNG2,UBL3,MAL,PLAC8,MXD1,S100P,FSCN1,IS...
# 1243  9.999950e-01          PRC1,C1orf116,TNC,GINS1,COL1A1,RRM2,THBS2
# 1244  9.999965e-01  ITGA6,CCNG2,VCAN,CFD,MAL,UBL3,ISG15,FSCN1,CXCL...
# 1245  9.999969e-01  ITGA6,CCNG2,VCAN,CFD,MAL,UBL3,ISG15,FSCN1,CXCL...
# 1246  9.999998e-01  LPIN1,S100P,ISG15,UBL3,COL5A2,MMP11,PLAU,NUCB2...
#
#                 Drug_gene_input_gene_overlap_in_network  \
# 0     CEACAM1,MXD1,MMP10,EHF,PPP1R3C,DUSP5,HSPB8,PRC...
# 1     PLAC8,SERPINE1,CDC20,CEP55,TOP2A,PRC1,NUSAP1,D...
# 2     S100P,KLK11,IGFBP3,CYP4B1,CD24,KAT2B,PSCA,TMEM...
# 3     IGFBP3,IL1RN,MMP10,SERPINB4,HSPB8,S100P,TMEM45...
# 4     LCN2,IGFBP3,TMPRSS2,CLIC3,MAL,DUSP5,PRSS3,PTHL...
# ...                                                 ...
# 1242  ITGA6,CCNG2,UBL3,MAL,PLAC8,MXD1,S100P,FSCN1,IS...
# 1243          PRC1,C1orf116,TNC,GINS1,COL1A1,RRM2,THBS2
# 1244    ITGA6,CCNG2,VCAN,CFD,MAL,UBL3,ISG15,FSCN1,IL1RN
# 1245    ITGA6,CCNG2,VCAN,CFD,MAL,UBL3,ISG15,FSCN1,IL1RN
# 1246  LPIN1,S100P,ISG15,UBL3,COL5A2,MMP11,PLAU,NUCB2...
#
#             Drug_genes_directly_connected_to_input_gene  \
# 0     C3,AREG,SAT1,IL1RL1,TNFAIP3,IL7R,ARG2,ATP6V0D2...
# 1     GPR87,CDKN1A,ANK1,SCN4B,TNFRSF21,ASCC3,SULF2,A...
# 2     TSPAN1,ID1,ID2,SOCS2,TM4SF1,NDRG1,ANXA3,AMIGO2...
# 3     C3,CFB,MGAM,KDR,ALPK2,HSPB3,DLX5,KMO,DKK1,RIMS...
# 4     CDKN1C,LOXL4,PTGDS,APOD,S100A9,RASL11B,HEYL,BG...
# ...                                                 ...
# 1242  FKBP5,TSC22D3,PIK3IP1,DDIT4,SOCS1,IL7R,PRDM1,T...
# 1243  EXOC4,CLRN3,SLC22A15,F13B,RHOBTB1,RSAD2,SERPIN...
# 1244  DDIT4,PIK3IP1,TSC22D3,SOCS1,RGS1,IL7R,NFKBIA,T...
# 1245  DDIT4,PIK3IP1,TSC22D3,SOCS1,RGS1,IL7R,NFKBIA,T...
# 1246  PSAT1,ASNS,GYPC,SH3RF2,TNFSF13B,LMO4,TMEM71,AP...
#
#             Input_genes_directly_connected_to_drug_gene  \
# 0     COL1A1,ECT2,CKS1B,RFC4,PLAU,CDK1,COL1A2,CEP55,...
# 1     COL1A1,ECT2,CKS1B,RFC4,PLAU,CDK1,COL1A2,CEP55,...
# 2     COL1A1,ECT2,CKS1B,RFC4,MFAP2,PLAU,COL1A2,CEP55...
# 3     COL1A1,ECT2,CKS1B,MFAP2,PLAU,CDK1,COL1A2,CEP55...
# 4     COL1A1,ECT2,CKS1B,RFC4,MFAP2,PLAU,CDK1,COL1A2,...
# ...                                                 ...
# 1242  COL1A1,ECT2,CKS1B,RFC4,MFAP2,PLAU,CDK1,COL1A2,...
# 1243  COL1A1,ECT2,CKS1B,RFC4,MFAP2,PLAU,COL1A2,CEP55...
# 1244  COL1A1,ECT2,CKS1B,RFC4,MFAP2,PLAU,CDK1,COL1A2,...
# 1245  COL1A1,ECT2,CKS1B,RFC4,MFAP2,PLAU,CDK1,COL1A2,...
# 1246  COL1A1,ECT2,CKS1B,RFC4,MFAP2,MMP1,PLAU,COL1A2,...
#
#                                       Drug_network_name
# 0                    Methotrexate_cardiovascular system
# 1                             Doxorubicin_immune system
# 2                                    Fulvestrant_breast
# 3                                 Antibiotic_integument
# 4                                    Tamoxifen_pancreas
# ...                                                 ...
# 1242  Glucocorticoid receptor agonist_hematopoietic ...
# 1243                       H2 receptor antagonist_liver
# 1244                  Antipruritic_hematopoietic system
# 1245                 Dexamethasone_hematopoietic system
# 1246                            Sorafenib_immune system
#
# [1247 rows x 17 columns]

# %% [markdown]
# As we are only interested in human data, first check for non-human data and remove if needed.

# %%
GSEA_net_meta[GSEA_net_meta["Species"] != "Homo sapiens"]
# Out:
# Empty DataFrame
# Columns: [Drug, Species, Tissue, Dataset, DEG_method, Genes_up, Genes_down, Genes_combined, SIDER_link, Z_score, Rank, Pvalue, All_Drug_Gene_Input_Gene_Overlap, Drug_gene_input_gene_overlap_in_network, Drug_genes_directly_connected_to_input_gene, Input_genes_directly_connected_to_drug_gene, Drug_network_name]
# Index: []

# %% [markdown]
# Sort the df according to drug and rank

# %%
GSEA_net_meta_sorted_drug = GSEA_net_meta.sort_values(['Drug', 'Rank'], axis=0, ascending=False, inplace=False)

# %%
GSEA_net_meta_sorted_drug
# Out:
#                       Drug       Species                   Tissue  \
# 571            pidilizumab  Homo sapiens            immune system
# 391         mTOR inhibitor  Homo sapiens                   breast
# 502         mTOR inhibitor  Homo sapiens                   kidney
# 989         mTOR inhibitor  Homo sapiens     hematopoietic system
# 1142        mTOR inhibitor  Homo sapiens                    ovary
# ...                    ...           ...                      ...
# 473   AMP kinase activator  Homo sapiens    cardiovascular system
# 864   AMP kinase activator  Homo sapiens                    liver
# 962   AMP kinase activator  Homo sapiens                   breast
# 1033  AMP kinase activator  Homo sapiens  gastrointestinal system
# 1215  AMP kinase activator  Homo sapiens               integument
#
#                            Dataset                DEG_method  \
# 571                       GSE52562  Characteristic direction
# 391   GSE39691, GSE39693, GSE73923  Characteristic direction
# 502             GSE66107, GSE31232  Characteristic direction
# 989                       GSE22224  Characteristic direction
# 1142  GSE97751, GSE97751, GSE51683  Characteristic direction
# ...                            ...                       ...
# 473             GSE46263, GSE46262  Characteristic direction
# 864    TG-GATEs_metformin_in_vitro  Characteristic direction
# 962                       GSE36847  Characteristic direction
# 1033                      GSE16816  Characteristic direction
# 1215                      GSE67342  Characteristic direction
#
#                                                Genes_up  \
# 571   TCL1B,PI16,LY6G6E,SCGB3A1,TELO2,PODN,JSRP1,CKM...
# 391   CYP1B1,RAB40B,TPP1,FBXO8,IRS2,CTSF,EPB41L4A-AS...
# 502   CPN2,RNASE2,GLYATL1,SNORA80E,MIR4300HG,SNORA2A...
# 989   UTS2,C19orf33,CXCL10,CLEC12A,SERPINB2,NUAK1,OL...
# 1142  SMURF2,ID2,ID1,BDH2,NOG,KRT6C,TUBA3FP,SMAD9,AD...
# ...                                                 ...
# 473   COX7B,PCDHB8,PCDHB13,MATN2,PCDHB4,MIR221,KLRC4...
# 864   INSIG1,THRSP,DDIT4,CYP1B1,CMTM3,TMEM234,PSG5,M...
# 962   HIST1H3B,GDF15,MAFF,LEMD1,TM4SF1,PLA2G10,MSMO1...
# 1033  AKAP12,DUSP5,EDN1,PIM1,CXCR4,SLC2A3,PHLDA1,ADM...
# 1215  LINC01426,PGM5P2,CSTF3-AS1,GYS2,IL12B,RCVRN,LI...
#
#                                              Genes_down  \
# 571   RPS4Y1,MIR641,BOLA2B,CCDC180,SPOCK1,UCP1,MAPK8...
# 391   RIMS2,ST6GAL1,GPAT3,RPPH1,RBPMS2,RDH11,ACAT2,T...
# 502   TNFAIP6,SCARNA4,SNORD45B,ABCA9,SCEL,TECRL,LINC...
# 989   FRG1JP,HLA-DQB1,THBD,PGGHG,BOD1L1,TET2,XIST,G0...
# 1142  POU1F1,BCORP1,NECAB1,GABRR1,TFPI,CRACR2A,NAALA...
# ...                                                 ...
# 473   RNU4-2,SELENOP,ZNF439,DPPA2,TPTE2,TRIM48,OR13C...
# 864   HAL,ANKRD50,BRD4,ERV3-2,TOP2A,ZNF850,PAPOLG,DI...
# 962   TXNIP,ANKRD37,PCDH19,SLC26A2,FOS,PLAC8,PIGW,FA...
# 1033  ZNF467,H3F3B,GP1BB,CADPS2,C17orf67,ARRDC4,TERC...
# 1215  C10orf126,ZNF749,MYOT,EAF2,C10orf55,ANKRD37,PC...
#
#                                          Genes_combined SIDER_link   Z_score  \
# 571   TCL1B,RPS4Y1,PI16,MIR641,LY6G6E,BOLA2B,SCGB3A1...       none -0.712479
# 391   CYP1B1,RIMS2,RAB40B,TPP1,ST6GAL1,GPAT3,RPPH1,R...       none -1.411871
# 502   CPN2,TNFAIP6,RNASE2,GLYATL1,SNORA80E,SCARNA4,M...       none -1.047026
# 989   UTS2,FRG1JP,C19orf33,HLA-DQB1,CXCL10,THBD,CLEC...       none  0.799793
# 1142  SMURF2,ID2,POU1F1,ID1,BCORP1,NECAB1,BDH2,NOG,G...       none  1.713545
# ...                                                 ...        ...       ...
# 473   RNU4-2,COX7B,PCDHB8,SELENOP,ZNF439,PCDHB13,MAT...       none -1.148188
# 864   INSIG1,HAL,THRSP,ANKRD50,DDIT4,BRD4,CYP1B1,ERV...       none  0.373173
# 962   HIST1H3B,TXNIP,GDF15,ANKRD37,MAFF,PCDH19,LEMD1...       none  0.657408
# 1033  AKAP12,ZNF467,DUSP5,H3F3B,EDN1,GP1BB,PIM1,CADP...       none  1.069813
# 1215  LINC01426,C10orf126,PGM5P2,ZNF749,CSTF3-AS1,MY...       none  2.746810
#
#           Rank    Pvalue                   All_Drug_Gene_Input_Gene_Overlap  \
# 571   0.542101  0.238084              COL5A2,VCAN,GINS1,COL1A1,PSCA,CEACAM5
# 391   0.686447  0.078994  POSTN,SERPINB2,LCN2,IGFBP3,COL7A1,SPARC,MMP1,P...
# 502   0.597434  0.147544  IL18,SCEL,THBS2,COL3A1,VCAN,CDC20,CRNN,CRYAB,F...
# 989   0.206897  0.788085                          SERPINB2,CXCL8,MEST,ITGA6
# 1142  0.084202  0.956694                           ID4,SPRR2B,CDC20,IGF2BP2
# ...        ...       ...                                                ...
# 473   0.620690  0.125446  CXCL8,POSTN,SULF1,CST1,VCAN,PLAC8,EPCAM,TMEM45...
# 864   0.307137  0.645490                   SERPINB2,DUSP5,CCNG2,TOP2A,CXCL8
# 962   0.228549  0.744541               CCNG2,TMPRSS2,CD24,MGLL,PLAC8,CXCL12
# 1033  0.171612  0.857648                      DUSP5,SNAI2,CXCL8,TP63,COL1A2
# 1215  0.025662  0.996991                                SPRR2C,IGFBP3,MMP10
#
#                 Drug_gene_input_gene_overlap_in_network  \
# 571                       COL5A2,VCAN,GINS1,COL1A1,PSCA
# 391   POSTN,SERPINB2,LCN2,IGFBP3,COL7A1,SPARC,MMP1,P...
# 502   IL18,SCEL,THBS2,COL3A1,VCAN,CDC20,CRYAB,FLG,PL...
# 989                                 SERPINB2,MEST,ITGA6
# 1142                                  ID4,CDC20,IGF2BP2
# ...                                                 ...
# 473            POSTN,SULF1,VCAN,PLAC8,EPCAM,TMEM45A,TNC
# 864                          SERPINB2,DUSP5,CCNG2,TOP2A
# 962                CCNG2,TMPRSS2,CD24,MGLL,PLAC8,CXCL12
# 1033                            DUSP5,SNAI2,TP63,COL1A2
# 1215                                       IGFBP3,MMP10
#
#             Drug_genes_directly_connected_to_input_gene  \
# 571   PI16,PODN,SFRP2,CXCL13,FABP4,PRRX2,MFAP5,CXCL1...
# 391   CYP1B1,TPP1,IRS2,ABCC3,EGR1,GAS6,SCG5,CFB,PLLP...
# 502   RNASE2,PDGFRB,LDHD,KDR,CXCL10,KRTAP9-9,SNORD82...
# 989   CXCL10,FCGBP,PDZK1IP1,CLEC1B,TSPAN13,MZB1,EGR1...
# 1142  ID2,ID1,BDH2,ADCY3,PDHA1,CORO1A,ATP1B1,NR4A2,S...
# ...                                                 ...
# 473   MATN2,ANKS4B,FILIP1,SELE,KITLG,VGLL3,SCIN,NRK,...
# 864   INSIG1,THRSP,DDIT4,CYP1B1,CMTM3,MVD,RGCC,DKK3,...
# 962   MAFF,TM4SF1,HMOX1,INSIG1,FZD7,DDIT4,CDKN1A,KRT...
# 1033  AKAP12,EDN1,CXCR4,SLC2A3,PHLDA1,ADM,ANKRD37,MA...
# 1215  GYS2,CAPN13,ZNF750,F13B,KRTAP9-9,C5AR1,SCG5,TA...
#
#             Input_genes_directly_connected_to_drug_gene  \
# 571   COL1A1,ECT2,MFAP2,PLAU,COL1A2,SNAI2,FOXM1,PPP1...
# 391   COL1A1,ECT2,CKS1B,MFAP2,MMP1,PLAU,COL1A2,CEP55...
# 502   COL1A1,ECT2,MFAP2,PLAU,COL1A2,SNAI2,SIM2,LAPTM...
# 989   COL1A1,ECT2,CKS1B,COL1A2,CEP55,SNAI2,LAPTM4B,P...
# 1142  COL1A1,ECT2,MFAP2,PLAU,COL1A2,CEP55,LAPTM4B,PP...
# ...                                                 ...
# 473   COL1A1,PLAU,COL1A2,CEP55,FOXM1,LAPTM4B,PPP1R3C...
# 864   COL1A1,ECT2,CKS1B,PLAU,CEP55,SNAI2,LAPTM4B,HPG...
# 962   COL1A1,ECT2,PLAU,CDK1,COL1A2,CEP55,SNAI2,FOXM1...
# 1033  COL1A1,ECT2,CKS1B,MFAP2,PLAU,COL1A2,SNAI2,FOXM...
# 1215  COL1A1,MFAP2,COL1A2,LAPTM4B,PPP1R3C,HPGD,NUCB2...
#
#                                  Drug_network_name
# 571                      pidilizumab_immune system
# 391                          mTOR inhibitor_breast
# 502                          mTOR inhibitor_kidney
# 989            mTOR inhibitor_hematopoietic system
# 1142                          mTOR inhibitor_ovary
# ...                                            ...
# 473     AMP kinase activator_cardiovascular system
# 864                     AMP kinase activator_liver
# 962                    AMP kinase activator_breast
# 1033  AMP kinase activator_gastrointestinal system
# 1215               AMP kinase activator_integument
#
# [1247 rows x 17 columns]

# %% [markdown]
# Remove the duplicates of drugs, keeping only the first occurrence as it as the highest p-value

# %%
GSEA_net_meta_sorted_drug.drop_duplicates(subset = ["Drug"], inplace=True)

# %%
GSEA_net_meta_sorted_drug
# Out:
#                                      Drug       Species  \
# 571                           pidilizumab  Homo sapiens
# 391                        mTOR inhibitor  Homo sapiens
# 323     beta2-Adrenergic receptor agonist  Homo sapiens
# 662  beta1-Adrenergic receptor antagonist  Homo sapiens
# 731   beta-Adrenergic receptor antagonist  Homo sapiens
# ..                                    ...           ...
# 63                          Abortifacient  Homo sapiens
# 355                           Abiraterone  Homo sapiens
# 590                             Abatacept  Homo sapiens
# 697                              Abacavir  Homo sapiens
# 160                  AMP kinase activator  Homo sapiens
#
#                     Tissue                        Dataset  \
# 571          immune system                       GSE52562
# 391                 breast   GSE39691, GSE39693, GSE73923
# 323     respiratory system                       GSE84880
# 662  cardiovascular system                    E-GEOD-3356
# 731                  liver  TG-GATEs_propranolol_in_vitro
# ..                     ...                            ...
# 63     embryonic structure                       GSE84990
# 355      urogenital system                       GSE49244
# 590             integument                       GSE66321
# 697      urogenital system                     E-TABM-532
# 160     respiratory system                       GSE33612
#
#                    DEG_method  \
# 571  Characteristic direction
# 391  Characteristic direction
# 323  Characteristic direction
# 662  Characteristic direction
# 731  Characteristic direction
# ..                        ...
# 63   Characteristic direction
# 355  Characteristic direction
# 590  Characteristic direction
# 697  Characteristic direction
# 160  Characteristic direction
#
#                                               Genes_up  \
# 571  TCL1B,PI16,LY6G6E,SCGB3A1,TELO2,PODN,JSRP1,CKM...
# 391  CYP1B1,RAB40B,TPP1,FBXO8,IRS2,CTSF,EPB41L4A-AS...
# 323  CRYBB3,CXCL13,TBX22,NR4A2,LACTB2-AS1,CCL20,IGH...
# 662  EFNA1,KLHL41,TNF,CHRNG,ZFP36,TRPV5,PRDM1,CHML,...
# 731  MMP1,ZNF564,THRSP,NUDT1,GTF2A2,ADGRG2,FZD8,SPT...
# ..                                                 ...
# 63   MIR4521,FOSB,IL6,RGS2,PTGS2,TRIB1,SAT1,MIR503,...
# 355  S100A8,LYZ,SNORA14A,SNORA80E,S100A12,GYPA,MPO,...
# 590  PRAMEF4,ECEL1,TECRL,DNER,ARHGEF33,RPS4Y1,RFPL4...
# 697  GZMA,CHAD,A2M,WNT2,COL23A1,ACSBG2,EVPL,ST8SIA3...
# 160  LCP1,RRAGD,HIST1H1E,SPX,ATP6V0D2,CXCR4,SV2A,FA...
#
#                                             Genes_down  \
# 571  RPS4Y1,MIR641,BOLA2B,CCDC180,SPOCK1,UCP1,MAPK8...
# 391  RIMS2,ST6GAL1,GPAT3,RPPH1,RBPMS2,RDH11,ACAT2,T...
# 323  HOXD12,SUN3,KCNA7,AKR1C3,HYALP1,SPACA7,C4orf22...
# 662  SLC12A1,ZFP2,JCHAIN,ZNF10,IFNA1,TEKT2,RFPL1,VN...
# 731  GTF2H2B,ASF1B,RPL27A,KIF4A,FOXM1,CA3,PLK4,KIF2...
# ..                                                 ...
# 63   MAOA,CORIN,MIR1264,ZBTB16,FKBP5,TRAJ61,CRISPLD...
# 355  PCP4,PTGS1,PAX8,SPRR2F,FBXO32,CCL21,MET,ADGRG2...
# 590  OLAH,HLA-DRB6,CDH18,ERAP2,ACSM3,SLC6A17,SPINK8...
# 697  MMP16,CHRNB3,LAIR2,GRID1,ZFP42,KLRC2,KMO,PAX6,...
# 160  SERPINB4,LCE2C,EHF,CXCL10,CCL20,IL6,C3,CXCL1,S...
#
#                                         Genes_combined  \
# 571  TCL1B,RPS4Y1,PI16,MIR641,LY6G6E,BOLA2B,SCGB3A1...
# 391  CYP1B1,RIMS2,RAB40B,TPP1,ST6GAL1,GPAT3,RPPH1,R...
# 323  CRYBB3,HOXD12,CXCL13,SUN3,TBX22,KCNA7,NR4A2,AK...
# 662  EFNA1,SLC12A1,KLHL41,ZFP2,TNF,JCHAIN,CHRNG,ZNF...
# 731  MMP1,GTF2H2B,ZNF564,ASF1B,THRSP,RPL27A,NUDT1,K...
# ..                                                 ...
# 63   MIR4521,MAOA,FOSB,CORIN,IL6,MIR1264,RGS2,ZBTB1...
# 355  S100A8,PCP4,LYZ,PTGS1,SNORA14A,PAX8,SNORA80E,S...
# 590  PRAMEF4,OLAH,ECEL1,HLA-DRB6,TECRL,CDH18,DNER,E...
# 697  GZMA,MMP16,CHAD,CHRNB3,A2M,LAIR2,WNT2,GRID1,CO...
# 160  LCP1,SERPINB4,RRAGD,LCE2C,HIST1H1E,EHF,SPX,CXC...
#
#                                 SIDER_link   Z_score      Rank    Pvalue  \
# 571                                   none -0.712479  0.542101  0.238084
# 391                                   none -1.411871  0.686447  0.078994
# 323                                   none -1.766422  0.740978  0.038663
# 662                                   none -0.399952  0.469126  0.344596
# 731                                   none -0.132081  0.413793  0.447460
# ..                                     ...       ...       ...       ...
# 63                                    none -4.102831  0.949479  0.000020
# 355                                   none -1.575548  0.715317  0.057565
# 590                                   none -0.658346  0.526864  0.255158
# 697  http://sideeffects.embl.de/drugs/1971 -0.262145  0.441059  0.396605
# 160                                   none -2.801294  0.871692  0.002545
#
#                       All_Drug_Gene_Input_Gene_Overlap  \
# 571              COL5A2,VCAN,GINS1,COL1A1,PSCA,CEACAM5
# 391  POSTN,SERPINB2,LCN2,IGFBP3,COL7A1,SPARC,MMP1,P...
# 323                     SERPINB4,TNC,SNAI2,S100P,CLIC3
# 662                                             CYP4B1
# 731                         MMP1,MALL,EMP1,FOXM1,MMP12
# ..                                                 ...
# 63   MEST,TNC,ITGA6,TGFBI,ADH1B,SULF1,IGFBP3,TMEM45...
# 355           MMP1,CD24,FLG,ZNF185,SPRR2B,TNC,PLAU,EHF
# 590             CEACAM6,DIO2,SPP1,MMP12,TMPRSS11E,LCN2
# 697                                          SPP1,MXD1
# 160  SPP1,SERPINB4,EHF,CST1,SERPINB3,CXCL8,MMP12,CO...
#
#                Drug_gene_input_gene_overlap_in_network  \
# 571                      COL5A2,VCAN,GINS1,COL1A1,PSCA
# 391  POSTN,SERPINB2,LCN2,IGFBP3,COL7A1,SPARC,MMP1,P...
# 323                     SERPINB4,TNC,SNAI2,S100P,CLIC3
# 662                                             CYP4B1
# 731                         MMP1,MALL,EMP1,FOXM1,MMP12
# ..                                                 ...
# 63   MEST,TNC,ITGA6,TGFBI,ADH1B,SULF1,IGFBP3,TMEM45...
# 355                  MMP1,CD24,FLG,ZNF185,TNC,PLAU,EHF
# 590                     DIO2,SPP1,MMP12,TMPRSS11E,LCN2
# 697                                          SPP1,MXD1
# 160  SPP1,SERPINB4,EHF,SERPINB3,MMP12,COL1A1,TGFBI,...
#
#            Drug_genes_directly_connected_to_input_gene  \
# 571  PI16,PODN,SFRP2,CXCL13,FABP4,PRRX2,MFAP5,CXCL1...
# 391  CYP1B1,TPP1,IRS2,ABCC3,EGR1,GAS6,SCG5,CFB,PLLP...
# 323  CXCL13,NR4A2,NR4A3,SCG3,FIBIN,LILRB5,TNMD,MEOX...
# 662  CHRNG,PRDM1,HAAO,PCK1,IFIH1,GRM8,FRMPD1,MAB21L...
# 731  THRSP,SPTSSB,RTP4,CMPK2,CHN1,SBF2,GNMT,SLC23A1...
# ..                                                 ...
# 63   IL6,RGS2,PTGS2,TRIB1,SAT1,JUNB,PLTP,PDK4,CXCL2...
# 355  S100A8,SULT2A1,KLK6,ESM1,FNDC1,PLXDC1,ADAM12,R...
# 590  ECEL1,GUCY1B2,TMC7,CD38,FRK,PRR11,OIT3,FSCN2,A...
# 697  GZMA,CHAD,A2M,WNT2,ACSBG2,EVPL,TMEM134,MMRN1,P...
# 160  RRAGD,ATP6V0D2,CXCR4,ITGAX,BNC1,EGR2,PAPPA2,LE...
#
#            Input_genes_directly_connected_to_drug_gene  \
# 571  COL1A1,ECT2,MFAP2,PLAU,COL1A2,SNAI2,FOXM1,PPP1...
# 391  COL1A1,ECT2,CKS1B,MFAP2,MMP1,PLAU,COL1A2,CEP55...
# 323  COL1A1,ECT2,RFC4,PLAU,COL1A2,CEP55,SNAI2,SIM2,...
# 662  CKS1B,COL1A2,SNAI2,FOXM1,SIM2,LAPTM4B,HPGD,SPP...
# 731  COL1A1,ECT2,CKS1B,MMP1,PLAU,CDK1,COL1A2,CEP55,...
# ..                                                 ...
# 63   COL1A1,ECT2,PLAU,COL1A2,CEP55,KAT2B,SNAI2,SIM2...
# 355  COL1A1,ECT2,CKS1B,MFAP2,MMP1,PLAU,COL1A2,CEP55...
# 590  COL1A1,PLAU,CDK1,COL1A2,CEP55,LAPTM4B,PPP1R3C,...
# 697  COL1A1,ECT2,PLAU,COL1A2,SNAI2,FOXM1,LAPTM4B,PP...
# 160  COL1A1,ECT2,MFAP2,PLAU,COL1A2,CEP55,KAT2B,SNAI...
#
#                                      Drug_network_name
# 571                          pidilizumab_immune system
# 391                              mTOR inhibitor_breast
# 323  beta2-Adrenergic receptor agonist_respiratory ...
# 662  beta1-Adrenergic receptor antagonist_cardiovas...
# 731          beta-Adrenergic receptor antagonist_liver
# ..                                                 ...
# 63                   Abortifacient_embryonic structure
# 355                      Abiraterone_urogenital system
# 590                               Abatacept_integument
# 697                         Abacavir_urogenital system
# 160            AMP kinase activator_respiratory system
#
# [540 rows x 17 columns]

# %% [markdown]
# Sort the df according to Rank.

# %%
GSEA_net_meta_sorted_rank = GSEA_net_meta_sorted_drug.sort_values(['Rank'], axis=0, ascending=False, inplace=False)

# %%
GSEA_net_meta_sorted_rank
# Out:
#                         Drug       Species                 Tissue  \
# 0               Methotrexate  Homo sapiens  cardiovascular system
# 1                Doxorubicin  Homo sapiens          immune system
# 2                Fulvestrant  Homo sapiens                 breast
# 3                 Antibiotic  Homo sapiens             integument
# 4                  Tamoxifen  Homo sapiens               pancreas
# ...                      ...           ...                    ...
# 1234                 Lindane  Homo sapiens          immune system
# 1235            Pediculicide  Homo sapiens          immune system
# 1238               Scabicide  Homo sapiens          immune system
# 1239             Antianxiety  Homo sapiens                  liver
# 1243  H2 receptor antagonist  Homo sapiens                  liver
#
#                                                 Dataset  \
# 0                                              GSE32008
# 1                                              GSE79413
# 2     GSE74391, GSE22533, GSE85536, E-GEOD-14986, E-...
# 3            GSE43080, GSE37994, E-GEOD-13487, GSE39091
# 4                                              GSE55999
# ...                                                 ...
# 1234                                           GSE46909
# 1235                                           GSE46909
# 1238                                           GSE46909
# 1239  TG-GATEs_phenobarbital_in_vitro, TG-GATEs_diaz...
# 1243  TG-GATEs_famotidine_in_vitro, TG-GATEs_cimetid...
#
#                     DEG_method  \
# 0     Characteristic direction
# 1     Characteristic direction
# 2     Characteristic direction
# 3     Characteristic direction
# 4     Characteristic direction
# ...                        ...
# 1234  Characteristic direction
# 1235  Characteristic direction
# 1238  Characteristic direction
# 1239  Characteristic direction
# 1243  Characteristic direction
#
#                                                Genes_up  \
# 0     C3,DDIT3,AREG,SAT1,IL1RL1,CXCL8,TNFAIP3,ANKRA2...
# 1     PCDH8,FDXR,GAS6-AS1,TRIM22,MUC19,DDB2,WDR63,GP...
# 2     S100P,TSPAN1,ID1,ID2,ID3,SOCS2,TM4SF1,SYBU,C19...
# 3     C3,ABCA12,IFI44L,GPR1,GFI1,TCN1,CFB,MGAM,DUOX2...
# 4     CDKN1C,LOXL4,GDF15,LCN2,SPNS2,PTGDS,APOD,GJB2,...
# ...                                                 ...
# 1234  EGR2,EGR1,KLHL24,SGK1,SLC7A11,DUSP6,GPR18,ETV5...
# 1235  EGR2,EGR1,KLHL24,SGK1,SLC7A11,DUSP6,GPR18,ETV5...
# 1238  EGR2,EGR1,KLHL24,SGK1,SLC7A11,DUSP6,GPR18,ETV5...
# 1239  KBTBD8,TSKU,CSPP1,CYP3A5,JAK2,CYP3A7,NUF2,CORT...
# 1243  PSEN1,MBTD1,PCBD2,EXOC4,NEAT1,DBT,CLRN3,SLC22A...
#
#                                              Genes_down  \
# 0     PLK1,HIST1H2BM,PRC1,BUB1,DEPDC1,KIF20A,TOP2A,C...
# 1     KIF20A,DLGAP5,CDC20,CCNB1,CENPE,NDC80,FAM83D,N...
# 2     FGFBP2,CDCA5,CENPF,CDC20,RBM24,TACC3,SLC18B1,R...
# 3     HYLS1,HMMR,DLGAP5,KIF14,DEPDC1,CDC45,BDKRB1,SP...
# 4     SLC25A18,UPK1B,MT1E,SOX21,CDS1,MXRA5,MT2A,FOXQ...
# ...                                                 ...
# 1234  RAG1,RAG2,BTBD11,FAM213B,SERPINB2,PMEPA1,ELOVL...
# 1235  RAG1,RAG2,BTBD11,FAM213B,SERPINB2,PMEPA1,ELOVL...
# 1238  RAG1,RAG2,BTBD11,FAM213B,SERPINB2,PMEPA1,ELOVL...
# 1239  CBLB,CAPN8,KRT80,MIS18BP1,PIGO,NAT14,VSTM2L,CC...
# 1243  EXO1,NANOS1,PRC1,BORA,HSPB9,PRTFDC1,DLGAP5,LIN...
#
#                                          Genes_combined  \
# 0     C3,PLK1,DDIT3,HIST1H2BM,AREG,PRC1,SAT1,BUB1,IL...
# 1     PCDH8,KIF20A,FDXR,DLGAP5,GAS6-AS1,CDC20,TRIM22...
# 2     CEACAM6,FGFBP2,S100P,TSPAN1,ID1,PDZK1,STC2,ID2...
# 3     C3,ABCA12,HYLS1,HMMR,DLGAP5,KIF14,DEPDC1,CDC45...
# 4     CDKN1C,SLC25A18,LOXL4,UPK1B,GDF15,MT1E,LCN2,SO...
# ...                                                 ...
# 1234  EGR2,RAG1,EGR1,RAG2,KLHL24,BTBD11,SGK1,FAM213B...
# 1235  EGR2,RAG1,EGR1,RAG2,KLHL24,BTBD11,SGK1,FAM213B...
# 1238  EGR2,RAG1,EGR1,RAG2,KLHL24,BTBD11,SGK1,FAM213B...
# 1239  CBLB,KBTBD8,CAPN8,KRT80,MIS18BP1,TSKU,CSPP1,PI...
# 1243  PSEN1,EXO1,NANOS1,PRC1,HSPB9,BORA,MBTD1,PCBD2,...
#
#                                    SIDER_link   Z_score      Rank  \
# 0       http://sideeffects.embl.de/drugs/4112 -7.525615  1.000000
# 1       http://sideeffects.embl.de/drugs/1690 -7.265339  0.999198
# 2     http://sideeffects.embl.de/drugs/104741 -7.211470  0.998396
# 3                                        none -6.876405  0.997594
# 4       http://sideeffects.embl.de/drugs/5376 -6.833129  0.996792
# ...                                       ...       ...       ...
# 1234     http://sideeffects.embl.de/drugs/727  3.289629  0.010425
# 1235                                     none  3.314773  0.009623
# 1238                                     none  3.448747  0.007217
# 1239                                     none  3.527563  0.006415
# 1243                                     none  4.416911  0.003208
#
#             Pvalue                   All_Drug_Gene_Input_Gene_Overlap  \
# 0     2.623639e-14  CXCL8,CEACAM1,MXD1,MMP10,EHF,PPP1R3C,DUSP5,HSP...
# 1     1.860516e-13  PLAC8,SERPINE1,CDC20,CEP55,TOP2A,PRC1,NUSAP1,D...
# 2     2.767545e-13  S100P,KLK11,IGFBP3,CYP4B1,CD24,KAT2B,PSCA,TMEM...
# 3     3.069100e-12  IGFBP3,IL1RN,MMP10,SERPINB4,HSPB8,S100P,CST1,T...
# 4     4.154103e-12  LCN2,IGFBP3,TMPRSS2,CLIC3,MAL,DUSP5,PRSS3,PTHL...
# ...            ...                                                ...
# 1234  9.994984e-01                           CCNG2,ITGA6,SERPINB2,MAL
# 1235  9.995414e-01                           CCNG2,ITGA6,SERPINB2,MAL
# 1238  9.997184e-01                           CCNG2,ITGA6,SERPINB2,MAL
# 1239  9.997903e-01  CYP3A5,MMP1,CD24,CEP55,CRABP2,C1orf116,TOP2A,P...
# 1243  9.999950e-01          PRC1,C1orf116,TNC,GINS1,COL1A1,RRM2,THBS2
#
#                 Drug_gene_input_gene_overlap_in_network  \
# 0     CEACAM1,MXD1,MMP10,EHF,PPP1R3C,DUSP5,HSPB8,PRC...
# 1     PLAC8,SERPINE1,CDC20,CEP55,TOP2A,PRC1,NUSAP1,D...
# 2     S100P,KLK11,IGFBP3,CYP4B1,CD24,KAT2B,PSCA,TMEM...
# 3     IGFBP3,IL1RN,MMP10,SERPINB4,HSPB8,S100P,TMEM45...
# 4     LCN2,IGFBP3,TMPRSS2,CLIC3,MAL,DUSP5,PRSS3,PTHL...
# ...                                                 ...
# 1234                           CCNG2,ITGA6,SERPINB2,MAL
# 1235                           CCNG2,ITGA6,SERPINB2,MAL
# 1238                           CCNG2,ITGA6,SERPINB2,MAL
# 1239  CYP3A5,MMP1,CD24,CEP55,CRABP2,C1orf116,TOP2A,P...
# 1243          PRC1,C1orf116,TNC,GINS1,COL1A1,RRM2,THBS2
#
#             Drug_genes_directly_connected_to_input_gene  \
# 0     C3,AREG,SAT1,IL1RL1,TNFAIP3,IL7R,ARG2,ATP6V0D2...
# 1     GPR87,CDKN1A,ANK1,SCN4B,TNFRSF21,ASCC3,SULF2,A...
# 2     TSPAN1,ID1,ID2,SOCS2,TM4SF1,NDRG1,ANXA3,AMIGO2...
# 3     C3,CFB,MGAM,KDR,ALPK2,HSPB3,DLX5,KMO,DKK1,RIMS...
# 4     CDKN1C,LOXL4,PTGDS,APOD,S100A9,RASL11B,HEYL,BG...
# ...                                                 ...
# 1234  EGR2,EGR1,GPR18,VLDLR,ABCG1,EVI2A,LY9,SLC2A3,B...
# 1235  EGR2,EGR1,GPR18,VLDLR,ABCG1,EVI2A,LY9,SLC2A3,B...
# 1238  EGR2,EGR1,GPR18,VLDLR,ABCG1,EVI2A,LY9,SLC2A3,B...
# 1239  KBTBD8,CYP3A7,NUF2,SORBS1,ABCC2,AKAP12,ADRB2,G...
# 1243  EXOC4,CLRN3,SLC22A15,F13B,RHOBTB1,RSAD2,SERPIN...
#
#             Input_genes_directly_connected_to_drug_gene  \
# 0     COL1A1,ECT2,CKS1B,RFC4,PLAU,CDK1,COL1A2,CEP55,...
# 1     COL1A1,ECT2,CKS1B,RFC4,PLAU,CDK1,COL1A2,CEP55,...
# 2     COL1A1,ECT2,CKS1B,RFC4,MFAP2,PLAU,COL1A2,CEP55...
# 3     COL1A1,ECT2,CKS1B,MFAP2,PLAU,CDK1,COL1A2,CEP55...
# 4     COL1A1,ECT2,CKS1B,RFC4,MFAP2,PLAU,CDK1,COL1A2,...
# ...                                                 ...
# 1234  COL1A1,ECT2,CKS1B,MFAP2,PLAU,COL1A2,CEP55,FOXM...
# 1235  COL1A1,ECT2,CKS1B,MFAP2,PLAU,COL1A2,CEP55,FOXM...
# 1238  COL1A1,ECT2,CKS1B,MFAP2,PLAU,COL1A2,CEP55,FOXM...
# 1239  COL1A1,ECT2,CKS1B,MFAP2,MMP1,PLAU,CDK1,COL1A2,...
# 1243  COL1A1,ECT2,CKS1B,RFC4,MFAP2,PLAU,COL1A2,CEP55...
#
#                        Drug_network_name
# 0     Methotrexate_cardiovascular system
# 1              Doxorubicin_immune system
# 2                     Fulvestrant_breast
# 3                  Antibiotic_integument
# 4                     Tamoxifen_pancreas
# ...                                  ...
# 1234               Lindane_immune system
# 1235          Pediculicide_immune system
# 1238             Scabicide_immune system
# 1239                   Antianxiety_liver
# 1243        H2 receptor antagonist_liver
#
# [540 rows x 17 columns]

# %%
GSEA_net_meta_sorted_rank.reset_index(inplace=True,drop=True)

# %%
GSEA_net_meta_sorted_rank
# Out:
#                        Drug       Species                 Tissue  \
# 0              Methotrexate  Homo sapiens  cardiovascular system
# 1               Doxorubicin  Homo sapiens          immune system
# 2               Fulvestrant  Homo sapiens                 breast
# 3                Antibiotic  Homo sapiens             integument
# 4                 Tamoxifen  Homo sapiens               pancreas
# ..                      ...           ...                    ...
# 535                 Lindane  Homo sapiens          immune system
# 536            Pediculicide  Homo sapiens          immune system
# 537               Scabicide  Homo sapiens          immune system
# 538             Antianxiety  Homo sapiens                  liver
# 539  H2 receptor antagonist  Homo sapiens                  liver
#
#                                                Dataset  \
# 0                                             GSE32008
# 1                                             GSE79413
# 2    GSE74391, GSE22533, GSE85536, E-GEOD-14986, E-...
# 3           GSE43080, GSE37994, E-GEOD-13487, GSE39091
# 4                                             GSE55999
# ..                                                 ...
# 535                                           GSE46909
# 536                                           GSE46909
# 537                                           GSE46909
# 538  TG-GATEs_phenobarbital_in_vitro, TG-GATEs_diaz...
# 539  TG-GATEs_famotidine_in_vitro, TG-GATEs_cimetid...
#
#                    DEG_method  \
# 0    Characteristic direction
# 1    Characteristic direction
# 2    Characteristic direction
# 3    Characteristic direction
# 4    Characteristic direction
# ..                        ...
# 535  Characteristic direction
# 536  Characteristic direction
# 537  Characteristic direction
# 538  Characteristic direction
# 539  Characteristic direction
#
#                                               Genes_up  \
# 0    C3,DDIT3,AREG,SAT1,IL1RL1,CXCL8,TNFAIP3,ANKRA2...
# 1    PCDH8,FDXR,GAS6-AS1,TRIM22,MUC19,DDB2,WDR63,GP...
# 2    S100P,TSPAN1,ID1,ID2,ID3,SOCS2,TM4SF1,SYBU,C19...
# 3    C3,ABCA12,IFI44L,GPR1,GFI1,TCN1,CFB,MGAM,DUOX2...
# 4    CDKN1C,LOXL4,GDF15,LCN2,SPNS2,PTGDS,APOD,GJB2,...
# ..                                                 ...
# 535  EGR2,EGR1,KLHL24,SGK1,SLC7A11,DUSP6,GPR18,ETV5...
# 536  EGR2,EGR1,KLHL24,SGK1,SLC7A11,DUSP6,GPR18,ETV5...
# 537  EGR2,EGR1,KLHL24,SGK1,SLC7A11,DUSP6,GPR18,ETV5...
# 538  KBTBD8,TSKU,CSPP1,CYP3A5,JAK2,CYP3A7,NUF2,CORT...
# 539  PSEN1,MBTD1,PCBD2,EXOC4,NEAT1,DBT,CLRN3,SLC22A...
#
#                                             Genes_down  \
# 0    PLK1,HIST1H2BM,PRC1,BUB1,DEPDC1,KIF20A,TOP2A,C...
# 1    KIF20A,DLGAP5,CDC20,CCNB1,CENPE,NDC80,FAM83D,N...
# 2    FGFBP2,CDCA5,CENPF,CDC20,RBM24,TACC3,SLC18B1,R...
# 3    HYLS1,HMMR,DLGAP5,KIF14,DEPDC1,CDC45,BDKRB1,SP...
# 4    SLC25A18,UPK1B,MT1E,SOX21,CDS1,MXRA5,MT2A,FOXQ...
# ..                                                 ...
# 535  RAG1,RAG2,BTBD11,FAM213B,SERPINB2,PMEPA1,ELOVL...
# 536  RAG1,RAG2,BTBD11,FAM213B,SERPINB2,PMEPA1,ELOVL...
# 537  RAG1,RAG2,BTBD11,FAM213B,SERPINB2,PMEPA1,ELOVL...
# 538  CBLB,CAPN8,KRT80,MIS18BP1,PIGO,NAT14,VSTM2L,CC...
# 539  EXO1,NANOS1,PRC1,BORA,HSPB9,PRTFDC1,DLGAP5,LIN...
#
#                                         Genes_combined  \
# 0    C3,PLK1,DDIT3,HIST1H2BM,AREG,PRC1,SAT1,BUB1,IL...
# 1    PCDH8,KIF20A,FDXR,DLGAP5,GAS6-AS1,CDC20,TRIM22...
# 2    CEACAM6,FGFBP2,S100P,TSPAN1,ID1,PDZK1,STC2,ID2...
# 3    C3,ABCA12,HYLS1,HMMR,DLGAP5,KIF14,DEPDC1,CDC45...
# 4    CDKN1C,SLC25A18,LOXL4,UPK1B,GDF15,MT1E,LCN2,SO...
# ..                                                 ...
# 535  EGR2,RAG1,EGR1,RAG2,KLHL24,BTBD11,SGK1,FAM213B...
# 536  EGR2,RAG1,EGR1,RAG2,KLHL24,BTBD11,SGK1,FAM213B...
# 537  EGR2,RAG1,EGR1,RAG2,KLHL24,BTBD11,SGK1,FAM213B...
# 538  CBLB,KBTBD8,CAPN8,KRT80,MIS18BP1,TSKU,CSPP1,PI...
# 539  PSEN1,EXO1,NANOS1,PRC1,HSPB9,BORA,MBTD1,PCBD2,...
#
#                                   SIDER_link   Z_score      Rank  \
# 0      http://sideeffects.embl.de/drugs/4112 -7.525615  1.000000
# 1      http://sideeffects.embl.de/drugs/1690 -7.265339  0.999198
# 2    http://sideeffects.embl.de/drugs/104741 -7.211470  0.998396
# 3                                       none -6.876405  0.997594
# 4      http://sideeffects.embl.de/drugs/5376 -6.833129  0.996792
# ..                                       ...       ...       ...
# 535     http://sideeffects.embl.de/drugs/727  3.289629  0.010425
# 536                                     none  3.314773  0.009623
# 537                                     none  3.448747  0.007217
# 538                                     none  3.527563  0.006415
# 539                                     none  4.416911  0.003208
#
#            Pvalue                   All_Drug_Gene_Input_Gene_Overlap  \
# 0    2.623639e-14  CXCL8,CEACAM1,MXD1,MMP10,EHF,PPP1R3C,DUSP5,HSP...
# 1    1.860516e-13  PLAC8,SERPINE1,CDC20,CEP55,TOP2A,PRC1,NUSAP1,D...
# 2    2.767545e-13  S100P,KLK11,IGFBP3,CYP4B1,CD24,KAT2B,PSCA,TMEM...
# 3    3.069100e-12  IGFBP3,IL1RN,MMP10,SERPINB4,HSPB8,S100P,CST1,T...
# 4    4.154103e-12  LCN2,IGFBP3,TMPRSS2,CLIC3,MAL,DUSP5,PRSS3,PTHL...
# ..            ...                                                ...
# 535  9.994984e-01                           CCNG2,ITGA6,SERPINB2,MAL
# 536  9.995414e-01                           CCNG2,ITGA6,SERPINB2,MAL
# 537  9.997184e-01                           CCNG2,ITGA6,SERPINB2,MAL
# 538  9.997903e-01  CYP3A5,MMP1,CD24,CEP55,CRABP2,C1orf116,TOP2A,P...
# 539  9.999950e-01          PRC1,C1orf116,TNC,GINS1,COL1A1,RRM2,THBS2
#
#                Drug_gene_input_gene_overlap_in_network  \
# 0    CEACAM1,MXD1,MMP10,EHF,PPP1R3C,DUSP5,HSPB8,PRC...
# 1    PLAC8,SERPINE1,CDC20,CEP55,TOP2A,PRC1,NUSAP1,D...
# 2    S100P,KLK11,IGFBP3,CYP4B1,CD24,KAT2B,PSCA,TMEM...
# 3    IGFBP3,IL1RN,MMP10,SERPINB4,HSPB8,S100P,TMEM45...
# 4    LCN2,IGFBP3,TMPRSS2,CLIC3,MAL,DUSP5,PRSS3,PTHL...
# ..                                                 ...
# 535                           CCNG2,ITGA6,SERPINB2,MAL
# 536                           CCNG2,ITGA6,SERPINB2,MAL
# 537                           CCNG2,ITGA6,SERPINB2,MAL
# 538  CYP3A5,MMP1,CD24,CEP55,CRABP2,C1orf116,TOP2A,P...
# 539          PRC1,C1orf116,TNC,GINS1,COL1A1,RRM2,THBS2
#
#            Drug_genes_directly_connected_to_input_gene  \
# 0    C3,AREG,SAT1,IL1RL1,TNFAIP3,IL7R,ARG2,ATP6V0D2...
# 1    GPR87,CDKN1A,ANK1,SCN4B,TNFRSF21,ASCC3,SULF2,A...
# 2    TSPAN1,ID1,ID2,SOCS2,TM4SF1,NDRG1,ANXA3,AMIGO2...
# 3    C3,CFB,MGAM,KDR,ALPK2,HSPB3,DLX5,KMO,DKK1,RIMS...
# 4    CDKN1C,LOXL4,PTGDS,APOD,S100A9,RASL11B,HEYL,BG...
# ..                                                 ...
# 535  EGR2,EGR1,GPR18,VLDLR,ABCG1,EVI2A,LY9,SLC2A3,B...
# 536  EGR2,EGR1,GPR18,VLDLR,ABCG1,EVI2A,LY9,SLC2A3,B...
# 537  EGR2,EGR1,GPR18,VLDLR,ABCG1,EVI2A,LY9,SLC2A3,B...
# 538  KBTBD8,CYP3A7,NUF2,SORBS1,ABCC2,AKAP12,ADRB2,G...
# 539  EXOC4,CLRN3,SLC22A15,F13B,RHOBTB1,RSAD2,SERPIN...
#
#            Input_genes_directly_connected_to_drug_gene  \
# 0    COL1A1,ECT2,CKS1B,RFC4,PLAU,CDK1,COL1A2,CEP55,...
# 1    COL1A1,ECT2,CKS1B,RFC4,PLAU,CDK1,COL1A2,CEP55,...
# 2    COL1A1,ECT2,CKS1B,RFC4,MFAP2,PLAU,COL1A2,CEP55...
# 3    COL1A1,ECT2,CKS1B,MFAP2,PLAU,CDK1,COL1A2,CEP55...
# 4    COL1A1,ECT2,CKS1B,RFC4,MFAP2,PLAU,CDK1,COL1A2,...
# ..                                                 ...
# 535  COL1A1,ECT2,CKS1B,MFAP2,PLAU,COL1A2,CEP55,FOXM...
# 536  COL1A1,ECT2,CKS1B,MFAP2,PLAU,COL1A2,CEP55,FOXM...
# 537  COL1A1,ECT2,CKS1B,MFAP2,PLAU,COL1A2,CEP55,FOXM...
# 538  COL1A1,ECT2,CKS1B,MFAP2,MMP1,PLAU,CDK1,COL1A2,...
# 539  COL1A1,ECT2,CKS1B,RFC4,MFAP2,PLAU,COL1A2,CEP55...
#
#                       Drug_network_name
# 0    Methotrexate_cardiovascular system
# 1             Doxorubicin_immune system
# 2                    Fulvestrant_breast
# 3                 Antibiotic_integument
# 4                    Tamoxifen_pancreas
# ..                                  ...
# 535               Lindane_immune system
# 536          Pediculicide_immune system
# 537             Scabicide_immune system
# 538                   Antianxiety_liver
# 539        H2 receptor antagonist_liver
#
# [540 rows x 17 columns]

# %%
GSEA_net_meta_filt_results = GSEA_net_meta_sorted_rank.copy()

# %% [markdown]
# Next, with GSEA_net_500, make sure the data is loaded in correctly.

# %%
GSEA_net_500
# Out:
#                         Drug            Species                 Tissue  \
# 0               Procainamide  Rattus norvegicus  cardiovascular system
# 1               Procainamide  Rattus norvegicus  cardiovascular system
# 2             Hydrocortisone  Rattus norvegicus  cardiovascular system
# 3            Chloramphenicol  Rattus norvegicus                  liver
# 4                 Imipramine  Rattus norvegicus                 kidney
# ...                      ...                ...                    ...
# 2977            Indomethacin       Homo sapiens                  liver
# 2978            Flurbiprofen  Rattus norvegicus                 kidney
# 2979           Cyclosporin a  Rattus norvegicus                 kidney
# 2980            Chlorpyrifos  Rattus norvegicus  cardiovascular system
# 2981  Phenylanthranilic acid  Rattus norvegicus                  liver
#
#                Study            Time            Dose  Control sample size  \
# 0            In Vivo  limma combined  limma combined                   15
# 1            In Vivo            24hr       755 mg/kg                   15
# 2            In Vivo              5d        56 mg/kg                    3
# 3           In Vitro             2hr           18 uM                    2
# 4     In Vivo Repeat             15d       100 mg/kg                    3
# ...              ...             ...             ...                  ...
# 2977        In Vitro             8hr           40 uM                    2
# 2978         In Vivo            24hr        10 mg/kg                   20
# 2979         In Vivo             6hr        70 mg/kg                    9
# 2980         In Vivo              3d        82 mg/kg                   12
# 2981  In Vivo Repeat             29d      1000 mg/kg                    3
#
#       Treatment sample size             Database Method  ...  ADRrank_mod26  \
# 0                         3      drugMatrix_Affy  limma  ...       0.471594
# 1                         3      drugMatrix_Affy  limma  ...       0.471594
# 2                         3      drugMatrix_Affy  limma  ...       0.873454
# 3                         2              TGGATEs  limma  ...            NaN
# 4                         3              TGGATEs  limma  ...       0.138092
# ...                     ...                  ...    ...  ...            ...
# 2977                      2              TGGATEs  limma  ...            NaN
# 2978                      3      drugMatrix_Affy  limma  ...            NaN
# 2979                      3  drugMatrix_Codelink  limma  ...       0.774947
# 2980                      3  drugMatrix_Codelink  limma  ...       0.134977
# 2981                      2              TGGATEs  limma  ...       0.137909
#
#      ADRscore_mod27 ADRrank_mod27 ADRscore_mod28 ADRrank_mod28  \
# 0          2.242937      0.122102       1.405839      0.700220
# 1          2.242937      0.122102       1.405839      0.700220
# 2          1.780141      0.193164       2.623350      0.586457
# 3               NaN           NaN            NaN           NaN
# 4          1.016562      0.369376       1.003514      0.746358
# ...             ...           ...            ...           ...
# 2977            NaN           NaN            NaN           NaN
# 2978            NaN           NaN            NaN           NaN
# 2979       1.435767      0.265372      -0.880884      0.955741
# 2980       2.839576      0.065427       1.016927      0.743425
# 2981       2.979473      0.057546       4.292665      0.472281
#
#       ADRscore_mod29  ADRrank_mod29 hepatotox_complete_signature  \
# 0          -2.139164       0.993082                     2.185463
# 1          -2.139164       0.993082                     2.185463
# 2          -1.483946       0.975717                     1.739041
# 3                NaN            NaN                          NaN
# 4          -0.048471       0.844497                     0.138532
# ...              ...            ...                          ...
# 2977             NaN            NaN                          NaN
# 2978             NaN            NaN                          NaN
# 2979        1.356351       0.605516                     0.680203
# 2980        1.239520       0.623110                     2.137345
# 2981        2.023662            NaN                          NaN
#
#      hepatotox_complete_signature_rank                             SIDER_link
# 0                               0.0619  http://sideeffects.embl.de/drugs/4913
# 1                               0.0619  http://sideeffects.embl.de/drugs/4913
# 2                               0.0942  http://sideeffects.embl.de/drugs/3640
# 3                                 none   http://sideeffects.embl.de/drugs/298
# 4                               0.3654  http://sideeffects.embl.de/drugs/3696
# ...                                ...                                    ...
# 2977                              none  http://sideeffects.embl.de/drugs/3715
# 2978                              none  http://sideeffects.embl.de/drugs/3394
# 2979                            0.2340                                   none
# 2980                            0.0650                                   none
# 2981                               NaN                                    NaN
#
# [2982 rows x 83 columns]

# %% [markdown]
# Remove non-significant results

# %%
GSEA_net_500[GSEA_net_500["Species"] == 'Homo sapiens']
# Out:
#                                    Drug       Species Tissue     Study  \
# 7     Transforming growth factor beta 1  Homo sapiens  liver  In Vitro
# 11                      Diethyl maleate  Homo sapiens  liver  In Vitro
# 14                        Phenobarbital  Homo sapiens  liver  In Vitro
# 19                             Pemoline  Homo sapiens  liver  In Vitro
# 51    Transforming growth factor beta 1  Homo sapiens  liver  In Vitro
# ...                                 ...           ...    ...       ...
# 2952                        Tunicamycin  Homo sapiens  liver  In Vitro
# 2959                      Rosiglitazone  Homo sapiens  liver  In Vitro
# 2964                Nitrosodiethylamine  Homo sapiens  liver  In Vitro
# 2972                N-nitrosomorpholine  Homo sapiens  liver  In Vitro
# 2977                       Indomethacin  Homo sapiens  liver  In Vitro
#
#                 Time            Dose  Control sample size  \
# 7                2hr         2 ng/mL                    2
# 11               8hr           60 uM                    2
# 14               8hr         2000 uM                    2
# 19               8hr           15 uM                    2
# 51               2hr        10 ng/mL                    2
# ...              ...             ...                  ...
# 2952  limma combined  limma combined                    4
# 2959            24hr        12 ug/kg                    2
# 2964            24hr        10000 uM                    2
# 2972             8hr          400 uM                    2
# 2977             8hr           40 uM                    2
#
#       Treatment sample size Database Method  ...  ADRrank_mod26  \
# 7                         2  TGGATEs  limma  ...            NaN
# 11                        2  TGGATEs  limma  ...            NaN
# 14                        2  TGGATEs  limma  ...            NaN
# 19                        2  TGGATEs  limma  ...            NaN
# 51                        2  TGGATEs  limma  ...            NaN
# ...                     ...      ...    ...  ...            ...
# 2952                     12  TGGATEs  limma  ...            NaN
# 2959                      2  TGGATEs  limma  ...            NaN
# 2964                      2  TGGATEs  limma  ...            NaN
# 2972                      2  TGGATEs  limma  ...            NaN
# 2977                      2  TGGATEs  limma  ...            NaN
#
#      ADRscore_mod27 ADRrank_mod27 ADRscore_mod28 ADRrank_mod28  \
# 7               NaN           NaN            NaN           NaN
# 11              NaN           NaN            NaN           NaN
# 14              NaN           NaN            NaN           NaN
# 19              NaN           NaN            NaN           NaN
# 51              NaN           NaN            NaN           NaN
# ...             ...           ...            ...           ...
# 2952            NaN           NaN            NaN           NaN
# 2959            NaN           NaN            NaN           NaN
# 2964            NaN           NaN            NaN           NaN
# 2972            NaN           NaN            NaN           NaN
# 2977            NaN           NaN            NaN           NaN
#
#       ADRscore_mod29  ADRrank_mod29 hepatotox_complete_signature  \
# 7                NaN            NaN                          NaN
# 11               NaN            NaN                          NaN
# 14               NaN            NaN                          NaN
# 19               NaN            NaN                          NaN
# 51               NaN            NaN                          NaN
# ...              ...            ...                          ...
# 2952             NaN            NaN                          NaN
# 2959             NaN            NaN                          NaN
# 2964             NaN            NaN                          NaN
# 2972             NaN            NaN                          NaN
# 2977             NaN            NaN                          NaN
#
#      hepatotox_complete_signature_rank                              SIDER_link
# 7                                 none                                    none
# 11                                none                                    none
# 14                                none   http://sideeffects.embl.de/drugs/4763
# 19                                none                                    none
# 51                                none                                    none
# ...                                ...                                     ...
# 2952                              none                                    none
# 2959                              none  http://sideeffects.embl.de/drugs/77998
# 2964                              none                                    none
# 2972                              none                                    none
# 2977                              none   http://sideeffects.embl.de/drugs/3715
#
# [384 rows x 83 columns]

# %%
GSEA_net_500_sig = GSEA_net_500[GSEA_net_500["Species"] == 'Homo sapiens']
GSEA_net_500_sig = GSEA_net_500_sig[GSEA_net_500_sig["Pvalue"] <= 0.05]

# %% [markdown]
# Remove entries with z score equal to zero as they are problematic

# %%
GSEA_net_500_sig_z0 = GSEA_net_500_sig[GSEA_net_500_sig["Z_score"] != 0]
GSEA_net_500_sig_z0 = GSEA_net_500_sig[GSEA_net_500_sig["Z_score"] < -2]

# %%
GSEA_net_500_sig_z0
# Out:
#                                   Drug       Species Tissue     Study  Time  \
# 7    Transforming growth factor beta 1  Homo sapiens  liver  In Vitro   2hr
# 11                     Diethyl maleate  Homo sapiens  liver  In Vitro   8hr
# 14                       Phenobarbital  Homo sapiens  liver  In Vitro   8hr
# 19                            Pemoline  Homo sapiens  liver  In Vitro   8hr
# 51   Transforming growth factor beta 1  Homo sapiens  liver  In Vitro   2hr
# 56                           Tiopronin  Homo sapiens  liver  In Vitro  24hr
# 68                   2,4-dinitrophenol  Homo sapiens  liver  In Vitro   8hr
# 74                    Propylthiouracil  Homo sapiens  liver  In Vitro   2hr
# 85                    Cyclophosphamide  Homo sapiens  liver  In Vitro  24hr
# 91                         Perhexiline  Homo sapiens  liver  In Vitro  24hr
# 92                        Benziodarone  Homo sapiens  liver  In Vitro  24hr
# 95                          Ethambutol  Homo sapiens  liver  In Vitro   8hr
# 99                           Tiopronin  Homo sapiens  liver  In Vitro  24hr
# 100                        Perhexiline  Homo sapiens  liver  In Vitro  24hr
# 101                         Diclofenac  Homo sapiens  liver  In Vitro   8hr
# 103                            Bucetin  Homo sapiens  liver  In Vitro   8hr
# 106                      Galactosamine  Homo sapiens  liver  In Vitro   8hr
# 116                     Nitrofurantoin  Homo sapiens  liver  In Vitro   8hr
# 122                        Haloperidol  Homo sapiens  liver  In Vitro   2hr
#
#          Dose  Control sample size  Treatment sample size Database Method  \
# 7     2 ng/mL                    2                      2  TGGATEs  limma
# 11      60 uM                    2                      2  TGGATEs  limma
# 14    2000 uM                    2                      2  TGGATEs  limma
# 19      15 uM                    2                      2  TGGATEs  limma
# 51   10 ng/mL                    2                      2  TGGATEs  limma
# 56    2000 uM                    2                      2  TGGATEs  limma
# 68       4 uM                    2                      2  TGGATEs  limma
# 74     800 uM                    2                      2  TGGATEs  limma
# 85     400 uM                    2                      2  TGGATEs  limma
# 91     0.6 uM                    2                      2  TGGATEs  limma
# 92       8 uM                    2                      2  TGGATEs  limma
# 95     800 uM                    2                      2  TGGATEs  limma
# 99     400 uM                    2                      2  TGGATEs  limma
# 100      3 uM                    2                      2  TGGATEs  limma
# 101     16 uM                    2                      2  TGGATEs  limma
# 103     60 uM                    2                      2  TGGATEs  limma
# 106   2000 uM                    2                      2  TGGATEs  limma
# 116      5 uM                    2                      2  TGGATEs  limma
# 122    0.8 uM                    2                      2  TGGATEs  limma
#
#      ...  ADRrank_mod26 ADRscore_mod27 ADRrank_mod27 ADRscore_mod28  \
# 7    ...            NaN            NaN           NaN            NaN
# 11   ...            NaN            NaN           NaN            NaN
# 14   ...            NaN            NaN           NaN            NaN
# 19   ...            NaN            NaN           NaN            NaN
# 51   ...            NaN            NaN           NaN            NaN
# 56   ...            NaN            NaN           NaN            NaN
# 68   ...            NaN            NaN           NaN            NaN
# 74   ...            NaN            NaN           NaN            NaN
# 85   ...            NaN            NaN           NaN            NaN
# 91   ...            NaN            NaN           NaN            NaN
# 92   ...            NaN            NaN           NaN            NaN
# 95   ...       0.833776      -1.298403      0.926235       0.128626
# 99   ...            NaN            NaN           NaN            NaN
# 100  ...            NaN            NaN           NaN            NaN
# 101  ...            NaN            NaN           NaN            NaN
# 103  ...            NaN            NaN           NaN            NaN
# 106  ...            NaN            NaN           NaN            NaN
# 116  ...            NaN            NaN           NaN            NaN
# 122  ...            NaN            NaN           NaN            NaN
#
#     ADRrank_mod28  ADRscore_mod29  ADRrank_mod29 hepatotox_complete_signature  \
# 7             NaN             NaN            NaN                          NaN
# 11            NaN             NaN            NaN                          NaN
# 14            NaN             NaN            NaN                          NaN
# 19            NaN             NaN            NaN                          NaN
# 51            NaN             NaN            NaN                          NaN
# 56            NaN             NaN            NaN                          NaN
# 68            NaN             NaN            NaN                          NaN
# 74            NaN             NaN            NaN                          NaN
# 85            NaN             NaN            NaN                          NaN
# 91            NaN             NaN            NaN                          NaN
# 92            NaN             NaN            NaN                          NaN
# 95       0.860533        0.554333       0.737836                    -0.452283
# 99            NaN             NaN            NaN                          NaN
# 100           NaN             NaN            NaN                          NaN
# 101           NaN             NaN            NaN                          NaN
# 103           NaN             NaN            NaN                          NaN
# 106           NaN             NaN            NaN                          NaN
# 116           NaN             NaN            NaN                          NaN
# 122           NaN             NaN            NaN                          NaN
#
#     hepatotox_complete_signature_rank                               SIDER_link
# 7                                none                                     none
# 11                               none                                     none
# 14                               none    http://sideeffects.embl.de/drugs/4763
# 19                               none                                     none
# 51                               none                                     none
# 56                               none                                     none
# 68                               none                                     none
# 74                               none  http://sideeffects.embl.de/drugs/657298
# 85                               none    http://sideeffects.embl.de/drugs/2907
# 91                               none    http://sideeffects.embl.de/drugs/4746
# 92                               none                                     none
# 95                             0.5703    http://sideeffects.embl.de/drugs/3279
# 99                               none                                     none
# 100                              none    http://sideeffects.embl.de/drugs/4746
# 101                              none    http://sideeffects.embl.de/drugs/3032
# 103                              none                                     none
# 106                              none                                     none
# 116                              none    http://sideeffects.embl.de/drugs/4509
# 122                              none    http://sideeffects.embl.de/drugs/3559
#
# [19 rows x 83 columns]

# %% [markdown]
# Sort the df according to drug and rank

# %%
GSEA_net_500_sig_z0_sorted_drug = GSEA_net_500_sig_z0.sort_values(['Drug', 'Pvalue', 'Z_score'], axis=0, ascending=True, inplace=False)

# %%
GSEA_net_500_sig_z0_sorted_drug
# Out:
#                                   Drug       Species Tissue     Study  Time  \
# 68                   2,4-dinitrophenol  Homo sapiens  liver  In Vitro   8hr
# 92                        Benziodarone  Homo sapiens  liver  In Vitro  24hr
# 103                            Bucetin  Homo sapiens  liver  In Vitro   8hr
# 85                    Cyclophosphamide  Homo sapiens  liver  In Vitro  24hr
# 101                         Diclofenac  Homo sapiens  liver  In Vitro   8hr
# 11                     Diethyl maleate  Homo sapiens  liver  In Vitro   8hr
# 95                          Ethambutol  Homo sapiens  liver  In Vitro   8hr
# 106                      Galactosamine  Homo sapiens  liver  In Vitro   8hr
# 122                        Haloperidol  Homo sapiens  liver  In Vitro   2hr
# 116                     Nitrofurantoin  Homo sapiens  liver  In Vitro   8hr
# 19                            Pemoline  Homo sapiens  liver  In Vitro   8hr
# 91                         Perhexiline  Homo sapiens  liver  In Vitro  24hr
# 100                        Perhexiline  Homo sapiens  liver  In Vitro  24hr
# 14                       Phenobarbital  Homo sapiens  liver  In Vitro   8hr
# 74                    Propylthiouracil  Homo sapiens  liver  In Vitro   2hr
# 56                           Tiopronin  Homo sapiens  liver  In Vitro  24hr
# 99                           Tiopronin  Homo sapiens  liver  In Vitro  24hr
# 7    Transforming growth factor beta 1  Homo sapiens  liver  In Vitro   2hr
# 51   Transforming growth factor beta 1  Homo sapiens  liver  In Vitro   2hr
#
#          Dose  Control sample size  Treatment sample size Database Method  \
# 68       4 uM                    2                      2  TGGATEs  limma
# 92       8 uM                    2                      2  TGGATEs  limma
# 103     60 uM                    2                      2  TGGATEs  limma
# 85     400 uM                    2                      2  TGGATEs  limma
# 101     16 uM                    2                      2  TGGATEs  limma
# 11      60 uM                    2                      2  TGGATEs  limma
# 95     800 uM                    2                      2  TGGATEs  limma
# 106   2000 uM                    2                      2  TGGATEs  limma
# 122    0.8 uM                    2                      2  TGGATEs  limma
# 116      5 uM                    2                      2  TGGATEs  limma
# 19      15 uM                    2                      2  TGGATEs  limma
# 91     0.6 uM                    2                      2  TGGATEs  limma
# 100      3 uM                    2                      2  TGGATEs  limma
# 14    2000 uM                    2                      2  TGGATEs  limma
# 74     800 uM                    2                      2  TGGATEs  limma
# 56    2000 uM                    2                      2  TGGATEs  limma
# 99     400 uM                    2                      2  TGGATEs  limma
# 7     2 ng/mL                    2                      2  TGGATEs  limma
# 51   10 ng/mL                    2                      2  TGGATEs  limma
#
#      ...  ADRrank_mod26 ADRscore_mod27 ADRrank_mod27 ADRscore_mod28  \
# 68   ...            NaN            NaN           NaN            NaN
# 92   ...            NaN            NaN           NaN            NaN
# 103  ...            NaN            NaN           NaN            NaN
# 85   ...            NaN            NaN           NaN            NaN
# 101  ...            NaN            NaN           NaN            NaN
# 11   ...            NaN            NaN           NaN            NaN
# 95   ...       0.833776      -1.298403      0.926235       0.128626
# 106  ...            NaN            NaN           NaN            NaN
# 122  ...            NaN            NaN           NaN            NaN
# 116  ...            NaN            NaN           NaN            NaN
# 19   ...            NaN            NaN           NaN            NaN
# 91   ...            NaN            NaN           NaN            NaN
# 100  ...            NaN            NaN           NaN            NaN
# 14   ...            NaN            NaN           NaN            NaN
# 74   ...            NaN            NaN           NaN            NaN
# 56   ...            NaN            NaN           NaN            NaN
# 99   ...            NaN            NaN           NaN            NaN
# 7    ...            NaN            NaN           NaN            NaN
# 51   ...            NaN            NaN           NaN            NaN
#
#     ADRrank_mod28  ADRscore_mod29  ADRrank_mod29 hepatotox_complete_signature  \
# 68            NaN             NaN            NaN                          NaN
# 92            NaN             NaN            NaN                          NaN
# 103           NaN             NaN            NaN                          NaN
# 85            NaN             NaN            NaN                          NaN
# 101           NaN             NaN            NaN                          NaN
# 11            NaN             NaN            NaN                          NaN
# 95       0.860533        0.554333       0.737836                    -0.452283
# 106           NaN             NaN            NaN                          NaN
# 122           NaN             NaN            NaN                          NaN
# 116           NaN             NaN            NaN                          NaN
# 19            NaN             NaN            NaN                          NaN
# 91            NaN             NaN            NaN                          NaN
# 100           NaN             NaN            NaN                          NaN
# 14            NaN             NaN            NaN                          NaN
# 74            NaN             NaN            NaN                          NaN
# 56            NaN             NaN            NaN                          NaN
# 99            NaN             NaN            NaN                          NaN
# 7             NaN             NaN            NaN                          NaN
# 51            NaN             NaN            NaN                          NaN
#
#     hepatotox_complete_signature_rank                               SIDER_link
# 68                               none                                     none
# 92                               none                                     none
# 103                              none                                     none
# 85                               none    http://sideeffects.embl.de/drugs/2907
# 101                              none    http://sideeffects.embl.de/drugs/3032
# 11                               none                                     none
# 95                             0.5703    http://sideeffects.embl.de/drugs/3279
# 106                              none                                     none
# 122                              none    http://sideeffects.embl.de/drugs/3559
# 116                              none    http://sideeffects.embl.de/drugs/4509
# 19                               none                                     none
# 91                               none    http://sideeffects.embl.de/drugs/4746
# 100                              none    http://sideeffects.embl.de/drugs/4746
# 14                               none    http://sideeffects.embl.de/drugs/4763
# 74                               none  http://sideeffects.embl.de/drugs/657298
# 56                               none                                     none
# 99                               none                                     none
# 7                                none                                     none
# 51                               none                                     none
#
# [19 rows x 83 columns]

# %% [markdown]
# View the top result, Etoposide, to make sure the df is sorted correctly, and the most significant result is at the top of the 'Etoposide's list in the df

# %%
GSEA_net_500_sig_z0_sorted_drug[GSEA_net_500_sig_z0_sorted_drug['Drug'] == 'Etoposide']
# Out:
# Empty DataFrame
# Columns: [Drug, Species, Tissue, Study, Time, Dose, Control sample size, Treatment sample size, Database, Method, Z_score, All_drug_gene_input_gene_overlap, Drug_gene_input_gene_overlap_in_network, Drug_genes_directly_connected_to_input_gene, Input_genes_directly_connected_to_drug_gene, Z_score_rank, Pvalue, Drug_network_name, signatures_up, signatures_down, genesignatures_combined, ADRscore_mod1, ADRrank_mod1, DILI, ADRscore_mod2, ADRrank_mod2, ADRscore_mod3, ADRrank_mod3, ADRscore_mod4, ADRrank_mod4, ADRscore_mod5, ADRrank_mod5, ADRscore_mod6, ADRrank_mod6, ADRscore_mod7, ADRrank_mod7, ADRscore_mod8, ADRrank_mod8, ADRscore_mod9, ADRrank_mod9, ADRscore_mod10, ADRrank_mod10, ADRscore_mod11, ADRrank_mod11, ADRscore_mod12, ADRrank_mod12, ADRscore_mod13, ADRrank_mod13, ADRscore_mod14, ADRrank_mod14, ADRscore_mod15, ADRrank_mod15, ADRscore_mod16, ADRrank_mod16, ADRscore_mod17, ADRrank_mod17, ADRscore_mod18, ADRrank_mod18, ADRscore_mod19, ADRrank_mod19, ADRscore_mod20, ADRrank_mod20, ADRscore_mod21, ADRrank_mod21, ADRscore_mod22, ADRrank_mod22, ADRscore_mod23, ADRrank_mod23, ADRscore_mod24, ADRrank_mod24, ADRscore_mod25, ADRrank_mod25, ADRscore_mod26, ADRrank_mod26, ADRscore_mod27, ADRrank_mod27, ADRscore_mod28, ADRrank_mod28, ADRscore_mod29, ADRrank_mod29, hepatotox_complete_signature, hepatotox_complete_signature_rank, SIDER_link]
# Index: []
#
# [0 rows x 83 columns]

# %% [markdown]
# Remove the duplicates of drugs, keeping only the first occurrence as it as the highest pvalue

# %%
GSEA_net_500_sig_z0_sorted_drug.drop_duplicates(subset = ["Drug"], inplace=True)

# %%
GSEA_net_500_sig_z0_sorted_drug
# Out:
#                                   Drug       Species Tissue     Study  Time  \
# 68                   2,4-dinitrophenol  Homo sapiens  liver  In Vitro   8hr
# 92                        Benziodarone  Homo sapiens  liver  In Vitro  24hr
# 103                            Bucetin  Homo sapiens  liver  In Vitro   8hr
# 85                    Cyclophosphamide  Homo sapiens  liver  In Vitro  24hr
# 101                         Diclofenac  Homo sapiens  liver  In Vitro   8hr
# 11                     Diethyl maleate  Homo sapiens  liver  In Vitro   8hr
# 95                          Ethambutol  Homo sapiens  liver  In Vitro   8hr
# 106                      Galactosamine  Homo sapiens  liver  In Vitro   8hr
# 122                        Haloperidol  Homo sapiens  liver  In Vitro   2hr
# 116                     Nitrofurantoin  Homo sapiens  liver  In Vitro   8hr
# 19                            Pemoline  Homo sapiens  liver  In Vitro   8hr
# 91                         Perhexiline  Homo sapiens  liver  In Vitro  24hr
# 14                       Phenobarbital  Homo sapiens  liver  In Vitro   8hr
# 74                    Propylthiouracil  Homo sapiens  liver  In Vitro   2hr
# 56                           Tiopronin  Homo sapiens  liver  In Vitro  24hr
# 7    Transforming growth factor beta 1  Homo sapiens  liver  In Vitro   2hr
#
#         Dose  Control sample size  Treatment sample size Database Method  ...  \
# 68      4 uM                    2                      2  TGGATEs  limma  ...
# 92      8 uM                    2                      2  TGGATEs  limma  ...
# 103    60 uM                    2                      2  TGGATEs  limma  ...
# 85    400 uM                    2                      2  TGGATEs  limma  ...
# 101    16 uM                    2                      2  TGGATEs  limma  ...
# 11     60 uM                    2                      2  TGGATEs  limma  ...
# 95    800 uM                    2                      2  TGGATEs  limma  ...
# 106  2000 uM                    2                      2  TGGATEs  limma  ...
# 122   0.8 uM                    2                      2  TGGATEs  limma  ...
# 116     5 uM                    2                      2  TGGATEs  limma  ...
# 19     15 uM                    2                      2  TGGATEs  limma  ...
# 91    0.6 uM                    2                      2  TGGATEs  limma  ...
# 14   2000 uM                    2                      2  TGGATEs  limma  ...
# 74    800 uM                    2                      2  TGGATEs  limma  ...
# 56   2000 uM                    2                      2  TGGATEs  limma  ...
# 7    2 ng/mL                    2                      2  TGGATEs  limma  ...
#
#      ADRrank_mod26 ADRscore_mod27 ADRrank_mod27 ADRscore_mod28 ADRrank_mod28  \
# 68             NaN            NaN           NaN            NaN           NaN
# 92             NaN            NaN           NaN            NaN           NaN
# 103            NaN            NaN           NaN            NaN           NaN
# 85             NaN            NaN           NaN            NaN           NaN
# 101            NaN            NaN           NaN            NaN           NaN
# 11             NaN            NaN           NaN            NaN           NaN
# 95        0.833776      -1.298403      0.926235       0.128626      0.860533
# 106            NaN            NaN           NaN            NaN           NaN
# 122            NaN            NaN           NaN            NaN           NaN
# 116            NaN            NaN           NaN            NaN           NaN
# 19             NaN            NaN           NaN            NaN           NaN
# 91             NaN            NaN           NaN            NaN           NaN
# 14             NaN            NaN           NaN            NaN           NaN
# 74             NaN            NaN           NaN            NaN           NaN
# 56             NaN            NaN           NaN            NaN           NaN
# 7              NaN            NaN           NaN            NaN           NaN
#
#      ADRscore_mod29  ADRrank_mod29 hepatotox_complete_signature  \
# 68              NaN            NaN                          NaN
# 92              NaN            NaN                          NaN
# 103             NaN            NaN                          NaN
# 85              NaN            NaN                          NaN
# 101             NaN            NaN                          NaN
# 11              NaN            NaN                          NaN
# 95         0.554333       0.737836                    -0.452283
# 106             NaN            NaN                          NaN
# 122             NaN            NaN                          NaN
# 116             NaN            NaN                          NaN
# 19              NaN            NaN                          NaN
# 91              NaN            NaN                          NaN
# 14              NaN            NaN                          NaN
# 74              NaN            NaN                          NaN
# 56              NaN            NaN                          NaN
# 7               NaN            NaN                          NaN
#
#     hepatotox_complete_signature_rank                               SIDER_link
# 68                               none                                     none
# 92                               none                                     none
# 103                              none                                     none
# 85                               none    http://sideeffects.embl.de/drugs/2907
# 101                              none    http://sideeffects.embl.de/drugs/3032
# 11                               none                                     none
# 95                             0.5703    http://sideeffects.embl.de/drugs/3279
# 106                              none                                     none
# 122                              none    http://sideeffects.embl.de/drugs/3559
# 116                              none    http://sideeffects.embl.de/drugs/4509
# 19                               none                                     none
# 91                               none    http://sideeffects.embl.de/drugs/4746
# 14                               none    http://sideeffects.embl.de/drugs/4763
# 74                               none  http://sideeffects.embl.de/drugs/657298
# 56                               none                                     none
# 7                                none                                     none
#
# [16 rows x 83 columns]

# %% [markdown]
# Sort the df according to Rank.

# %%
GSEA_net_500_sig_z0_sorted_sorted_rank = GSEA_net_500_sig_z0_sorted_drug.sort_values(['Z_score', 'Z_score_rank', 'Pvalue'], axis=0, ascending=True, inplace=False)

# %%
GSEA_net_500_sig_z0_sorted_sorted_rank
# Out:
#                                   Drug       Species Tissue     Study  Time  \
# 7    Transforming growth factor beta 1  Homo sapiens  liver  In Vitro   2hr
# 11                     Diethyl maleate  Homo sapiens  liver  In Vitro   8hr
# 14                       Phenobarbital  Homo sapiens  liver  In Vitro   8hr
# 19                            Pemoline  Homo sapiens  liver  In Vitro   8hr
# 56                           Tiopronin  Homo sapiens  liver  In Vitro  24hr
# 68                   2,4-dinitrophenol  Homo sapiens  liver  In Vitro   8hr
# 74                    Propylthiouracil  Homo sapiens  liver  In Vitro   2hr
# 85                    Cyclophosphamide  Homo sapiens  liver  In Vitro  24hr
# 91                         Perhexiline  Homo sapiens  liver  In Vitro  24hr
# 92                        Benziodarone  Homo sapiens  liver  In Vitro  24hr
# 95                          Ethambutol  Homo sapiens  liver  In Vitro   8hr
# 101                         Diclofenac  Homo sapiens  liver  In Vitro   8hr
# 103                            Bucetin  Homo sapiens  liver  In Vitro   8hr
# 106                      Galactosamine  Homo sapiens  liver  In Vitro   8hr
# 116                     Nitrofurantoin  Homo sapiens  liver  In Vitro   8hr
# 122                        Haloperidol  Homo sapiens  liver  In Vitro   2hr
#
#         Dose  Control sample size  Treatment sample size Database Method  ...  \
# 7    2 ng/mL                    2                      2  TGGATEs  limma  ...
# 11     60 uM                    2                      2  TGGATEs  limma  ...
# 14   2000 uM                    2                      2  TGGATEs  limma  ...
# 19     15 uM                    2                      2  TGGATEs  limma  ...
# 56   2000 uM                    2                      2  TGGATEs  limma  ...
# 68      4 uM                    2                      2  TGGATEs  limma  ...
# 74    800 uM                    2                      2  TGGATEs  limma  ...
# 85    400 uM                    2                      2  TGGATEs  limma  ...
# 91    0.6 uM                    2                      2  TGGATEs  limma  ...
# 92      8 uM                    2                      2  TGGATEs  limma  ...
# 95    800 uM                    2                      2  TGGATEs  limma  ...
# 101    16 uM                    2                      2  TGGATEs  limma  ...
# 103    60 uM                    2                      2  TGGATEs  limma  ...
# 106  2000 uM                    2                      2  TGGATEs  limma  ...
# 116     5 uM                    2                      2  TGGATEs  limma  ...
# 122   0.8 uM                    2                      2  TGGATEs  limma  ...
#
#      ADRrank_mod26 ADRscore_mod27 ADRrank_mod27 ADRscore_mod28 ADRrank_mod28  \
# 7              NaN            NaN           NaN            NaN           NaN
# 11             NaN            NaN           NaN            NaN           NaN
# 14             NaN            NaN           NaN            NaN           NaN
# 19             NaN            NaN           NaN            NaN           NaN
# 56             NaN            NaN           NaN            NaN           NaN
# 68             NaN            NaN           NaN            NaN           NaN
# 74             NaN            NaN           NaN            NaN           NaN
# 85             NaN            NaN           NaN            NaN           NaN
# 91             NaN            NaN           NaN            NaN           NaN
# 92             NaN            NaN           NaN            NaN           NaN
# 95        0.833776      -1.298403      0.926235       0.128626      0.860533
# 101            NaN            NaN           NaN            NaN           NaN
# 103            NaN            NaN           NaN            NaN           NaN
# 106            NaN            NaN           NaN            NaN           NaN
# 116            NaN            NaN           NaN            NaN           NaN
# 122            NaN            NaN           NaN            NaN           NaN
#
#      ADRscore_mod29  ADRrank_mod29 hepatotox_complete_signature  \
# 7               NaN            NaN                          NaN
# 11              NaN            NaN                          NaN
# 14              NaN            NaN                          NaN
# 19              NaN            NaN                          NaN
# 56              NaN            NaN                          NaN
# 68              NaN            NaN                          NaN
# 74              NaN            NaN                          NaN
# 85              NaN            NaN                          NaN
# 91              NaN            NaN                          NaN
# 92              NaN            NaN                          NaN
# 95         0.554333       0.737836                    -0.452283
# 101             NaN            NaN                          NaN
# 103             NaN            NaN                          NaN
# 106             NaN            NaN                          NaN
# 116             NaN            NaN                          NaN
# 122             NaN            NaN                          NaN
#
#     hepatotox_complete_signature_rank                               SIDER_link
# 7                                none                                     none
# 11                               none                                     none
# 14                               none    http://sideeffects.embl.de/drugs/4763
# 19                               none                                     none
# 56                               none                                     none
# 68                               none                                     none
# 74                               none  http://sideeffects.embl.de/drugs/657298
# 85                               none    http://sideeffects.embl.de/drugs/2907
# 91                               none    http://sideeffects.embl.de/drugs/4746
# 92                               none                                     none
# 95                             0.5703    http://sideeffects.embl.de/drugs/3279
# 101                              none    http://sideeffects.embl.de/drugs/3032
# 103                              none                                     none
# 106                              none                                     none
# 116                              none    http://sideeffects.embl.de/drugs/4509
# 122                              none    http://sideeffects.embl.de/drugs/3559
#
# [16 rows x 83 columns]

# %%
GSEA_net_500_sig_z0_sorted_sorted_rank.reset_index(inplace=True,drop=True)

# %%
GSEA_net_500_filt_results = GSEA_net_500_sig_z0_sorted_sorted_rank.copy()

# %%
GSEA_net_500_filt_results
# Out:
#                                  Drug       Species Tissue     Study  Time  \
# 0   Transforming growth factor beta 1  Homo sapiens  liver  In Vitro   2hr
# 1                     Diethyl maleate  Homo sapiens  liver  In Vitro   8hr
# 2                       Phenobarbital  Homo sapiens  liver  In Vitro   8hr
# 3                            Pemoline  Homo sapiens  liver  In Vitro   8hr
# 4                           Tiopronin  Homo sapiens  liver  In Vitro  24hr
# 5                   2,4-dinitrophenol  Homo sapiens  liver  In Vitro   8hr
# 6                    Propylthiouracil  Homo sapiens  liver  In Vitro   2hr
# 7                    Cyclophosphamide  Homo sapiens  liver  In Vitro  24hr
# 8                         Perhexiline  Homo sapiens  liver  In Vitro  24hr
# 9                        Benziodarone  Homo sapiens  liver  In Vitro  24hr
# 10                         Ethambutol  Homo sapiens  liver  In Vitro   8hr
# 11                         Diclofenac  Homo sapiens  liver  In Vitro   8hr
# 12                            Bucetin  Homo sapiens  liver  In Vitro   8hr
# 13                      Galactosamine  Homo sapiens  liver  In Vitro   8hr
# 14                     Nitrofurantoin  Homo sapiens  liver  In Vitro   8hr
# 15                        Haloperidol  Homo sapiens  liver  In Vitro   2hr
#
#        Dose  Control sample size  Treatment sample size Database Method  ...  \
# 0   2 ng/mL                    2                      2  TGGATEs  limma  ...
# 1     60 uM                    2                      2  TGGATEs  limma  ...
# 2   2000 uM                    2                      2  TGGATEs  limma  ...
# 3     15 uM                    2                      2  TGGATEs  limma  ...
# 4   2000 uM                    2                      2  TGGATEs  limma  ...
# 5      4 uM                    2                      2  TGGATEs  limma  ...
# 6    800 uM                    2                      2  TGGATEs  limma  ...
# 7    400 uM                    2                      2  TGGATEs  limma  ...
# 8    0.6 uM                    2                      2  TGGATEs  limma  ...
# 9      8 uM                    2                      2  TGGATEs  limma  ...
# 10   800 uM                    2                      2  TGGATEs  limma  ...
# 11    16 uM                    2                      2  TGGATEs  limma  ...
# 12    60 uM                    2                      2  TGGATEs  limma  ...
# 13  2000 uM                    2                      2  TGGATEs  limma  ...
# 14     5 uM                    2                      2  TGGATEs  limma  ...
# 15   0.8 uM                    2                      2  TGGATEs  limma  ...
#
#     ADRrank_mod26 ADRscore_mod27 ADRrank_mod27 ADRscore_mod28 ADRrank_mod28  \
# 0             NaN            NaN           NaN            NaN           NaN
# 1             NaN            NaN           NaN            NaN           NaN
# 2             NaN            NaN           NaN            NaN           NaN
# 3             NaN            NaN           NaN            NaN           NaN
# 4             NaN            NaN           NaN            NaN           NaN
# 5             NaN            NaN           NaN            NaN           NaN
# 6             NaN            NaN           NaN            NaN           NaN
# 7             NaN            NaN           NaN            NaN           NaN
# 8             NaN            NaN           NaN            NaN           NaN
# 9             NaN            NaN           NaN            NaN           NaN
# 10       0.833776      -1.298403      0.926235       0.128626      0.860533
# 11            NaN            NaN           NaN            NaN           NaN
# 12            NaN            NaN           NaN            NaN           NaN
# 13            NaN            NaN           NaN            NaN           NaN
# 14            NaN            NaN           NaN            NaN           NaN
# 15            NaN            NaN           NaN            NaN           NaN
#
#     ADRscore_mod29  ADRrank_mod29 hepatotox_complete_signature  \
# 0              NaN            NaN                          NaN
# 1              NaN            NaN                          NaN
# 2              NaN            NaN                          NaN
# 3              NaN            NaN                          NaN
# 4              NaN            NaN                          NaN
# 5              NaN            NaN                          NaN
# 6              NaN            NaN                          NaN
# 7              NaN            NaN                          NaN
# 8              NaN            NaN                          NaN
# 9              NaN            NaN                          NaN
# 10        0.554333       0.737836                    -0.452283
# 11             NaN            NaN                          NaN
# 12             NaN            NaN                          NaN
# 13             NaN            NaN                          NaN
# 14             NaN            NaN                          NaN
# 15             NaN            NaN                          NaN
#
#    hepatotox_complete_signature_rank                               SIDER_link
# 0                               none                                     none
# 1                               none                                     none
# 2                               none    http://sideeffects.embl.de/drugs/4763
# 3                               none                                     none
# 4                               none                                     none
# 5                               none                                     none
# 6                               none  http://sideeffects.embl.de/drugs/657298
# 7                               none    http://sideeffects.embl.de/drugs/2907
# 8                               none    http://sideeffects.embl.de/drugs/4746
# 9                               none                                     none
# 10                            0.5703    http://sideeffects.embl.de/drugs/3279
# 11                              none    http://sideeffects.embl.de/drugs/3032
# 12                              none                                     none
# 13                              none                                     none
# 14                              none    http://sideeffects.embl.de/drugs/4509
# 15                              none    http://sideeffects.embl.de/drugs/3559
#
# [16 rows x 83 columns]

# %% [markdown]
# Finally, for GSEA, filter overlap

# %%
GSEA_overlap
# Out:
#                                                 Database  \
# 0                                               TG-GATEs
# 1                                        DrugMatrix_Affy
# 2                                            E-GEOD-7999
# 3                              DrugMatrix_ASPIRIN_kidney
# 4                              DrugMatrix_ASPIRIN_kidney
# ...                                                  ...
# 45987                   DrugMatrix_HYDROCORTISONE_kidney
# 45988                       DrugMatrix_ANTIPYRINE_kidney
# 45989  GSE17115, GSE30416, GSE63188, GSE56426, GSE606...
# 45990                        DrugMatrix_RIFABUTIN_kidney
# 45991                    DrugMatrix_HYDROCORTISONE_heart
#
#                          Method            Drug            Species  \
# 0                         limma     Carboplatin  Rattus norvegicus
# 1                         limma    Isoprenaline  Rattus norvegicus
# 2      Characteristic direction   Isoproterenol  Rattus norvegicus
# 3      Characteristic direction         Aspirin  Rattus norvegicus
# 4      Characteristic direction    Antiplatelet  Rattus norvegicus
# ...                         ...             ...                ...
# 45987  Characteristic direction  Hydrocortisone  Rattus norvegicus
# 45988  Characteristic direction      Antipyrine  Rattus norvegicus
# 45989  Characteristic direction  Antineoplastic       Mus musculus
# 45990  Characteristic direction       Rifabutin  Rattus norvegicus
# 45991  Characteristic direction  Hydrocortisone  Rattus norvegicus
#
#            Tissue or Cell Line            Study             Dose  \
# 0                       kidney   In Vivo Repeat         10 mg/kg
# 1        cardiovascular system          In Vivo        4.2 mg/kg
# 2                        liver  PharmOmics meta  PharmOmics meta
# 3                       kidney  PharmOmics meta  PharmOmics meta
# 4                       kidney  PharmOmics meta  PharmOmics meta
# ...                        ...              ...              ...
# 45987                   kidney  PharmOmics meta  PharmOmics meta
# 45988                   kidney  PharmOmics meta  PharmOmics meta
# 45989  gastrointestinal system  PharmOmics meta  PharmOmics meta
# 45990                   kidney  PharmOmics meta  PharmOmics meta
# 45991    cardiovascular system  PharmOmics meta  PharmOmics meta
#
#                   Time  Jaccard Score  Odds Ratio       P value  \
# 0                  15d       0.058824    8.553157  9.658755e-06
# 1                   5d       0.053571   11.201770  2.998571e-05
# 2      PharmOmics meta       0.051065    8.602776  2.647010e-06
# 3      PharmOmics meta       0.049843    6.185165  1.799134e-06
# 4      PharmOmics meta       0.049843    6.185165  1.799134e-06
# ...                ...            ...         ...           ...
# 45987  PharmOmics meta      -0.060992    7.375676  3.586221e-08
# 45988  PharmOmics meta      -0.063584   10.579296  5.439363e-13
# 45989  PharmOmics meta      -0.064075    8.590419  3.101464e-15
# 45990  PharmOmics meta      -0.071276   11.262328  4.854320e-14
# 45991  PharmOmics meta      -0.078281    9.256138  5.656869e-11
#
#        Within Species Rank                                            Overlap  \
# 0                 1.000000  Dtl, Cdk1, Top2a, Cks1b, Nusap1, Aspm, Ect2, Prc1
# 1                 0.999594              Cdk1, Top2a, Cdc20, Prc1, Postn, Cks2
# 2                 0.999187  Spp1, Epcam, Postn, Vcan, Mmp10, Serpine1, Nmu...
# 3                 0.998578  Lcn2, Aspm, Top2a, Nusap1, Tnc, Cks2, Cdk1, Ec...
# 4                 0.998578  Lcn2, Aspm, Top2a, Nusap1, Tnc, Cks2, Cdk1, Ec...
# ...                    ...                                                ...
# 45987            -0.999401  Lcn2, Serpine1, Mall, Dusp5, Cdk1, Prc1, Ect2,...
# 45988            -0.999600  Psca, Cfd, Vcan, Ppl, Cyp3a18, Upk1a, LOC49822...
# 45989            -1.000000  Lcn2, Cfd, Ecm1, Dio2, Ppl, Serpinb2, Ereg, Co...
# 45990            -0.999800  Lamb3, Psca, Lamc2, Vcan, Upk1a, Lcn2, Clca4, ...
# 45991            -1.000000  Cfd, Fmo2, Ppl, Cdk1, Prc1, Cks2, Mall, Postn,...
#
#        nOverlap                                   allsignatures_up  \
# 0             8  Ccng1,Phlda3,Ckap2,Dtl,Mdm2,Spc24,Cdkn1a,P2rx4...
# 1             6  LOC685157,Stk19,Ns5atp9,Cdk1,Tmem163,Top2a,Mki...
# 2             9  Il6,Cxcl1,Ptgs2,Nr4a3,Sphk1,Atf3,Timp1,Olr1,Il...
# 3            12  Havcr1,Nr1d1,Gpx2,Fndc1,Dbp,Car3,Cyp3a2,Hmgcs2...
# 4            12  Havcr1,Nr1d1,Gpx2,Fndc1,Dbp,Car3,Cyp3a2,Hmgcs2...
# ...         ...                                                ...
# 45987        14  S100a9,Coch,LOC679818,Lcn2,Ftcd,Abcb11,Cyp27b1...
# 45988        19  Sprr1a,Psca,Cyp2b2,Aldh1a7,Gstm1,Nrip3,Pcsk9,U...
# 45989        26  Hp,Lrg1,Lcn2,Per2,Mt2,Dbp,Apod,Saa3,Chil3,Mt1,...
# 45990        20  Serpina3n,Cyp1a1,Gpnmb,Sprr1a,Cyp3a23/3a1,Guca...
# 45991        17  Ptgds,Orm1,Pla2g2a,S100a9,Tmem108,Thrsp,Cyp2e1...
#
#                                       allsignatures_down  \
# 0      C3,Cd4,Hbb-b1,LOC103694857,LOC689064,LOC100134...
# 1      Rimbp2,Epas1,Akap6,Me1,Ldb3,Lgalsl,Svip,Itga7,...
# 2      Aoc1,Mmp3,Agps,LOC297568,Lin7a,Smr3a,Cfap161,S...
# 3      Fos,Cyp2c11,Cish,Nr4a1,Egr1,Dusp1,Psca,Gadd45g...
# 4      Fos,Cyp2c11,Cish,Nr4a1,Egr1,Dusp1,Psca,Gadd45g...
# ...                                                  ...
# 45987  Slpi,Fam111a,Cdkn3,Akr1b8,Mki67,Cdk1,Fndc1,Mfa...
# 45988  Hao1,Mylk3,Mfap4,Cish,Aadac,Cdkn3,Ubd,Gadd45g,...
# 45989  Alas2,Cdkn3,Prap1,Cxcl10,Tppp,Cenpa,Plk1,Slc7a...
# 45990  Cyp2c11,Snca,Aldh1b1,Alas2,Cdkn3,Mfap4,Cdk1,Pc...
# 45991  Fam111a,Cdk1,Prc1,Cks2,Ccnb2,Copg2,Mki67,Cdkn3...
#
#                                   allsignatures_combined  \
# 0      Ccng1,C3,Phlda3,Ckap2,Dtl,Cd4,Mdm2,Spc24,Hbb-b...
# 1      LOC685157,Stk19,Ns5atp9,Cdk1,Tmem163,Top2a,Mki...
# 2      Il6,Aoc1,Cxcl1,Mmp3,Ptgs2,Agps,Nr4a3,LOC297568...
# 3      Havcr1,Fos,Nr1d1,Cyp2c11,Gpx2,Cish,Fndc1,Nr4a1...
# 4      Havcr1,Fos,Nr1d1,Cyp2c11,Gpx2,Cish,Fndc1,Nr4a1...
# ...                                                  ...
# 45987  S100a9,Slpi,Coch,Fam111a,LOC679818,Cdkn3,Lcn2,...
# 45988  Sprr1a,Hao1,Psca,Mylk3,Cyp2b2,Mfap4,Aldh1a7,Ci...
# 45989  Hp,Alas2,Lrg1,Lcn2,Per2,Cdkn3,Prap1,Mt2,Dbp,Cx...
# 45990  Serpina3n,Cyp2c11,Cyp1a1,Snca,Gpnmb,Aldh1b1,Sp...
# 45991  Ptgds,Fam111a,Orm1,Cdk1,Pla2g2a,Prc1,S100a9,Ck...
#
#                                      SIDER_link
# 0        http://sideeffects.embl.de/drugs/38904
# 1         http://sideeffects.embl.de/drugs/3779
# 2                                          none
# 3         http://sideeffects.embl.de/drugs/2244
# 4                                          none
# ...                                         ...
# 45987     http://sideeffects.embl.de/drugs/3640
# 45988                                      none
# 45989                                      none
# 45990  http://sideeffects.embl.de/drugs/5361912
# 45991     http://sideeffects.embl.de/drugs/3640
#
# [45992 rows x 18 columns]

# %%
GSEA_overlap_sig = GSEA_overlap[GSEA_overlap["P value"] <= 0.05]

# %%
GSEA_overlap_sig = GSEA_overlap_sig[GSEA_overlap_sig['Within Species Rank'] >= 0]

# %%
GSEA_overlap_sig_hs = GSEA_overlap_sig[GSEA_overlap_sig['Species'] == 'Homo sapiens']

# %%
GSEA_overlap_sig_hs
# Out:
#                     Database                    Method              Drug  \
# 2720  L1000_CPC006_HCC515_6H  Characteristic direction      Fluspirilene
# 2721   L1000_CPC011_VCAP_24H  Characteristic direction       Vincristine
# 2722                GSE33520  Characteristic direction  Arsenic trioxide
# 2723    L1000_ASG001_MCF7_6H  Characteristic direction      Troglitazone
# 2724    L1000_ASG001_MCF7_6H  Characteristic direction         Tretinoin
# ...                      ...                       ...               ...
# 9787                TG-GATEs                     limma     Benzbromarone
# 9789                TG-GATEs                     limma         Flutamide
# 9790                TG-GATEs                     limma      Ketoconazole
# 9791                TG-GATEs                     limma     Methapyrilene
# 9793                TG-GATEs                     limma    Nitrofurantoin
#
#            Species Tissue or Cell Line            Study             Dose  \
# 2720  Homo sapiens              HCC515         In Vitro          4.21 uM
# 2721  Homo sapiens                VCAP         In Vitro            10 uM
# 2722  Homo sapiens  respiratory system  PharmOmics meta  PharmOmics meta
# 2723  Homo sapiens                MCF7         In Vitro             2 uM
# 2724  Homo sapiens                MCF7         In Vitro          0.08 uM
# ...            ...                 ...              ...              ...
# 9787  Homo sapiens               liver         In Vitro           100 uM
# 9789  Homo sapiens               liver         In Vitro            50 uM
# 9790  Homo sapiens               liver         In Vitro            15 uM
# 9791  Homo sapiens               liver         In Vitro           600 uM
# 9793  Homo sapiens               liver         In Vitro           125 uM
#
#                  Time  Jaccard Score  Odds Ratio       P value  \
# 2720              6hr   1.387779e-17   62.914719  6.708412e-54
# 2721             24hr   1.387779e-17   38.118083  1.690898e-34
# 2722  PharmOmics meta   6.938894e-18   33.682192  1.804291e-15
# 2723              6hr   6.938894e-18   21.412650  9.046003e-16
# 2724              6hr   6.938894e-18   33.475333  7.273149e-26
# ...               ...            ...         ...           ...
# 9787             24hr   2.168404e-19    1.750739  2.077499e-02
# 9789             24hr   2.168404e-19    2.195384  9.930895e-03
# 9790              8hr   2.168404e-19    3.940191  1.440475e-03
# 9791              8hr   2.168404e-19    3.767372  5.516397e-05
# 9793             24hr   1.084202e-19    2.091866  9.135439e-03
#
#       Within Species Rank                                            Overlap  \
# 2720             0.999929  SERPINB3, ISG15, BLNK, CYP4B1, SCEL, TMPRSS11D...
# 2721             0.999929  CRABP2, POSTN, FOXM1, HOPX, CEACAM5, CEACAM6, ...
# 2722             0.974530  HOPX, SPP1, EPB41L3, CDH11, TOP2A, SERPINB2, N...
# 2723             0.974530  COL11A1, CD24, POSTN, ITGA6, COL3A1, CEACAM1, ...
# 2724             0.974530  PPP1R3C, ABLIM1, SERPINB2, COL3A1, SERPINE1, C...
# ...                   ...                                                ...
# 9787             0.000778  TMPRSS2, PPL, LCN2, VCAN, DUSP5, GPX3, S100P, ...
# 9789             0.000778  CYP3A5, CD24, GPX3, LPIN1, DUSP5, TMPRSS2, ODC...
# 9790             0.000778  TMPRSS2, DUSP5, BLNK, CYP3A5, LPIN1, SERPINE1,...
# 9791             0.000778  DUSP5, LPIN1, TMPRSS2, IL1RN, UBL3, CYP3A5, EM...
# 9793             0.000142  SASH1, CRYAB, GPX3, SERPINE1, DUSP5, LPIN1, TM...
#
#       nOverlap                                   allsignatures_up  \
# 2720        41  TGM2,TRIM14,MIA,IFI27,FBXO11,DENND1B,SRSF11,SR...
# 2721        30  HEPH,TIMP3,MMP19,KIAA0182,PLK1,KIAA0226L,TSPAN...
# 2722        13  AGR2,HOPX,IL1A,AKR1C1,SPP1,EPB41L3,AKR1C3,CDH1...
# 2723        16  HSPA2,PCK1,KLK6,NTAN1,CDKN2AIP,PCSK1,IL6ST,CAS...
# 2724        23  MAN2B1,SCG5,CPD,BGN,NQO1,RAPGEF5,CHN1,MFAP4,UB...
# ...        ...                                                ...
# 9787        19  SLC30A2,MICALL1,FABP4,TRIM24,RABGGTB,GADD45B,G...
# 9789        13  SLC7A8,TBC1D22B,CASP2,SULT1C2,NOV,DLAT,NR1H4,A...
# 9790         8  SERTAD2,RASIP1,PPP1R15A,C10orf90,ZNF442,WEE1,S...
# 9791        14  SEMA6B,FBXO32,CD55,DUSP5,LPIN1,INSIG1,TMPRSS2,...
# 9793        15  RTN4RL2,SLC19A1,ANKRD26P3,MAFF,DNAJA4,HSPA6,UP...
#
#                                      allsignatures_down  \
# 2720  CD38,ADD3,PPAP2B,KIAA0182,FAM3C,CPE,BGN,ADCK3,...
# 2721  PTGS1,ADD3,LRPPRC,PCCB,GALC,CD34,CLDN10,BGN,TX...
# 2722  SULF2,TIMP3,MT1F,SFRP1,STC1,TNFSF10,LYPD1,SPAR...
# 2723  TAP1,PPAP2B,TIMP1,SLC16A7,IFI27,PLK2,CPD,GSTA1...
# 2724  TGM2,TM7SF2,PPAP2A,SSX1,SLC16A7,TSPAN13,SPRED2...
# ...                                                 ...
# 9787  CYP8B1,ANLN,NAT2,SLC33A1,ALDH8A1,B4GAT1,FAM72A...
# 9789  LOC653581,HRG,INSC,KIF20A,HJURP,CDCA3,UBE2C,DE...
# 9790  DNAJA1,HSPA8,ANGPTL4,GSPT2,RGS2,TNFRSF21,PIGH,...
# 9791  RANBP6,OXCT2,ZNF121,OXTR,ANGPTL4,SPTSSB,OXCT2P...
# 9793  BUB1,PIPOX,GDA,ITIH2,NDC80,CDCA3,PCK1,PDIA4,FA...
#
#                                  allsignatures_combined  \
# 2720  CD38,ADD3,PPAP2B,IFI27,FBXO11,CPE,BGN,HIPK2,MF...
# 2721  ELANE,ADD3,HRSP12,SLC6A8,CD34,STEAP3,CD36,TXND...
# 2722  AGR2,SULF2,HOPX,TIMP3,IL1A,MT1F,AKR1C1,SFRP1,S...
# 2723  TAP1,HSPA2,GNLY,PPAP2B,HSPA5,CDKN2AIP,PCSK1,CP...
# 2724  TM7SF2,PPAP2A,SCG5,CPD,BGN,CD37,RAPGEF5,CHN1,M...
# ...                                                 ...
# 9787  CYP8B1,SLC30A2,ANLN,MICALL1,FABP4,TRIM24,NAT2,...
# 9789  LOC653581,SLC7A8,HRG,INSC,TBC1D22B,KIF20A,CASP...
# 9790  DNAJA1,HSPA8,SERTAD2,RASIP1,ANGPTL4,PPP1R15A,C...
# 9791  SEMA6B,FBXO32,RANBP6,CD55,DUSP5,LPIN1,OXCT2,IN...
# 9793  RTN4RL2,SLC19A1,BUB1,PIPOX,GDA,ANKRD26P3,MAFF,...
#
#                                   SIDER_link
# 2720                                    none
# 2721   http://sideeffects.embl.de/drugs/5978
# 2722  http://sideeffects.embl.de/drugs/14888
# 2723   http://sideeffects.embl.de/drugs/5591
# 2724   http://sideeffects.embl.de/drugs/5538
# ...                                      ...
# 9787                                    none
# 9789   http://sideeffects.embl.de/drugs/3397
# 9790   http://sideeffects.embl.de/drugs/3823
# 9791                                    none
# 9793   http://sideeffects.embl.de/drugs/4509
#
# [6991 rows x 18 columns]

# %% [markdown]
# Filter the results to select only those with a Jaccard score above the mean.

# %%
GSEA_overlap_sig_hs['Jaccard Score'].mean()
# Out:
# 2.5989059628514987e-18

# %%
GSEA_overlap_sig_hs_js = GSEA_overlap_sig_hs[GSEA_overlap_sig_hs['Jaccard Score'] > 2.5989059628514987e-18]

# %%
GSEA_overlap_sig_hs_js
# Out:
#                       Database                    Method              Drug  \
# 2720    L1000_CPC006_HCC515_6H  Characteristic direction      Fluspirilene
# 2721     L1000_CPC011_VCAP_24H  Characteristic direction       Vincristine
# 2722                  GSE33520  Characteristic direction  Arsenic trioxide
# 2723      L1000_ASG001_MCF7_6H  Characteristic direction      Troglitazone
# 2724      L1000_ASG001_MCF7_6H  Characteristic direction         Tretinoin
# ...                        ...                       ...               ...
# 6059   L1000_MUC.CP002_MCF7_6H  Characteristic direction       Mebendazole
# 6060  L1000_MUC.CP004_MCF7_24H  Characteristic direction       Vincristine
# 6061       L1000_NMH002_NPC_6H  Characteristic direction     Rosiglitazone
# 6062      L1000_PCLB001_PC3_6H  Characteristic direction    Trichostatin-a
# 6063    L1000_RAD001_HCC515_6H  Characteristic direction       Selumetinib
#
#            Species Tissue or Cell Line            Study             Dose  \
# 2720  Homo sapiens              HCC515         In Vitro          4.21 uM
# 2721  Homo sapiens                VCAP         In Vitro            10 uM
# 2722  Homo sapiens  respiratory system  PharmOmics meta  PharmOmics meta
# 2723  Homo sapiens                MCF7         In Vitro             2 uM
# 2724  Homo sapiens                MCF7         In Vitro          0.08 uM
# ...            ...                 ...              ...              ...
# 6059  Homo sapiens                MCF7         In Vitro            40 uM
# 6060  Homo sapiens                MCF7         In Vitro            10 uM
# 6061  Homo sapiens                 NPC         In Vitro            10 uM
# 6062  Homo sapiens                 PC3         In Vitro           2.5 uM
# 6063  Homo sapiens              HCC515         In Vitro        1.1111 uM
#
#                  Time  Jaccard Score  Odds Ratio       P value  \
# 2720              6hr   1.387779e-17   62.914719  6.708412e-54
# 2721             24hr   1.387779e-17   38.118083  1.690898e-34
# 2722  PharmOmics meta   6.938894e-18   33.682192  1.804291e-15
# 2723              6hr   6.938894e-18   21.412650  9.046003e-16
# 2724              6hr   6.938894e-18   33.475333  7.273149e-26
# ...               ...            ...         ...           ...
# 6059              6hr   2.602085e-18   14.530886  7.125643e-12
# 6060             24hr   2.602085e-18   14.452263  4.070164e-11
# 6061              6hr   2.602085e-18   13.945562  1.199518e-11
# 6062              6hr   2.602085e-18   14.125101  2.808639e-10
# 6063              6hr   2.602085e-18   15.431676  6.180043e-10
#
#       Within Species Rank                                            Overlap  \
# 2720             0.999929  SERPINB3, ISG15, BLNK, CYP4B1, SCEL, TMPRSS11D...
# 2721             0.999929  CRABP2, POSTN, FOXM1, HOPX, CEACAM5, CEACAM6, ...
# 2722             0.974530  HOPX, SPP1, EPB41L3, CDH11, TOP2A, SERPINB2, N...
# 2723             0.974530  COL11A1, CD24, POSTN, ITGA6, COL3A1, CEACAM1, ...
# 2724             0.974530  PPP1R3C, ABLIM1, SERPINB2, COL3A1, SERPINE1, C...
# ...                   ...                                                ...
# 6059             0.535800  CLIC3, POSTN, LPIN1, CEACAM1, DIO2, CRISP3, CR...
# 6060             0.535800  CYP3A5, SCEL, FLG, SCNN1A, CEACAM6, ZNF185, IL...
# 6061             0.535800  MYH11, HPGD, SCNN1A, ZNF185, MGLL, ADH1B, GPX3...
# 6062             0.535800  BLNK, MALL, PRSS3, ZNF185, HSPB8, CCNG2, MGLL,...
# 6063             0.535800  CD24, HPGD, CEACAM1, CLCA4, CEACAM7, KRT4, ASP...
#
#       nOverlap                                   allsignatures_up  \
# 2720        41  TGM2,TRIM14,MIA,IFI27,FBXO11,DENND1B,SRSF11,SR...
# 2721        30  HEPH,TIMP3,MMP19,KIAA0182,PLK1,KIAA0226L,TSPAN...
# 2722        13  AGR2,HOPX,IL1A,AKR1C1,SPP1,EPB41L3,AKR1C3,CDH1...
# 2723        16  HSPA2,PCK1,KLK6,NTAN1,CDKN2AIP,PCSK1,IL6ST,CAS...
# 2724        23  MAN2B1,SCG5,CPD,BGN,NQO1,RAPGEF5,CHN1,MFAP4,UB...
# ...        ...                                                ...
# 6059        14  DHDDS,PMAIP1,KCNE4,KIAA0182,NRCAM,PCSK1,MFHAS1...
# 6060        13  BPTF,BCL2L1,ELANE,ZDHHC11,HBB,PLA2G2A,SH3BGRL,...
# 6061        14  MSMO1,TGM2,SCGB1D2,YWHAE,SFTPB,MYH11,PLK1,IDI1...
# 6062        12  MSMO1,PCK1,ADD3,IDI1,IFI27,FBXO11,CD36,CD37,CT...
# 6063        11  LAMP1,PPAP2A,TUSC3,FBXO11,STXBP6,ANP32E,CLU,CR...
#
#                                      allsignatures_down  \
# 2720  CD38,ADD3,PPAP2B,KIAA0182,FAM3C,CPE,BGN,ADCK3,...
# 2721  PTGS1,ADD3,LRPPRC,PCCB,GALC,CD34,CLDN10,BGN,TX...
# 2722  SULF2,TIMP3,MT1F,SFRP1,STC1,TNFSF10,LYPD1,SPAR...
# 2723  TAP1,PPAP2B,TIMP1,SLC16A7,IFI27,PLK2,CPD,GSTA1...
# 2724  TGM2,TM7SF2,PPAP2A,SSX1,SLC16A7,TSPAN13,SPRED2...
# ...                                                 ...
# 6059  TIMP1,SFTPC,ZFPM2,PPP2R3C,IFI27,POLG2,CHN2,P4H...
# 6060  SSPN,PGAP3,TM2D3,FXYD3,TUSC3,PCSK6,ELF3,MFAP5,...
# 6061  DYNC1I1,TRDV3,FXYD5,ADD3,COL11A1,GNPTAB,PLK2,I...
# 6062  UBE3A,FXYD3,FKBP10,WNT5A,BGN,NEFH,GLG1,PLK1S1,...
# 6063  EFNB2,LIF,ANGPTL4,SFTPB,TMC5,RHBDF2,SCG5,PTPRE...
#
#                                  allsignatures_combined  \
# 2720  CD38,ADD3,PPAP2B,IFI27,FBXO11,CPE,BGN,HIPK2,MF...
# 2721  ELANE,ADD3,HRSP12,SLC6A8,CD34,STEAP3,CD36,TXND...
# 2722  AGR2,SULF2,HOPX,TIMP3,IL1A,MT1F,AKR1C1,SFRP1,S...
# 2723  TAP1,HSPA2,GNLY,PPAP2B,HSPA5,CDKN2AIP,PCSK1,CP...
# 2724  TM7SF2,PPAP2A,SCG5,CPD,BGN,CD37,RAPGEF5,CHN1,M...
# ...                                                 ...
# 6059  PMAIP1,IFI27,PCSK1,OGN,TXNDC9,CHN2,P4HA1,APOC1...
# 6060  BPTF,SSPN,ELANE,ZDHHC11,DAPK1,TMEM140,PCSK6,PG...
# 6061  RANBP9,ADD3,PPAP2B,GNPTAB,HSPA8,TRDV3,CD36,IL6...
# 6062  ADD3,FKBP10,IFI27,FBXO11,CD36,CD37,PLK1S1,PMM2...
# 6063  ARHGAP12,UBE2J1,PPAP2A,SCG5,FBXO11,SSFA2,ANP32...
#
#                                   SIDER_link
# 2720                                    none
# 2721   http://sideeffects.embl.de/drugs/5978
# 2722  http://sideeffects.embl.de/drugs/14888
# 2723   http://sideeffects.embl.de/drugs/5591
# 2724   http://sideeffects.embl.de/drugs/5538
# ...                                      ...
# 6059   http://sideeffects.embl.de/drugs/4030
# 6060   http://sideeffects.embl.de/drugs/5978
# 6061  http://sideeffects.embl.de/drugs/77998
# 6062                                    none
# 6063                                    none
#
# [3344 rows x 18 columns]

# %%
GSEA_overlap_sig_hs_sorted_drug = GSEA_overlap_sig_hs_js.sort_values(['Drug', 'Within Species Rank', 'Jaccard Score', 'P value'], axis=0, ascending=False, inplace=False)

# %%
GSEA_overlap_sig_hs_sorted_drug
# Out:
#                      Database                    Method                 Drug  \
# 5200     L1000_CPD001_PC3_24H  Characteristic direction         Zoxazolamine
# 3511     L1000_CPC004_HA1E_6H  Characteristic direction         Zoxazolamine
# 3547    L1000_CPC004_HEPG2_6H  Characteristic direction         Zoxazolamine
# 4931     L1000_CPC014_HA1E_6H  Characteristic direction           Zosuquidar
# 4559     L1000_CPC011_MCF7_6H  Characteristic direction             Zolpidem
# ...                       ...                       ...                  ...
# 3923  L1000_CPC006_HCC515_24H  Characteristic direction              10-DEBC
# 5989      L1000_CPC006_PC3_6H  Characteristic direction              10-DEBC
# 4509     L1000_CPC010_VCAP_6H  Characteristic direction    1-benzylimidazole
# 4469    L1000_CPC010_HEPG2_6H  Characteristic direction    1-benzylimidazole
# 3262    L1000_CPC001_VCAP_24H  Characteristic direction  1,2-dichlorobenzene
#
#            Species Tissue or Cell Line     Study   Dose  Time  Jaccard Score  \
# 5200  Homo sapiens                 PC3  In Vitro  10 uM  24hr   3.469447e-18
# 3511  Homo sapiens                HA1E  In Vitro  10 uM   6hr   3.469447e-18
# 3547  Homo sapiens               HEPG2  In Vitro  10 uM   6hr   3.469447e-18
# 4931  Homo sapiens                HA1E  In Vitro  10 uM   6hr   3.469447e-18
# 4559  Homo sapiens                MCF7  In Vitro  10 uM   6hr   3.469447e-18
# ...            ...                 ...       ...    ...   ...            ...
# 3923  Homo sapiens              HCC515  In Vitro  24 uM  24hr   3.469447e-18
# 5989  Homo sapiens                 PC3  In Vitro  24 uM   6hr   2.602085e-18
# 4509  Homo sapiens                VCAP  In Vitro  10 uM   6hr   3.469447e-18
# 4469  Homo sapiens               HEPG2  In Vitro  10 uM   6hr   3.469447e-18
# 3262  Homo sapiens                VCAP  In Vitro  10 uM  24hr   3.469447e-18
#
#       Odds Ratio       P value  Within Species Rank  \
# 5200   10.148099  2.565312e-06             0.745649
# 3511   13.039772  1.643461e-08             0.745649
# 3547   27.633904  3.663020e-23             0.745649
# 4931   15.289574  3.736518e-12             0.745649
# 4559   12.862774  9.287813e-08             0.745649
# ...          ...           ...                  ...
# 3923   21.728227  7.301320e-16             0.745649
# 5989   15.631213  9.326867e-11             0.535800
# 4509   17.786412  5.439590e-13             0.745649
# 4469   18.073465  1.681474e-15             0.745649
# 3262   26.737282  3.542894e-17             0.745649
#
#                                                 Overlap  nOverlap  \
# 5200  MMP11, IL1RN, COL1A2, HMGB3, VCAN, SULF1, PPL,...         8
# 3511  POSTN, CXCL12, KAT2B, COL3A1, THBS2, TMEM45A, ...        10
# 3547  SNAI2, PPP1R3C, POSTN, CYP3A5, ITGA6, LAMB3, P...        22
# 4931  PPP1R3C, TP63, EHF, ITGA6, SCNN1A, CYP4B1, MUC...        14
# 4559  KLK11, SNAI2, CXCL12, ISG15, GPX3, MYH11, PSCA...         9
# ...                                                 ...       ...
# 3923  ID4, SCEL, CEACAM1, MALL, SCNN1A, CEACAM6, TOP...        16
# 5989  SCEL, LAMB3, MALL, PPP1R3C, GPX3, CCNG2, HPGD,...        12
# 4509  CRNN, SNAI2, CXCL12, PSCA, GABRP, KRT13, CLCA4...        14
# 4469  CD24, SERPINB1, ISG15, SPRR3, GABRP, KRT13, SN...        17
# 3262  SERPINB2, SPINK5, COL3A1, PLAC8, ZNF185, IL1RN...        16
#
#                                        allsignatures_up  \
# 5200  TGM2,TMOD1,PPAP2A,ACP5,PLK1,SLC6A8,CPD,CCL4,PO...
# 3511  HSPA2,ADD3,UBE2J1,TRIM16,IFI27,FBXO11,NQO1,POD...
# 3547  HIST1H4C,SSPN,PGAP3,PPAP2C,UBE2J1,TMC5,JUN,PLK...
# 4931  PCK2,PTGS2,KLRB1,PPAP2B,HSPA2,HIST1H4J,PSMF1,N...
# 4559  PECR,PCK1,ADD3,CPM,ACTG2,RAB4A,TGDS,SCG5,KLK11...
# ...                                                 ...
# 3923  PTGS2,C17ORF81,PPAP2C,YWHAE,IDI1,FBXO11,DHCR7,...
# 5989  TM4SF1,ADD3,CPM,TRIM16,IDI1,KLK10,HSPA8,HBB,CA...
# 4509  HIST1H4C,SCGB1D2,ADD3,RAB4A,LRRC16A,CRNN,SPRED...
# 4469  ADD3,TRIM14,SYBU,WNT5A,KLK10,PSPC1,NQO1,N4BP2L...
# 3262  HSPA2,RPN2,TM7SF3,KCNE4,SSX1,GSTA4,IFI27,HSPA8...
#
#                                      allsignatures_down  \
# 5200  FXYD2,HSPA6,IFI27,TSPAN13,ABP1,C3ORF14,DHCR7,M...
# 3511  FXYD6,TGM2,CRKL,SSX1,TRDV3,TXNDC9,N4BP2L2,APOC...
# 3547  PTGS1,SYNPO,HSPA6,CKB,KLK13,KLK10,KLK11,NQO2,C...
# 4931  HIST1H4C,BPTF,PPP1R14B,TIMP2,SCG5,HSPA8,BGN,TX...
# 4559  ELANE,C11ORF10,NDUFB2,PTHLH,TXNDC9,CHN2,GPM6A,...
# ...                                                 ...
# 3923  TIMP3,DARS,ISL1,STK10,CHRNA3,HBB,RAPGEF5,MFAP5...
# 5989  PCK2,TAP1,PCK1,ACTG2,TUSC3,GSTA4,STK10,BBX,POL...
# 4509  SFTPB,SFTPC,PCCB,KLK10,PLK2,EPB41L4B,BGN,POLR3...
# 4469  TIMP3,COL11A1,MFGE8,GSTA4,SPRED2,IL6ST,LAPTM5,...
# 3262  PCK1,SPRY1,TIMP2,TMOD3,HSPA4,SCG5,PLK2,CPE,TXN...
#
#                                  allsignatures_combined SIDER_link
# 5200  LAPTM5,HSPA6,PPAP2A,CKM,IFI27,SLC6A8,CPD,CPE,P...       none
# 3511  HSPA2,ADD3,UBE2J1,ACTG2,GPAA1,IFI27,FBXO11,TRD...       none
# 3547  HIST1H4C,SSPN,PGAP3,PPAP2C,UBE2J1,CKB,JUN,WLS,...       none
# 4931  TRAPPC2L,HSPA2,TCTN1,PPAP2B,FKBP11,HIST1H4J,SC...       none
# 4559  ELANE,ADD3,CPM,ACTG2,RAB4A,SCG5,WLS,NDUFB2,TXN...       none
# ...                                                 ...        ...
# 3923  C17ORF81,PPAP2C,STK10,FBXO11,RAPGEF5,MFAP5,ANP...       none
# 5989  TAP1,ADD3,CPM,ACTG2,ZNF814,STK10,HSPA8,SPON1,L...       none
# 4509  HIST1H4C,ADD3,FKBP10,RAB4A,PCCB,HOXC10,HSPA8,L...       none
# 4469  ADD3,MFGE8,PSPC1,PCSK5,N4BP2L1,TPBG,MFAP5,MFAP...       none
# 3262  HSPA2,TM7SF3,PDGFC,HSPA4,IFI27,HSPA8,CPE,TXNDC...       none
#
# [3344 rows x 18 columns]

# %%
GSEA_overlap_sig_hs_sorted_drug.drop_duplicates(subset = ["Drug"], inplace=True)

# %%
GSEA_overlap_sig_hs_sorted_rank = GSEA_overlap_sig_hs_sorted_drug.sort_values(['Within Species Rank', 'Jaccard Score', 'P value'], axis=0, ascending=False, inplace=False)

# %%
GSEA_overlap_sig_hs_sorted_rank
# Out:
#                       Database                    Method          Drug  \
# 2721     L1000_CPC011_VCAP_24H  Characteristic direction   Vincristine
# 2720    L1000_CPC006_HCC515_6H  Characteristic direction  Fluspirilene
# 3018     L1000_HOG003_A549_24H  Characteristic direction    Idarubicin
# 2925       L1000_CPC012_PC3_6H  Characteristic direction     Topotecan
# 2835  L1000_CPC006_NCIH2073_6H  Characteristic direction    NSC-632839
# ...                        ...                       ...           ...
# 5941     L1000_CPC001_HA1E_24H  Characteristic direction         TTNPB
# 5984      L1000_CPC006_HT29_6H  Characteristic direction        PF-750
# 5948      L1000_CPC001_VCAP_6H  Characteristic direction   Carpindolol
# 5950       L1000_CPC002_PC3_6H  Characteristic direction   BAY-11-7821
# 6033    L1000_CPC020_HCC515_6H  Characteristic direction    Mefloquine
#
#            Species Tissue or Cell Line     Study     Dose  Time  \
# 2721  Homo sapiens                VCAP  In Vitro    10 uM  24hr
# 2720  Homo sapiens              HCC515  In Vitro  4.21 uM   6hr
# 3018  Homo sapiens                A549  In Vitro  3.33 uM  24hr
# 2925  Homo sapiens                 PC3  In Vitro    10 uM   6hr
# 2835  Homo sapiens            NCIH2073  In Vitro    10 uM   6hr
# ...            ...                 ...       ...      ...   ...
# 5941  Homo sapiens                HA1E  In Vitro    10 uM  24hr
# 5984  Homo sapiens                HT29  In Vitro    80 uM   6hr
# 5948  Homo sapiens                VCAP  In Vitro    10 uM   6hr
# 5950  Homo sapiens                 PC3  In Vitro    10 uM   6hr
# 6033  Homo sapiens              HCC515  In Vitro    10 uM   6hr
#
#       Jaccard Score  Odds Ratio       P value  Within Species Rank  \
# 2721   1.387779e-17   38.118083  1.690898e-34             0.999929
# 2720   1.387779e-17   62.914719  6.708412e-54             0.999929
# 3018   6.938894e-18   13.222827  3.840709e-07             0.974530
# 2925   6.938894e-18   15.074806  2.559920e-08             0.974530
# 2835   6.938894e-18   12.266379  6.027223e-09             0.974530
# ...             ...         ...           ...                  ...
# 5941   2.602085e-18   26.887135  4.392864e-20             0.535800
# 5984   2.602085e-18   28.000221  2.809446e-23             0.535800
# 5948   2.602085e-18   32.277407  1.607416e-24             0.535800
# 5950   2.602085e-18   28.701622  2.222065e-26             0.535800
# 6033   2.602085e-18   38.242357  1.222778e-36             0.535800
#
#                                                 Overlap  nOverlap  \
# 2721  CRABP2, POSTN, FOXM1, HOPX, CEACAM5, CEACAM6, ...        30
# 2720  SERPINB3, ISG15, BLNK, CYP4B1, SCEL, TMPRSS11D...        41
# 3018  SERPINE1, ISG15, CEACAM6, COL11A1, ASPN, COL5A...         8
# 2925  THBS2, INHBA, COL3A1, ASPN, SPARC, COL1A2, MAG...         9
# 2835  MFAP2, INHBA, MMP11, ITGA6, SERPINE1, SPARC, R...        11
# ...                                                 ...       ...
# 5941  MYH11, PPP1R3C, SERPINB2, MAL, SCEL, CEACAM1, ...        19
# 5984  SERPINB2, PPP1R3C, NUCB2, CEACAM5, SCNN1A, IL1...        22
# 5948  TGM1, KLK11, TTC9, CD24, SERPINB3, MMP10, SCEL...        22
# 5950  PPP1R3C, MALL, SERPINB1, BLNK, ABLIM1, SERPINB...        25
# 6033  TGM3, KLK13, KLK11, CRNN, MFAP2, PPP1R3C, GPX3...        32
#
#                                        allsignatures_up  \
# 2721  HEPH,TIMP3,MMP19,KIAA0182,PLK1,KIAA0226L,TSPAN...
# 2720  TGM2,TRIM14,MIA,IFI27,FBXO11,DENND1B,SRSF11,SR...
# 3018  DHDDS,FAM198B,ADD3,TSPAN4,CKB,GSTA4,ALDH7A1,ER...
# 2925  CD38,ADD3,CPM,TUSC3,THBS2,SSFA2,EPHX2,UQCRQ,CH...
# 2835  PMAIP1,PHGDH,SFTPC,CHORDC1,HSPA8,CHN1,N4BP2L2,...
# ...                                                 ...
# 5941  HSPA2,ZDHHC11,PPAP2A,MYH11,PSMF1,PLK2,PCSK6,FN...
# 5984  PCK2,MYH10,CD52,SCGB1D2,TRIM14,TIMP1,FKBP11,TG...
# 5948  TGM1,KLK6,GSTA4,IDI1,PBX3,KLK11,CPE,DHCR7,MARC...
# 5950  PCK2,HSPA2,PMAIP1,PPAP2B,HSPA5,FKBP11,NRCAM,HS...
# 6033  TRDV3,TGM3,FXYD2,FXYD3,PPAP2A,TRIM16,HRSP12,KL...
#
#                                      allsignatures_down  \
# 2721  PTGS1,ADD3,LRPPRC,PCCB,GALC,CD34,CLDN10,BGN,TX...
# 2720  CD38,ADD3,PPAP2B,KIAA0182,FAM3C,CPE,BGN,ADCK3,...
# 3018  PTGS2,HSF2,PPAP2B,TRIM16,IDI1,HSPA8,PRPF4B,CRY...
# 2925  NGDN,MUDENG,PLK1,HSPA8,SAV1,ZFAND6,N4BP2L2,RUF...
# 2835  FKBP14,PLK1,NQO1,DHTKD1,MFAP5,GPM6A,TNNC1,DUSP...
# ...                                                 ...
# 5941  FXYD6,SMARCC1,FXYD3,TUSC3,STK10,N4BP2L1,FGL2,S...
# 5984  HSPA2,TGM2,FXYD5,TSPAN4,PPP2R3C,STK10,PTGS1,NQ...
# 5948  PCK2,HIST1H4C,ELANE,PCK1,PCCB,PPP2R3C,IFI27,SL...
# 5950  HIST1H4C,PTGS1,SCGB1D2,FXYD2,SFTPB,SSX1,NDUFB6...
# 6033  PTGS2,RPN2,ADD3,COL11A1,HSPA5,SCG5,HSPA8,HBB,T...
#
#                                  allsignatures_combined  \
# 2721  ELANE,ADD3,HRSP12,SLC6A8,CD34,STEAP3,CD36,TXND...
# 2720  CD38,ADD3,PPAP2B,IFI27,FBXO11,CPE,BGN,HIPK2,MF...
# 3018  HSPA2,ELANE,HSF2,ADD3,PPAP2B,FBXO34,CKB,WLS,ER...
# 2925  CD38,ADD3,CPM,HSPA8,SSFA2,UQCRQ,CHN2,DDIT3,N4B...
# 2835  FKBP14,PMAIP1,HSPA6,AP1M2,HSPA8,CHN1,N4BP2L2,G...
# ...                                                 ...
# 5941  HSPA2,SMARCC1,ZDHHC11,ACTG2,STK10,SLC6A8,PCSK6...
# 5984  HSPA2,FKBP11,STK10,MLEC,PTGS1,IL6ST,MYL2,MFAP2...
# 5948  HIST1H4C,RBCK1,ELANE,KIAA0564,PPAP2B,PCCB,IFI2...
# 5950  HIST1H4C,HSPA2,PMAIP1,PPAP2B,HSPA5,FKBP11,GNPT...
# 6033  ADD3,HSPA6,PPAP2A,HRSP12,SCG5,HSPA8,RPN2,TXNDC...
#
#                                  SIDER_link
# 2721  http://sideeffects.embl.de/drugs/5978
# 2720                                   none
# 3018  http://sideeffects.embl.de/drugs/3685
# 2925  http://sideeffects.embl.de/drugs/5515
# 2835                                   none
# ...                                     ...
# 5941                                   none
# 5984                                   none
# 5948                                   none
# 5950                                   none
# 6033                                   none
#
# [1526 rows x 18 columns]

# %%
GSEA_overlap_sig_hs_sorted_rank.reset_index(inplace=True,drop=True)

# %%
GSEA_overlap_sig_hs_sorted_rank
# Out:
#                       Database                    Method          Drug  \
# 0        L1000_CPC011_VCAP_24H  Characteristic direction   Vincristine
# 1       L1000_CPC006_HCC515_6H  Characteristic direction  Fluspirilene
# 2        L1000_HOG003_A549_24H  Characteristic direction    Idarubicin
# 3          L1000_CPC012_PC3_6H  Characteristic direction     Topotecan
# 4     L1000_CPC006_NCIH2073_6H  Characteristic direction    NSC-632839
# ...                        ...                       ...           ...
# 1521     L1000_CPC001_HA1E_24H  Characteristic direction         TTNPB
# 1522      L1000_CPC006_HT29_6H  Characteristic direction        PF-750
# 1523      L1000_CPC001_VCAP_6H  Characteristic direction   Carpindolol
# 1524       L1000_CPC002_PC3_6H  Characteristic direction   BAY-11-7821
# 1525    L1000_CPC020_HCC515_6H  Characteristic direction    Mefloquine
#
#            Species Tissue or Cell Line     Study     Dose  Time  \
# 0     Homo sapiens                VCAP  In Vitro    10 uM  24hr
# 1     Homo sapiens              HCC515  In Vitro  4.21 uM   6hr
# 2     Homo sapiens                A549  In Vitro  3.33 uM  24hr
# 3     Homo sapiens                 PC3  In Vitro    10 uM   6hr
# 4     Homo sapiens            NCIH2073  In Vitro    10 uM   6hr
# ...            ...                 ...       ...      ...   ...
# 1521  Homo sapiens                HA1E  In Vitro    10 uM  24hr
# 1522  Homo sapiens                HT29  In Vitro    80 uM   6hr
# 1523  Homo sapiens                VCAP  In Vitro    10 uM   6hr
# 1524  Homo sapiens                 PC3  In Vitro    10 uM   6hr
# 1525  Homo sapiens              HCC515  In Vitro    10 uM   6hr
#
#       Jaccard Score  Odds Ratio       P value  Within Species Rank  \
# 0      1.387779e-17   38.118083  1.690898e-34             0.999929
# 1      1.387779e-17   62.914719  6.708412e-54             0.999929
# 2      6.938894e-18   13.222827  3.840709e-07             0.974530
# 3      6.938894e-18   15.074806  2.559920e-08             0.974530
# 4      6.938894e-18   12.266379  6.027223e-09             0.974530
# ...             ...         ...           ...                  ...
# 1521   2.602085e-18   26.887135  4.392864e-20             0.535800
# 1522   2.602085e-18   28.000221  2.809446e-23             0.535800
# 1523   2.602085e-18   32.277407  1.607416e-24             0.535800
# 1524   2.602085e-18   28.701622  2.222065e-26             0.535800
# 1525   2.602085e-18   38.242357  1.222778e-36             0.535800
#
#                                                 Overlap  nOverlap  \
# 0     CRABP2, POSTN, FOXM1, HOPX, CEACAM5, CEACAM6, ...        30
# 1     SERPINB3, ISG15, BLNK, CYP4B1, SCEL, TMPRSS11D...        41
# 2     SERPINE1, ISG15, CEACAM6, COL11A1, ASPN, COL5A...         8
# 3     THBS2, INHBA, COL3A1, ASPN, SPARC, COL1A2, MAG...         9
# 4     MFAP2, INHBA, MMP11, ITGA6, SERPINE1, SPARC, R...        11
# ...                                                 ...       ...
# 1521  MYH11, PPP1R3C, SERPINB2, MAL, SCEL, CEACAM1, ...        19
# 1522  SERPINB2, PPP1R3C, NUCB2, CEACAM5, SCNN1A, IL1...        22
# 1523  TGM1, KLK11, TTC9, CD24, SERPINB3, MMP10, SCEL...        22
# 1524  PPP1R3C, MALL, SERPINB1, BLNK, ABLIM1, SERPINB...        25
# 1525  TGM3, KLK13, KLK11, CRNN, MFAP2, PPP1R3C, GPX3...        32
#
#                                        allsignatures_up  \
# 0     HEPH,TIMP3,MMP19,KIAA0182,PLK1,KIAA0226L,TSPAN...
# 1     TGM2,TRIM14,MIA,IFI27,FBXO11,DENND1B,SRSF11,SR...
# 2     DHDDS,FAM198B,ADD3,TSPAN4,CKB,GSTA4,ALDH7A1,ER...
# 3     CD38,ADD3,CPM,TUSC3,THBS2,SSFA2,EPHX2,UQCRQ,CH...
# 4     PMAIP1,PHGDH,SFTPC,CHORDC1,HSPA8,CHN1,N4BP2L2,...
# ...                                                 ...
# 1521  HSPA2,ZDHHC11,PPAP2A,MYH11,PSMF1,PLK2,PCSK6,FN...
# 1522  PCK2,MYH10,CD52,SCGB1D2,TRIM14,TIMP1,FKBP11,TG...
# 1523  TGM1,KLK6,GSTA4,IDI1,PBX3,KLK11,CPE,DHCR7,MARC...
# 1524  PCK2,HSPA2,PMAIP1,PPAP2B,HSPA5,FKBP11,NRCAM,HS...
# 1525  TRDV3,TGM3,FXYD2,FXYD3,PPAP2A,TRIM16,HRSP12,KL...
#
#                                      allsignatures_down  \
# 0     PTGS1,ADD3,LRPPRC,PCCB,GALC,CD34,CLDN10,BGN,TX...
# 1     CD38,ADD3,PPAP2B,KIAA0182,FAM3C,CPE,BGN,ADCK3,...
# 2     PTGS2,HSF2,PPAP2B,TRIM16,IDI1,HSPA8,PRPF4B,CRY...
# 3     NGDN,MUDENG,PLK1,HSPA8,SAV1,ZFAND6,N4BP2L2,RUF...
# 4     FKBP14,PLK1,NQO1,DHTKD1,MFAP5,GPM6A,TNNC1,DUSP...
# ...                                                 ...
# 1521  FXYD6,SMARCC1,FXYD3,TUSC3,STK10,N4BP2L1,FGL2,S...
# 1522  HSPA2,TGM2,FXYD5,TSPAN4,PPP2R3C,STK10,PTGS1,NQ...
# 1523  PCK2,HIST1H4C,ELANE,PCK1,PCCB,PPP2R3C,IFI27,SL...
# 1524  HIST1H4C,PTGS1,SCGB1D2,FXYD2,SFTPB,SSX1,NDUFB6...
# 1525  PTGS2,RPN2,ADD3,COL11A1,HSPA5,SCG5,HSPA8,HBB,T...
#
#                                  allsignatures_combined  \
# 0     ELANE,ADD3,HRSP12,SLC6A8,CD34,STEAP3,CD36,TXND...
# 1     CD38,ADD3,PPAP2B,IFI27,FBXO11,CPE,BGN,HIPK2,MF...
# 2     HSPA2,ELANE,HSF2,ADD3,PPAP2B,FBXO34,CKB,WLS,ER...
# 3     CD38,ADD3,CPM,HSPA8,SSFA2,UQCRQ,CHN2,DDIT3,N4B...
# 4     FKBP14,PMAIP1,HSPA6,AP1M2,HSPA8,CHN1,N4BP2L2,G...
# ...                                                 ...
# 1521  HSPA2,SMARCC1,ZDHHC11,ACTG2,STK10,SLC6A8,PCSK6...
# 1522  HSPA2,FKBP11,STK10,MLEC,PTGS1,IL6ST,MYL2,MFAP2...
# 1523  HIST1H4C,RBCK1,ELANE,KIAA0564,PPAP2B,PCCB,IFI2...
# 1524  HIST1H4C,HSPA2,PMAIP1,PPAP2B,HSPA5,FKBP11,GNPT...
# 1525  ADD3,HSPA6,PPAP2A,HRSP12,SCG5,HSPA8,RPN2,TXNDC...
#
#                                  SIDER_link
# 0     http://sideeffects.embl.de/drugs/5978
# 1                                      none
# 2     http://sideeffects.embl.de/drugs/3685
# 3     http://sideeffects.embl.de/drugs/5515
# 4                                      none
# ...                                     ...
# 1521                                   none
# 1522                                   none
# 1523                                   none
# 1524                                   none
# 1525                                   none
#
# [1526 rows x 18 columns]

# %%
GSEA_overlap_filt_results = GSEA_overlap_sig_hs_sorted_rank.copy()

# %% [markdown]
# Filtered result dfs used in the subsequent steps:
# - GSEA_net_meta_filt_results
# - GSEA_net_500_filt_results
# - GSEA_overlap_filt_results

# %%
GSEA_net_meta_filt_results.head()
# Out:
#            Drug       Species                 Tissue  \
# 0  Methotrexate  Homo sapiens  cardiovascular system
# 1   Doxorubicin  Homo sapiens          immune system
# 2   Fulvestrant  Homo sapiens                 breast
# 3    Antibiotic  Homo sapiens             integument
# 4     Tamoxifen  Homo sapiens               pancreas
#
#                                              Dataset  \
# 0                                           GSE32008
# 1                                           GSE79413
# 2  GSE74391, GSE22533, GSE85536, E-GEOD-14986, E-...
# 3         GSE43080, GSE37994, E-GEOD-13487, GSE39091
# 4                                           GSE55999
#
#                  DEG_method  \
# 0  Characteristic direction
# 1  Characteristic direction
# 2  Characteristic direction
# 3  Characteristic direction
# 4  Characteristic direction
#
#                                             Genes_up  \
# 0  C3,DDIT3,AREG,SAT1,IL1RL1,CXCL8,TNFAIP3,ANKRA2...
# 1  PCDH8,FDXR,GAS6-AS1,TRIM22,MUC19,DDB2,WDR63,GP...
# 2  S100P,TSPAN1,ID1,ID2,ID3,SOCS2,TM4SF1,SYBU,C19...
# 3  C3,ABCA12,IFI44L,GPR1,GFI1,TCN1,CFB,MGAM,DUOX2...
# 4  CDKN1C,LOXL4,GDF15,LCN2,SPNS2,PTGDS,APOD,GJB2,...
#
#                                           Genes_down  \
# 0  PLK1,HIST1H2BM,PRC1,BUB1,DEPDC1,KIF20A,TOP2A,C...
# 1  KIF20A,DLGAP5,CDC20,CCNB1,CENPE,NDC80,FAM83D,N...
# 2  FGFBP2,CDCA5,CENPF,CDC20,RBM24,TACC3,SLC18B1,R...
# 3  HYLS1,HMMR,DLGAP5,KIF14,DEPDC1,CDC45,BDKRB1,SP...
# 4  SLC25A18,UPK1B,MT1E,SOX21,CDS1,MXRA5,MT2A,FOXQ...
#
#                                       Genes_combined  \
# 0  C3,PLK1,DDIT3,HIST1H2BM,AREG,PRC1,SAT1,BUB1,IL...
# 1  PCDH8,KIF20A,FDXR,DLGAP5,GAS6-AS1,CDC20,TRIM22...
# 2  CEACAM6,FGFBP2,S100P,TSPAN1,ID1,PDZK1,STC2,ID2...
# 3  C3,ABCA12,HYLS1,HMMR,DLGAP5,KIF14,DEPDC1,CDC45...
# 4  CDKN1C,SLC25A18,LOXL4,UPK1B,GDF15,MT1E,LCN2,SO...
#
#                                 SIDER_link   Z_score      Rank        Pvalue  \
# 0    http://sideeffects.embl.de/drugs/4112 -7.525615  1.000000  2.623639e-14
# 1    http://sideeffects.embl.de/drugs/1690 -7.265339  0.999198  1.860516e-13
# 2  http://sideeffects.embl.de/drugs/104741 -7.211470  0.998396  2.767545e-13
# 3                                     none -6.876405  0.997594  3.069100e-12
# 4    http://sideeffects.embl.de/drugs/5376 -6.833129  0.996792  4.154103e-12
#
#                     All_Drug_Gene_Input_Gene_Overlap  \
# 0  CXCL8,CEACAM1,MXD1,MMP10,EHF,PPP1R3C,DUSP5,HSP...
# 1  PLAC8,SERPINE1,CDC20,CEP55,TOP2A,PRC1,NUSAP1,D...
# 2  S100P,KLK11,IGFBP3,CYP4B1,CD24,KAT2B,PSCA,TMEM...
# 3  IGFBP3,IL1RN,MMP10,SERPINB4,HSPB8,S100P,CST1,T...
# 4  LCN2,IGFBP3,TMPRSS2,CLIC3,MAL,DUSP5,PRSS3,PTHL...
#
#              Drug_gene_input_gene_overlap_in_network  \
# 0  CEACAM1,MXD1,MMP10,EHF,PPP1R3C,DUSP5,HSPB8,PRC...
# 1  PLAC8,SERPINE1,CDC20,CEP55,TOP2A,PRC1,NUSAP1,D...
# 2  S100P,KLK11,IGFBP3,CYP4B1,CD24,KAT2B,PSCA,TMEM...
# 3  IGFBP3,IL1RN,MMP10,SERPINB4,HSPB8,S100P,TMEM45...
# 4  LCN2,IGFBP3,TMPRSS2,CLIC3,MAL,DUSP5,PRSS3,PTHL...
#
#          Drug_genes_directly_connected_to_input_gene  \
# 0  C3,AREG,SAT1,IL1RL1,TNFAIP3,IL7R,ARG2,ATP6V0D2...
# 1  GPR87,CDKN1A,ANK1,SCN4B,TNFRSF21,ASCC3,SULF2,A...
# 2  TSPAN1,ID1,ID2,SOCS2,TM4SF1,NDRG1,ANXA3,AMIGO2...
# 3  C3,CFB,MGAM,KDR,ALPK2,HSPB3,DLX5,KMO,DKK1,RIMS...
# 4  CDKN1C,LOXL4,PTGDS,APOD,S100A9,RASL11B,HEYL,BG...
#
#          Input_genes_directly_connected_to_drug_gene  \
# 0  COL1A1,ECT2,CKS1B,RFC4,PLAU,CDK1,COL1A2,CEP55,...
# 1  COL1A1,ECT2,CKS1B,RFC4,PLAU,CDK1,COL1A2,CEP55,...
# 2  COL1A1,ECT2,CKS1B,RFC4,MFAP2,PLAU,COL1A2,CEP55...
# 3  COL1A1,ECT2,CKS1B,MFAP2,PLAU,CDK1,COL1A2,CEP55...
# 4  COL1A1,ECT2,CKS1B,RFC4,MFAP2,PLAU,CDK1,COL1A2,...
#
#                     Drug_network_name
# 0  Methotrexate_cardiovascular system
# 1           Doxorubicin_immune system
# 2                  Fulvestrant_breast
# 3               Antibiotic_integument
# 4                  Tamoxifen_pancreas

# %%
GSEA_net_500_filt_results.head()
# Out:
#                                 Drug       Species Tissue     Study  Time  \
# 0  Transforming growth factor beta 1  Homo sapiens  liver  In Vitro   2hr
# 1                    Diethyl maleate  Homo sapiens  liver  In Vitro   8hr
# 2                      Phenobarbital  Homo sapiens  liver  In Vitro   8hr
# 3                           Pemoline  Homo sapiens  liver  In Vitro   8hr
# 4                          Tiopronin  Homo sapiens  liver  In Vitro  24hr
#
#       Dose  Control sample size  Treatment sample size Database Method  ...  \
# 0  2 ng/mL                    2                      2  TGGATEs  limma  ...
# 1    60 uM                    2                      2  TGGATEs  limma  ...
# 2  2000 uM                    2                      2  TGGATEs  limma  ...
# 3    15 uM                    2                      2  TGGATEs  limma  ...
# 4  2000 uM                    2                      2  TGGATEs  limma  ...
#
#    ADRrank_mod26 ADRscore_mod27 ADRrank_mod27 ADRscore_mod28 ADRrank_mod28  \
# 0            NaN            NaN           NaN            NaN           NaN
# 1            NaN            NaN           NaN            NaN           NaN
# 2            NaN            NaN           NaN            NaN           NaN
# 3            NaN            NaN           NaN            NaN           NaN
# 4            NaN            NaN           NaN            NaN           NaN
#
#    ADRscore_mod29  ADRrank_mod29 hepatotox_complete_signature  \
# 0             NaN            NaN                          NaN
# 1             NaN            NaN                          NaN
# 2             NaN            NaN                          NaN
# 3             NaN            NaN                          NaN
# 4             NaN            NaN                          NaN
#
#   hepatotox_complete_signature_rank                             SIDER_link
# 0                              none                                   none
# 1                              none                                   none
# 2                              none  http://sideeffects.embl.de/drugs/4763
# 3                              none                                   none
# 4                              none                                   none
#
# [5 rows x 83 columns]

# %%
GSEA_overlap_filt_results.head()
# Out:
#                    Database                    Method          Drug  \
# 0     L1000_CPC011_VCAP_24H  Characteristic direction   Vincristine
# 1    L1000_CPC006_HCC515_6H  Characteristic direction  Fluspirilene
# 2     L1000_HOG003_A549_24H  Characteristic direction    Idarubicin
# 3       L1000_CPC012_PC3_6H  Characteristic direction     Topotecan
# 4  L1000_CPC006_NCIH2073_6H  Characteristic direction    NSC-632839
#
#         Species Tissue or Cell Line     Study     Dose  Time  Jaccard Score  \
# 0  Homo sapiens                VCAP  In Vitro    10 uM  24hr   1.387779e-17
# 1  Homo sapiens              HCC515  In Vitro  4.21 uM   6hr   1.387779e-17
# 2  Homo sapiens                A549  In Vitro  3.33 uM  24hr   6.938894e-18
# 3  Homo sapiens                 PC3  In Vitro    10 uM   6hr   6.938894e-18
# 4  Homo sapiens            NCIH2073  In Vitro    10 uM   6hr   6.938894e-18
#
#    Odds Ratio       P value  Within Species Rank  \
# 0   38.118083  1.690898e-34             0.999929
# 1   62.914719  6.708412e-54             0.999929
# 2   13.222827  3.840709e-07             0.974530
# 3   15.074806  2.559920e-08             0.974530
# 4   12.266379  6.027223e-09             0.974530
#
#                                              Overlap  nOverlap  \
# 0  CRABP2, POSTN, FOXM1, HOPX, CEACAM5, CEACAM6, ...        30
# 1  SERPINB3, ISG15, BLNK, CYP4B1, SCEL, TMPRSS11D...        41
# 2  SERPINE1, ISG15, CEACAM6, COL11A1, ASPN, COL5A...         8
# 3  THBS2, INHBA, COL3A1, ASPN, SPARC, COL1A2, MAG...         9
# 4  MFAP2, INHBA, MMP11, ITGA6, SERPINE1, SPARC, R...        11
#
#                                     allsignatures_up  \
# 0  HEPH,TIMP3,MMP19,KIAA0182,PLK1,KIAA0226L,TSPAN...
# 1  TGM2,TRIM14,MIA,IFI27,FBXO11,DENND1B,SRSF11,SR...
# 2  DHDDS,FAM198B,ADD3,TSPAN4,CKB,GSTA4,ALDH7A1,ER...
# 3  CD38,ADD3,CPM,TUSC3,THBS2,SSFA2,EPHX2,UQCRQ,CH...
# 4  PMAIP1,PHGDH,SFTPC,CHORDC1,HSPA8,CHN1,N4BP2L2,...
#
#                                   allsignatures_down  \
# 0  PTGS1,ADD3,LRPPRC,PCCB,GALC,CD34,CLDN10,BGN,TX...
# 1  CD38,ADD3,PPAP2B,KIAA0182,FAM3C,CPE,BGN,ADCK3,...
# 2  PTGS2,HSF2,PPAP2B,TRIM16,IDI1,HSPA8,PRPF4B,CRY...
# 3  NGDN,MUDENG,PLK1,HSPA8,SAV1,ZFAND6,N4BP2L2,RUF...
# 4  FKBP14,PLK1,NQO1,DHTKD1,MFAP5,GPM6A,TNNC1,DUSP...
#
#                               allsignatures_combined  \
# 0  ELANE,ADD3,HRSP12,SLC6A8,CD34,STEAP3,CD36,TXND...
# 1  CD38,ADD3,PPAP2B,IFI27,FBXO11,CPE,BGN,HIPK2,MF...
# 2  HSPA2,ELANE,HSF2,ADD3,PPAP2B,FBXO34,CKB,WLS,ER...
# 3  CD38,ADD3,CPM,HSPA8,SSFA2,UQCRQ,CHN2,DDIT3,N4B...
# 4  FKBP14,PMAIP1,HSPA6,AP1M2,HSPA8,CHN1,N4BP2L2,G...
#
#                               SIDER_link
# 0  http://sideeffects.embl.de/drugs/5978
# 1                                   none
# 2  http://sideeffects.embl.de/drugs/3685
# 3  http://sideeffects.embl.de/drugs/5515
# 4                                   none

# %%
GSEA_overlap_results = GSEA_overlap_filt_results.copy()
GSEA_net_500_results = GSEA_net_500_filt_results[['Drug', 'Species', 'Tissue']].copy()
GSEA_net_meta_results = GSEA_net_meta_filt_results[['Drug',	'Species', 'Tissue', 'Dataset']].copy()

# %%
# GSEA_overlap_results = GSEA_overlap_results.add_suffix('_frm_G_ovrlp')

GSEA_net_500_results = GSEA_net_500_results.add_suffix('_frm_G_nt500')
GSEA_net_meta_results = GSEA_net_meta_results.add_suffix('_frm_G_ntmeta')

# %%
GSEA_overlap_results.head()
# Out:
#                    Database                    Method          Drug  \
# 0     L1000_CPC011_VCAP_24H  Characteristic direction   Vincristine
# 1    L1000_CPC006_HCC515_6H  Characteristic direction  Fluspirilene
# 2     L1000_HOG003_A549_24H  Characteristic direction    Idarubicin
# 3       L1000_CPC012_PC3_6H  Characteristic direction     Topotecan
# 4  L1000_CPC006_NCIH2073_6H  Characteristic direction    NSC-632839
#
#         Species Tissue or Cell Line     Study     Dose  Time  Jaccard Score  \
# 0  Homo sapiens                VCAP  In Vitro    10 uM  24hr   1.387779e-17
# 1  Homo sapiens              HCC515  In Vitro  4.21 uM   6hr   1.387779e-17
# 2  Homo sapiens                A549  In Vitro  3.33 uM  24hr   6.938894e-18
# 3  Homo sapiens                 PC3  In Vitro    10 uM   6hr   6.938894e-18
# 4  Homo sapiens            NCIH2073  In Vitro    10 uM   6hr   6.938894e-18
#
#    Odds Ratio       P value  Within Species Rank  \
# 0   38.118083  1.690898e-34             0.999929
# 1   62.914719  6.708412e-54             0.999929
# 2   13.222827  3.840709e-07             0.974530
# 3   15.074806  2.559920e-08             0.974530
# 4   12.266379  6.027223e-09             0.974530
#
#                                              Overlap  nOverlap  \
# 0  CRABP2, POSTN, FOXM1, HOPX, CEACAM5, CEACAM6, ...        30
# 1  SERPINB3, ISG15, BLNK, CYP4B1, SCEL, TMPRSS11D...        41
# 2  SERPINE1, ISG15, CEACAM6, COL11A1, ASPN, COL5A...         8
# 3  THBS2, INHBA, COL3A1, ASPN, SPARC, COL1A2, MAG...         9
# 4  MFAP2, INHBA, MMP11, ITGA6, SERPINE1, SPARC, R...        11
#
#                                     allsignatures_up  \
# 0  HEPH,TIMP3,MMP19,KIAA0182,PLK1,KIAA0226L,TSPAN...
# 1  TGM2,TRIM14,MIA,IFI27,FBXO11,DENND1B,SRSF11,SR...
# 2  DHDDS,FAM198B,ADD3,TSPAN4,CKB,GSTA4,ALDH7A1,ER...
# 3  CD38,ADD3,CPM,TUSC3,THBS2,SSFA2,EPHX2,UQCRQ,CH...
# 4  PMAIP1,PHGDH,SFTPC,CHORDC1,HSPA8,CHN1,N4BP2L2,...
#
#                                   allsignatures_down  \
# 0  PTGS1,ADD3,LRPPRC,PCCB,GALC,CD34,CLDN10,BGN,TX...
# 1  CD38,ADD3,PPAP2B,KIAA0182,FAM3C,CPE,BGN,ADCK3,...
# 2  PTGS2,HSF2,PPAP2B,TRIM16,IDI1,HSPA8,PRPF4B,CRY...
# 3  NGDN,MUDENG,PLK1,HSPA8,SAV1,ZFAND6,N4BP2L2,RUF...
# 4  FKBP14,PLK1,NQO1,DHTKD1,MFAP5,GPM6A,TNNC1,DUSP...
#
#                               allsignatures_combined  \
# 0  ELANE,ADD3,HRSP12,SLC6A8,CD34,STEAP3,CD36,TXND...
# 1  CD38,ADD3,PPAP2B,IFI27,FBXO11,CPE,BGN,HIPK2,MF...
# 2  HSPA2,ELANE,HSF2,ADD3,PPAP2B,FBXO34,CKB,WLS,ER...
# 3  CD38,ADD3,CPM,HSPA8,SSFA2,UQCRQ,CHN2,DDIT3,N4B...
# 4  FKBP14,PMAIP1,HSPA6,AP1M2,HSPA8,CHN1,N4BP2L2,G...
#
#                               SIDER_link
# 0  http://sideeffects.embl.de/drugs/5978
# 1                                   none
# 2  http://sideeffects.embl.de/drugs/3685
# 3  http://sideeffects.embl.de/drugs/5515
# 4                                   none

# %%
GSEA_net_500_results.head()
# Out:
#                     Drug_frm_G_nt500 Species_frm_G_nt500 Tissue_frm_G_nt500
# 0  Transforming growth factor beta 1        Homo sapiens              liver
# 1                    Diethyl maleate        Homo sapiens              liver
# 2                      Phenobarbital        Homo sapiens              liver
# 3                           Pemoline        Homo sapiens              liver
# 4                          Tiopronin        Homo sapiens              liver

# %%
GSEA_net_meta_results.head()
# Out:
#   Drug_frm_G_ntmeta Species_frm_G_ntmeta    Tissue_frm_G_ntmeta  \
# 0      Methotrexate         Homo sapiens  cardiovascular system
# 1       Doxorubicin         Homo sapiens          immune system
# 2       Fulvestrant         Homo sapiens                 breast
# 3        Antibiotic         Homo sapiens             integument
# 4         Tamoxifen         Homo sapiens               pancreas
#
#                                 Dataset_frm_G_ntmeta
# 0                                           GSE32008
# 1                                           GSE79413
# 2  GSE74391, GSE22533, GSE85536, E-GEOD-14986, E-...
# 3         GSE43080, GSE37994, E-GEOD-13487, GSE39091
# 4                                           GSE55999

# %%
GSEA_common_network_drugs = pd.merge(left=GSEA_net_500_results, right=GSEA_net_meta_results, how='inner', left_on='Drug_frm_G_nt500', right_on='Drug_frm_G_ntmeta')

# %%
GSEA_common_network_drugs
# Out:
#     Drug_frm_G_nt500 Species_frm_G_nt500 Tissue_frm_G_nt500 Drug_frm_G_ntmeta  \
# 0      Phenobarbital        Homo sapiens              liver     Phenobarbital
# 1           Pemoline        Homo sapiens              liver          Pemoline
# 2          Tiopronin        Homo sapiens              liver         Tiopronin
# 3   Propylthiouracil        Homo sapiens              liver  Propylthiouracil
# 4   Cyclophosphamide        Homo sapiens              liver  Cyclophosphamide
# 5        Perhexiline        Homo sapiens              liver       Perhexiline
# 6       Benziodarone        Homo sapiens              liver      Benziodarone
# 7         Ethambutol        Homo sapiens              liver        Ethambutol
# 8         Diclofenac        Homo sapiens              liver        Diclofenac
# 9            Bucetin        Homo sapiens              liver           Bucetin
# 10    Nitrofurantoin        Homo sapiens              liver    Nitrofurantoin
# 11       Haloperidol        Homo sapiens              liver       Haloperidol
#
#    Species_frm_G_ntmeta Tissue_frm_G_ntmeta Dataset_frm_G_ntmeta
# 0          Homo sapiens               liver    TG-GATEs_in_vitro
# 1          Homo sapiens               liver    TG-GATEs_in_vitro
# 2          Homo sapiens               liver    TG-GATEs_in_vitro
# 3          Homo sapiens               liver    TG-GATEs_in_vitro
# 4          Homo sapiens   urogenital system             GSE42913
# 5          Homo sapiens               liver    TG-GATEs_in_vitro
# 6          Homo sapiens               liver    TG-GATEs_in_vitro
# 7          Homo sapiens               liver    TG-GATEs_in_vitro
# 8          Homo sapiens               ovary             GSE45052
# 9          Homo sapiens               liver    TG-GATEs_in_vitro
# 10         Homo sapiens               liver    TG-GATEs_in_vitro
# 11         Homo sapiens               liver    TG-GATEs_in_vitro

# %%
GSEA_common_drugs_temp = pd.merge(left=GSEA_overlap_results, right=GSEA_common_network_drugs, how='inner', left_on='Drug', right_on='Drug_frm_G_nt500')

# %%
GSEA_common_drugs_temp2 = pd.merge(left=GSEA_overlap_results, right=GSEA_net_meta_results, how='inner', left_on='Drug', right_on='Drug_frm_G_ntmeta')

# %%
GSEA_common_drugs = GSEA_common_drugs_temp[['Database', 'Method', 'Drug', 'Species', 'Tissue or Cell Line', 'Study', 'Dose', 'Time', 'Jaccard Score', 'Odds Ratio', 'P value', 'Within Species Rank', 'Overlap']].copy()

# %%
GSEA_common_drugs2 = GSEA_common_drugs_temp2[['Database', 'Method', 'Drug', 'Species', 'Tissue or Cell Line', 'Study', 'Dose', 'Time', 'Jaccard Score', 'Odds Ratio', 'P value', 'Within Species Rank', 'Overlap']].copy()

# %%
GSEA_common_drugs
# Out:
#                 Database                    Method         Drug       Species  \
# 0  L1000_CPD001_MCF7_24H  Characteristic direction  Perhexiline  Homo sapiens
# 1   L1000_NMH002_NEU_24H  Characteristic direction   Diclofenac  Homo sapiens
#
#   Tissue or Cell Line     Study   Dose  Time  Jaccard Score  Odds Ratio  \
# 0                MCF7  In Vitro  10 uM  24hr   3.469447e-18   12.477129
# 1                 NEU  In Vitro  10 uM  24hr   3.469447e-18   15.555769
#
#         P value  Within Species Rank  \
# 0  1.069574e-09             0.745649
# 1  9.831479e-11             0.745649
#
#                                              Overlap
# 0  INHBA, ABLIM1, MGLL, GPX3, CCNG2, CD24, CST1, ...
# 1  COL11A1, PPP1R3C, NMU, THBS2, CLCA4, TMEM45A, ...

# %%
GSEA_common_drugs2
# Out:
#                     Database                    Method  \
# 0      L1000_CPC011_VCAP_24H  Characteristic direction
# 1        L1000_CPC012_PC3_6H  Characteristic direction
# 2     L1000_LJP001_SKBR3_24H  Characteristic direction
# 3       L1000_CPC011_HA1E_6H  Characteristic direction
# 4     L1000_CPC014_HCC515_6H  Characteristic direction
# ..                       ...                       ...
# 126     L1000_CPC001_VCAP_6H  Characteristic direction
# 127     L1000_CPC002_PC3_24H  Characteristic direction
# 128                 GSE74603  Characteristic direction
# 129    L1000_CPC011_VCAP_24H  Characteristic direction
# 130  L1000_CPC006_SNU1040_6H  Characteristic direction
#
#                                    Drug       Species  \
# 0                           Vincristine  Homo sapiens
# 1                             Topotecan  Homo sapiens
# 2                             Sirolimus  Homo sapiens
# 3                           Doxorubicin  Homo sapiens
# 4                           Ruxolitinib  Homo sapiens
# ..                                  ...           ...
# 126                            Naproxen  Homo sapiens
# 127                        Mifepristone  Homo sapiens
# 128  Cyclin-dependent kinase  inhibitor  Homo sapiens
# 129                      Levonorgestrel  Homo sapiens
# 130                         Thalidomide  Homo sapiens
#
#          Tissue or Cell Line            Study             Dose  \
# 0                       VCAP         In Vitro            10 uM
# 1                        PC3         In Vitro            10 uM
# 2                      SKBR3         In Vitro          0.08 uM
# 3                       HA1E         In Vitro            10 uM
# 4                     HCC515         In Vitro            10 uM
# ..                       ...              ...              ...
# 126                     VCAP         In Vitro            10 uM
# 127                      PC3         In Vitro            10 uM
# 128  gastrointestinal system  PharmOmics meta  PharmOmics meta
# 129                     VCAP         In Vitro            10 uM
# 130                  SNU1040         In Vitro            10 uM
#
#                 Time  Jaccard Score  Odds Ratio       P value  \
# 0               24hr   1.387779e-17   38.118083  1.690898e-34
# 1                6hr   6.938894e-18   15.074806  2.559920e-08
# 2               24hr   6.938894e-18   16.410028  9.100746e-12
# 3                6hr   6.938894e-18   22.805246  1.489037e-12
# 4                6hr   6.938894e-18   20.774369  5.573141e-13
# ..               ...            ...         ...           ...
# 126              6hr   3.469447e-18   32.442635  1.450715e-24
# 127             24hr   3.035766e-18   15.929676  2.219857e-12
# 128  PharmOmics meta   2.602085e-18   14.012731  8.628123e-09
# 129             24hr   2.602085e-18   15.631213  9.326867e-11
# 130              6hr   2.602085e-18   17.049223  1.535769e-13
#
#      Within Species Rank                                            Overlap
# 0               0.999929  CRABP2, POSTN, FOXM1, HOPX, CEACAM5, CEACAM6, ...
# 1               0.974530  THBS2, INHBA, COL3A1, ASPN, SPARC, COL1A2, MAG...
# 2               0.974530  COL11A1, GPX3, SNAI2, CXCL12, ISG15, HPGD, NUS...
# 3               0.974530  GPX3, KAT2B, SCNN1A, CEACAM6, TMEM45A, ASPN, P...
# 4               0.974530  MFAP2, POSTN, CEACAM5, TOP2A, EPS8L1, CYP4B1, ...
# ..                   ...                                                ...
# 126             0.745649  BLNK, SERPINB2, SCEL, HPGD, SERPINB13, ZNF185,...
# 127             0.545847  CD24, ABLIM1, CXCL12, BLNK, ITGA6, SCNN1A, SPR...
# 128             0.535800  S100P, MALL, CLIC3, ISG15, TGFBI, PPL, CD24, D...
# 129             0.535800  KLK11, NUCB2, PLAC8, SCNN1A, EPS8L1, EHF, MUC5...
# 130             0.535800  KLK11, SERPINE1, HPGD, PPP1R3C, HOPX, CYP4B1, ...
#
# [131 rows x 13 columns]

# %%
old_Results_file = "/Users/anb/Documents/CMEB-Lab/ESCC-Drug-Repositioning/DR-escc-data/output/GSE23400/1st-dual-arm-analysis/analysis-both-arms/Common_Drugs.tsv"

old_Results = pd.read_csv(
    old_Results_file, comment="#", header=0, sep='\t', low_memory=False
)

# %%
GSEA_common_drugs_temp2 = pd.merge(left=GSEA_overlap_results, right=old_Results, how='inner', left_on='Drug', right_on='Drug')

# %%
GSEA_common_drugs_temp2
# Out:
#                   Database                  Method_x           Drug  \
# 0     L1000_CPC011_HA1E_6H  Characteristic direction    Doxorubicin
# 1     L1000_CPC004_VCAP_6H  Characteristic direction      Flutamide
# 2  L1000_CPC006_NCIH596_6H  Characteristic direction  Dexamethasone
# 3     L1000_CPC011_PC3_24H  Characteristic direction  Rosiglitazone
# 4    L1000_CPC005_A375_24H  Characteristic direction     Fluoxetine
# 5    L1000_CPC005_A549_24H  Characteristic direction      Etoposide
# 6    L1000_CPC020_VCAP_24H  Characteristic direction      Labetalol
# 7    L1000_ASG001_MCF7_24H  Characteristic direction   Fluphenazine
#
#         Species Tissue or Cell Line     Study  Dose_x Time_x  Jaccard Score_x  \
# 0  Homo sapiens                HA1E  In Vitro   10 uM    6hr     6.938894e-18
# 1  Homo sapiens                VCAP  In Vitro   10 uM    6hr     6.938894e-18
# 2  Homo sapiens             NCIH596  In Vitro   10 uM    6hr     6.938894e-18
# 3  Homo sapiens                 PC3  In Vitro   10 uM   24hr     6.938894e-18
# 4  Homo sapiens                A375  In Vitro   10 uM   24hr     3.469447e-18
# 5  Homo sapiens                A549  In Vitro   10 uM   24hr     3.469447e-18
# 6  Homo sapiens                VCAP  In Vitro   10 uM   24hr     3.469447e-18
# 7  Homo sapiens                MCF7  In Vitro  0.4 uM   24hr     3.469447e-18
#
#    Odds Ratio_x  ...                                 allsignatures_down  \
# 0     22.805246  ...  HSPA2,PPAP2B,UAP1,KLHL24,PLK1,IDI1,KLK10,HSPA8...
# 1     18.840951  ...  HIST1H4C,TGM4,TIMP1,SYBU,IDI1,IFI27,DHCR7,PUF6...
# 2     19.654562  ...  PRG2,PMAIP1,PPAP2B,PBX3,PLK2,CPE,CD36,PRKCA,TP...
# 3     28.606721  ...  HIST1H4C,NETO2,PPAP2B,FKBP10,NISCH,ALDH7A1,CPE...
# 4     11.548660  ...  HIST1H4C,PTGS1,HSPA5,FKBP11,KLK10,KLK11,ERGIC2...
# 5     13.653047  ...  PPAP2B,PLK1,IDI1,PLK4,PKMYT1,NQO1,RAPGEF5,MFAP...
# 6     13.084765  ...  PTGS1,FXYD5,TRIM16,NRCAM,HBD,IFI27,SLC6A8,CD36...
# 7     13.202214  ...  HIST1H4C,KLRB1,FXYD2,TM7SF2,CKB,SCG5,IL6ST,P4H...
#
#                               allsignatures_combined  \
# 0  HSPA2,FKBP14,CPM,RAB4A,C20ORF111,HSPA8,LRRC16A...
# 1  HIST1H4C,FKBP11,GNPTAB,STK10,WLS,TPBG,CHN1,MFA...
# 2  PMAIP1,PPAP2B,CKM,PRKCA,CPE,BGN,FKBP5,MYL2,MYL...
# 3  HIST1H4C,PPAP2B,FKBP10,HSPA9,HSPA8,NDUFB3,CPE,...
# 4  HIST1H4C,RYK,ZDHHC13,WWP1,AP1M2,FBXO11,ERGIC2,...
# 5  TAP1,ACADVL,PMAIP1,CPM,ACTG2,YWHAH,IFI27,RAPGE...
# 6  CD38,PPAP2B,CKB,GNPTAB,IFI27,POLG2,CD36,N4BP2L...
# 7  SSPN,HIST1H4C,ELANE,AGL,UBE2J1,HSPA5,CKB,SUMO3...
#
#                                SIDER_link     P value_y Jaccard Score_y  \
# 0   http://sideeffects.embl.de/drugs/1690  5.036655e-06        0.020121
# 1   http://sideeffects.embl.de/drugs/3397  4.676347e-08        0.025287
# 2   http://sideeffects.embl.de/drugs/3003  2.769265e-11        0.032407
# 3  http://sideeffects.embl.de/drugs/77998  5.285526e-06        0.020316
# 4   http://sideeffects.embl.de/drugs/3386  6.306750e-05        0.017505
# 5   http://sideeffects.embl.de/drugs/3310  1.325940e-17        0.036082
# 6   http://sideeffects.embl.de/drugs/3869  1.751802e-06        0.016949
# 7   http://sideeffects.embl.de/drugs/3372  2.453611e-24        0.030704
#
#   Odds Ratio_y Average Rank                  Method_y           Dose_y  \
# 0     6.762837     0.869384  Characteristic direction        0.3704 uM
# 1     9.924151     0.881097  Characteristic direction  PharmOmics meta
# 2    12.996564     0.887469  Characteristic direction            10 uM
# 3     7.724825     0.870036  Characteristic direction            10 uM
# 4     6.383801     0.856873  Characteristic direction            10 uM
# 5     9.664942     0.889064  Characteristic direction  PharmOmics meta
# 6     3.743442     0.853167                     limma   limma combined
# 7     7.219049     0.886349                     limma   limma combined
#
#             Time_y
# 0             24hr
# 1  PharmOmics meta
# 2             24hr
# 3             24hr
# 4              6hr
# 5  PharmOmics meta
# 6   limma combined
# 7   limma combined
#
# [8 rows x 25 columns]

# %% [markdown]
# Now we will move onto the wkda arm.

# %% [markdown]
# Staring with wkda_net_meta, make sure the data is loaded in correctly.

# %%
wkda_net_meta

# %% [markdown]
# As we are only interested in human data, first check for non-human data and remove if needed.

# %%
wkda_net_meta[wkda_net_meta["Species"] != "Homo sapiens"]

# %% [markdown]
# Sort the df according to drug and rank

# %%
wkda_net_meta_sorted_drug = wkda_net_meta.sort_values(['Drug', 'Rank'], axis=0, ascending=False, inplace=False)

# %%
wkda_net_meta_sorted_drug

# %% [markdown]
# Remove the duplicates of drugs, keeping only the first occurrence as it as the highest p-value

# %%
wkda_net_meta_sorted_drug.drop_duplicates(subset = ["Drug"], inplace=True)

# %%
wkda_net_meta_sorted_drug

# %% [markdown]
# Sort the df according to Rank.

# %%
wkda_net_meta_sorted_rank = wkda_net_meta_sorted_drug.sort_values(['Rank'], axis=0, ascending=False, inplace=False)

# %%
wkda_net_meta_sorted_rank

# %%
wkda_net_meta_sorted_rank.reset_index(inplace=True,drop=True)

# %%
wkda_net_meta_sorted_rank

# %%
wkda_net_meta_filt_results = wkda_net_meta_sorted_rank.copy()

# %% [markdown]
# Next, with wkda_net_500, make sure the data is loaded in correctly.

# %%
wkda_net_500

# %% [markdown]
# Remove non-significant results

# %%
wkda_net_500_sig = wkda_net_500[wkda_net_500["Species"] == 'Homo sapiens']
wkda_net_500_sig = wkda_net_500_sig[wkda_net_500_sig["P value"] <= 0.05]

# %% [markdown]
# Remove entries with z score equal to zero as they are problematic

# %%
wkda_net_500_sig_z0 = wkda_net_500_sig[wkda_net_500_sig["Z score"] != 0]
wkda_net_500_sig_z0 = wkda_net_500_sig[wkda_net_500_sig["Z score"] < -2]

# %%
wkda_net_500_sig_z0

# %% [markdown]
# Sort the df according to drug and rank

# %%
wkda_net_500_sig_z0_sorted_drug = wkda_net_500_sig_z0.sort_values(['Drug', 'P value', 'Z score'], axis=0, ascending=True, inplace=False)

# %%
wkda_net_500_sig_z0_sorted_drug

# %% [markdown]
# View the top result, Etoposide, to make sure the df is sorted correctly, and the most significant result is at the top of the 'Etoposide's list in the df

# %%
wkda_net_500_sig_z0_sorted_drug[wkda_net_500_sig_z0_sorted_drug['Drug'] == 'Etoposide']

# %% [markdown]
# Remove the duplicates of drugs, keeping only the first occurrence as it as the highest pvalue

# %%
wkda_net_500_sig_z0_sorted_drug.drop_duplicates(subset = ["Drug"], inplace=True)

# %%
wkda_net_500_sig_z0_sorted_drug

# %% [markdown]
# Sort the df according to Rank.

# %%
wkda_net_500_sig_z0_sorted_sorted_rank = wkda_net_500_sig_z0_sorted_drug.sort_values(['Z score', 'Z score rank', 'P value'], axis=0, ascending=True, inplace=False)

# %%
wkda_net_500_sig_z0_sorted_sorted_rank

# %%
wkda_net_500_sig_z0_sorted_sorted_rank.reset_index(inplace=True,drop=True)

# %%
wkda_net_500_filt_results = wkda_net_500_sig_z0_sorted_sorted_rank.copy()

# %%
wkda_net_500_filt_results

# %% [markdown]
# Finally, for wkda, filter overlap

# %%
wkda_overlap

# %%
wkda_overlap_sig = wkda_overlap[wkda_overlap["P value"] <= 0.05]

# %%
wkda_overlap_sig = wkda_overlap_sig[wkda_overlap_sig['Within Species Rank'] >= 0]

# %%
wkda_overlap_sig_hs = wkda_overlap_sig[wkda_overlap_sig['Species'] == 'Homo sapiens']

# %%
wkda_overlap_sig_hs

# %% [markdown]
# Filter the results to select only those with a Jaccard score above the mean.

# %%
wkda_overlap_sig_hs['Jaccard Score'].mean()

# %%
wkda_overlap_sig_hs_js = wkda_overlap_sig_hs[wkda_overlap_sig_hs['Jaccard Score'] > 0.015192708293416539]

# %%
wkda_overlap_sig_hs_js

# %%
wkda_overlap_sig_hs_sorted_drug = wkda_overlap_sig_hs_js.sort_values(['Drug', 'Within Species Rank', 'Jaccard Score', 'P value'], axis=0, ascending=False, inplace=False)

# %%
wkda_overlap_sig_hs_sorted_drug

# %%
wkda_overlap_sig_hs_sorted_drug.drop_duplicates(subset = ["Drug"], inplace=True)

# %%
wkda_overlap_sig_hs_sorted_rank = wkda_overlap_sig_hs_sorted_drug.sort_values(['Within Species Rank', 'Jaccard Score', 'P value'], axis=0, ascending=False, inplace=False)

# %%
wkda_overlap_sig_hs_sorted_rank

# %%
wkda_overlap_sig_hs_sorted_rank.reset_index(inplace=True,drop=True)

# %%
wkda_overlap_sig_hs_sorted_rank

# %%
wkda_overlap_filt_results = wkda_overlap_sig_hs_sorted_rank.copy()

# %% [markdown]
# Filtered result dfs used in the subsequent steps:
# - wkda_net_meta_filt_results
# - wkda_net_500_filt_results
# - wkda_overlap_filt_results

# %%
wkda_net_meta_filt_results.head()

# %%
wkda_net_500_filt_results.head()

# %%
wkda_overlap_filt_results.head()

# %%
wkda_overlap_results = wkda_overlap_filt_results.copy()
wkda_net_500_results = wkda_net_500_filt_results[['Drug', 'Species', 'Tissue']].copy()
wkda_net_meta_results = wkda_net_meta_filt_results[['Drug',	'Species', 'Tissue', 'Dataset']].copy()

# %%
# wkda_overlap_results = wkda_overlap_results.add_suffix('_frm_w_ovrlp')

wkda_net_500_results = wkda_net_500_results.add_suffix('_frm_w_nt500')
wkda_net_meta_results = wkda_net_meta_results.add_suffix('_frm_w_ntmeta')

# %%
wkda_overlap_results.head()

# %%
wkda_net_500_results.head()

# %%
wkda_net_meta_results.head()

# %%
wkda_common_network_drugs = pd.merge(left=wkda_net_500_results, right=wkda_net_meta_results, how='inner', left_on='Drug_frm_w_nt500', right_on='Drug_frm_w_ntmeta')

# %%
wkda_common_network_drugs

# %%
wkda_common_drugs_temp = pd.merge(left=wkda_overlap_results, right=wkda_common_network_drugs, how='inner', left_on='Drug', right_on='Drug_frm_w_nt500')

# %%
wkda_common_drugs = wkda_common_drugs_temp[['Database', 'Method', 'Drug', 'Species', 'Tissue or Cell Line', 'Study', 'Dose', 'Time', 'Jaccard Score', 'Odds Ratio', 'P value', 'Within Species Rank', 'Overlap']].copy()

# %% [markdown]
# Now that the drugs from each arm of the analysis have been extracted, the results from both arms will be compared to extract only drugs common to both arms

# %%
GSEA_common_drugs

# %%
wkda_common_drugs

# %%
GSEA_common_drugs = GSEA_common_drugs.add_suffix('_GSEA')

# %%
wkda_common_drugs.head()

# %%
common_drugs_temp = pd.merge(left=wkda_common_drugs, right=GSEA_common_drugs, how='inner', left_on='Drug', right_on='Drug_GSEA')

# %%
common_drugs_temp['Average Rank'] = common_drugs_temp[['Within Species Rank', 'Within Species Rank_GSEA']].mean(axis=1)

# %%
common_drugs_temp

# %%
common_drugs = common_drugs_temp[['Database', 'Method', 'Drug', 'Average Rank', 'Species', 'Tissue or Cell Line', 'Study', 'Dose', 'Time', 'Jaccard Score', 'Odds Ratio', 'P value']].copy()

# %%
common_drugs

# %%
Results = common_drugs[['Drug','P value', 'Jaccard Score', 'Odds Ratio', 'Average Rank', 'Method', 'Dose', 'Time']].copy()

# %%
Results.sort_values(['P value', ], axis=0, ascending=True, inplace=True)
Results.reset_index(drop=True, inplace=True)

# %%
Results

# %%
out_dir = "/Users/anb/Documents/CMEB-Lab/ESCC-Drug-Repositioning/DR-escc-data/output/GSE23400/1st-dual-arm-analysis/analysis-both-arms"

Results.to_csv(os.path.join(out_dir, "Common_Drugs.tsv"), sep='\t', index=False)
