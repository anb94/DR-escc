# %%
path_in = "d:/Data/GPL570-55999.txt"

# %%
fin = open (path_in ,"r")
header = []
row_data = []
for line in fin:
    if not line.startswith ("#"):
        if line.startswith("ID"):
            line = line.strip()
            s = line.split('\t')
            for i in range(len(s)):
                header.append(s[i])
        else:
            temp = []
            line = line.strip()
            p = line.split('\t')
            for j in range(len(p)):
                temp.append(p[j])
            row_data.append(temp)

# %%
len(header)
# Out:
# 16

# %%
len(row_data)
# Out:
# 54675

# %%
data = pd.DataFrame(row_data)
# Out:
#                     0       1          2             3            4   \
# 0            1007_s_at  U48705             Homo sapiens  Oct 6, 2014
# 1              1053_at  M87338             Homo sapiens  Oct 6, 2014
# 2               117_at  X51757             Homo sapiens  Oct 6, 2014
# 3               121_at  X69699             Homo sapiens  Oct 6, 2014
# 4            1255_g_at  L36861             Homo sapiens  Oct 6, 2014
# ...                ...     ...        ...           ...          ...
# 54670   AFFX-ThrX-5_at          --Control  Homo sapiens  Oct 6, 2014
# 54671   AFFX-ThrX-M_at          --Control  Homo sapiens  Oct 6, 2014
# 54672  AFFX-TrpnX-3_at          --Control  Homo sapiens  Oct 6, 2014
# 54673  AFFX-TrpnX-5_at          --Control  Homo sapiens  Oct 6, 2014
# 54674  AFFX-TrpnX-M_at          --Control  Homo sapiens  Oct 6, 2014
#
#                       5                                6   \
# 0      Exemplar sequence  Affymetrix Proprietary Database
# ...

# %%
import pandas as pd

# %%
data = pd.DataFrame(columns=[header])

# %%
data
# Out:
# Empty DataFrame
# Columns: [(ID,), (GB_ACC,), (SPOT_ID,), (Species Scientific Name,), (Annotation Date,), (Sequence Type,), (Sequence Source,), (Target Description,), (Representative Public ID,), (Gene Title,), (Gene Symbol,), (ENTREZ_GENE_ID,), (RefSeq Transcript ID,), (Gene Ontology Biological Process,), (Gene Ontology Cellular Component,), (Gene Ontology Molecular Function,)]
# Index: []
