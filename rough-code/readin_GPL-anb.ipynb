# %%
path_in = "/Users/anb/Downloads/GPL570-55999.txt"

# %%
import pandas as pd

# %%
#fin = open (path_in ,"r")
#header = []
#row_data = []
#for line in fin:
#    if not line.startswith ("#"):
#        if line.startswith("ID"):
#            line = line.strip()
#            s = line.split('\t')
#            for i in range(len(s)):
#                header.append(s[i])
#        else:
 #           temp = []
 #           line = line.strip()
 #           p = line.split('\t')
##          for j in range(len(p)):
 #               temp.append(p[j])
 #           row_data.append(temp)
#

# %%
#len(header)

# %%
#len(row_data)
# Out:
# 54675

# %%
#data = pd.DataFrame(row_data)

# %%
#header
# Out:
# ['ID',
#  'GB_ACC',
#  'SPOT_ID',
#  'Species Scientific Name',
#  'Annotation Date',
#  'Sequence Type',
#  'Sequence Source',
#  'Target Description',
#  'Representative Public ID',
#  'Gene Title',
#  'Gene Symbol',
#  'ENTREZ_GENE_ID',
#  'RefSeq Transcript ID',
#  'Gene Ontology Biological Process',
#  'Gene Ontology Cellular Component',
#  'Gene Ontology Molecular Function']

# %%
#data = pd.DataFrame(columns=[header], dtype=object)

# %%
#data
# Out:
# Empty DataFrame
# Columns: [(ID,), (GB_ACC,), (SPOT_ID,), (Species Scientific Name,), (Annotation Date,), (Sequence Type,), (Sequence Source,), (Target Description,), (Representative Public ID,), (Gene Title,), (Gene Symbol,), (ENTREZ_GENE_ID,), (RefSeq Transcript ID,), (Gene Ontology Biological Process,), (Gene Ontology Cellular Component,), (Gene Ontology Molecular Function,)]
# Index: []

# %%
affy_array = "/Users/anb/Documents/DR-escc-data/dataset/GSE44021/GPL570-55999.txt"

affy_array_df = pd.read_csv(
    affy_array, comment="#", header=0, sep='\t', low_memory=False
)

# %%
affy_array_df
# Out:
#                     ID  GB_ACC    SPOT_ID Species Scientific Name  \
# 0            1007_s_at  U48705        NaN            Homo sapiens
# 1              1053_at  M87338        NaN            Homo sapiens
# 2               117_at  X51757        NaN            Homo sapiens
# 3               121_at  X69699        NaN            Homo sapiens
# 4            1255_g_at  L36861        NaN            Homo sapiens
# ...                ...     ...        ...                     ...
# 54670   AFFX-ThrX-5_at     NaN  --Control            Homo sapiens
# 54671   AFFX-ThrX-M_at     NaN  --Control            Homo sapiens
# 54672  AFFX-TrpnX-3_at     NaN  --Control            Homo sapiens
# 54673  AFFX-TrpnX-5_at     NaN  --Control            Homo sapiens
# 54674  AFFX-TrpnX-M_at     NaN  --Control            Homo sapiens
#
#       Annotation Date      Sequence Type                  Sequence Source  \
# 0         Oct 6, 2014  Exemplar sequence  Affymetrix Proprietary Database
# ...

# %%
common_probes_data = "/Users/anb/Documents/DR-escc-data/dataset/GSE44021/GSE44021_common_probes_data.txt"

common_probes_df = pd.read_csv(
    common_probes_data, comment="#", header=0, sep='\t', low_memory=False
)

# %%
common_probes_df
# Out:
#           Probe.Set.ID     E1164N     E1164T     E1301N     E1301T     E1405N  \
# 0            1007_s_at  10.987670  11.157660  10.247950  11.269070  10.935340
# 1              1053_at   6.601962   6.814484   6.676557   6.904263   6.750452
# 2               117_at   7.180749   7.218192   7.380199   7.462622   7.317579
# 3               121_at   9.646809   9.509505   9.444956   9.680482   9.859735
# 4            1255_g_at   4.961967   4.916804   4.948649   5.066451   4.982614
# ...                ...        ...        ...        ...        ...        ...
# 22272   AFFX-ThrX-5_at   4.944631   5.041653   5.046082   5.154872   5.017673
# 22273   AFFX-ThrX-M_at   4.682776   4.685426   4.646530   4.694914   4.667716
# 22274  AFFX-TrpnX-3_at   4.391311   4.348401   4.393190   4.419393   4.391309
# 22275  AFFX-TrpnX-5_at   4.653123   4.672676   4.643037   4.662748   4.728524
# 22276  AFFX-TrpnX-M_at   4.689422   4.614806   4.695632   4.719317   4.666295
#
# ...

# %%
affy_array_df['Probe.Set.ID']=affy_array_df['ID'].copy()

# %%
temp1 = pd.merge(left=common_probes_df, right=affy_array_df[['Probe.Set.ID', 'Gene Symbol']], how='left', left_on='Probe.Set.ID', right_on='Probe.Set.ID')

# %%
temp1
# Out:
#           Probe.Set.ID     E1164N     E1164T     E1301N     E1301T     E1405N  \
# 0            1007_s_at  10.987670  11.157660  10.247950  11.269070  10.935340
# 1              1053_at   6.601962   6.814484   6.676557   6.904263   6.750452
# 2               117_at   7.180749   7.218192   7.380199   7.462622   7.317579
# 3               121_at   9.646809   9.509505   9.444956   9.680482   9.859735
# 4            1255_g_at   4.961967   4.916804   4.948649   5.066451   4.982614
# ...                ...        ...        ...        ...        ...        ...
# 22272   AFFX-ThrX-5_at   4.944631   5.041653   5.046082   5.154872   5.017673
# 22273   AFFX-ThrX-M_at   4.682776   4.685426   4.646530   4.694914   4.667716
# 22274  AFFX-TrpnX-3_at   4.391311   4.348401   4.393190   4.419393   4.391309
# 22275  AFFX-TrpnX-5_at   4.653123   4.672676   4.643037   4.662748   4.728524
# 22276  AFFX-TrpnX-M_at   4.689422   4.614806   4.695632   4.719317   4.666295
#
# ...
