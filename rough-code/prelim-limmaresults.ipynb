# %%
import pandas as pd

# %%
affy_array = "/Users/anb/Documents/DR-escc-data/dataset/GSE44021/GPL570-55999.txt"

affy_array_df = pd.read_csv(
    affy_array, comment="#", header=0, sep='\t', low_memory=False
)

# %%
limma_diff_data ="/Users/anb/Documents/DR-escc-data/output/unpaired-limma/0-vs-1.limma_Dif.txt"
limma_diff_df = pd.read_csv(
    limma_diff_data, comment="#", header=0, sep='\t', low_memory=False
)

# %%
limma_diff_df
# Out:
#      row.names(tT)     logFC    AveExpr          t       P.Value  \
# 0        201535_at  1.714750   8.278219  19.429494  2.918571e-50
# 1        203845_at  2.093369   7.572078  18.320585  1.052277e-46
# 2      203571_s_at  2.125775   8.671351  17.858511  3.291293e-45
# 3      211548_s_at  3.218877   7.305840  17.814270  4.580243e-45
# 4      221896_s_at  1.028031   9.721022  17.415202  9.081557e-44
# ...            ...       ...        ...        ...           ...
# 1032     206291_at -1.594372   6.037729  -4.774119  3.227126e-06
# 1033   214768_x_at -1.078726   7.206429  -4.700964  4.481843e-06
# 1034   216576_x_at -1.172161   6.948873  -4.559393  8.371262e-06
# 1035   211194_s_at -1.108632   6.341635  -4.204118  3.765611e-05
# 1036     209351_at -1.224875  11.534990  -4.067133  6.557814e-05
#
#          adj.P.Val           B       regulated
# 0     2.167233e-46  103.658513    Up-Regulated
# 1     4.688313e-43   95.557448    Up-Regulated
# ...

# %%
affy_array_df['row.names(tT)']=affy_array_df['ID'].copy()

# %%
affy_array_df
# Out:
#                     ID  GB_ACC    SPOT_ID Species Scientific Name  \
# 0            1007_s_at  U48705        NaN            Homo sapiens
# 1              1053_at  M87338        NaN            Homo sapiens
# 2               117_at  X51757        NaN            Homo sapiens
# 3               121_at  X69699        NaN            Homo sapiens
# 4            1255_g_at  L36861        NaN            Homo sapiens
# ...                ...     ...        ...                     ...
# 54670   AFFX-ThrX-5_at     NaN  --Control            Homo sapiens
# 54671   AFFX-ThrX-M_at     NaN  --Control            Homo sapiens
# 54672  AFFX-TrpnX-3_at     NaN  --Control            Homo sapiens
# 54673  AFFX-TrpnX-5_at     NaN  --Control            Homo sapiens
# 54674  AFFX-TrpnX-M_at     NaN  --Control            Homo sapiens
#
#       Annotation Date      Sequence Type                  Sequence Source  \
# 0         Oct 6, 2014  Exemplar sequence  Affymetrix Proprietary Database
# ...

# %%
lima_diff_annotated_temp1 = pd.merge(left=limma_diff_df, right=affy_array_df[['row.names(tT)', 'Gene Symbol']], how='left', left_on='row.names(tT)', right_on='row.names(tT)')

# %%
lima_diff_annotated_temp1
# Out:
#      row.names(tT)     logFC    AveExpr          t       P.Value  \
# 0        201535_at  1.714750   8.278219  19.429494  2.918571e-50
# 1        203845_at  2.093369   7.572078  18.320585  1.052277e-46
# 2      203571_s_at  2.125775   8.671351  17.858511  3.291293e-45
# 3      211548_s_at  3.218877   7.305840  17.814270  4.580243e-45
# 4      221896_s_at  1.028031   9.721022  17.415202  9.081557e-44
# ...            ...       ...        ...        ...           ...
# 1032     206291_at -1.594372   6.037729  -4.774119  3.227126e-06
# 1033   214768_x_at -1.078726   7.206429  -4.700964  4.481843e-06
# 1034   216576_x_at -1.172161   6.948873  -4.559393  8.371262e-06
# 1035   211194_s_at -1.108632   6.341635  -4.204118  3.765611e-05
# 1036     209351_at -1.224875  11.534990  -4.067133  6.557814e-05
#
#          adj.P.Val           B       regulated  \
# 0     2.167233e-46  103.658513    Up-Regulated
# 1     4.688313e-43   95.557448    Up-Regulated
# ...

# %%
lima_diff_annotated = lima_diff_annotated_temp1[["Gene Symbol", "regulated", "logFC", "AveExpr", "t", "P.Value", "adj.P.Val", "B"]]

# %%
lima_diff_annotated
# Out:
#                                             Gene Symbol       regulated  \
# 0                                                  UBL3    Up-Regulated
# 1                                                 KAT2B    Up-Regulated
# 2                                                 ADIRF    Up-Regulated
# 3                                                  HPGD    Up-Regulated
# 4                                                HIGD1A    Up-Regulated
# ...                                                 ...             ...
# 1032                                                NTS  Down-Regulated
# 1033  IGKC /// IGKV2-28 /// IGKV2-28 /// IGKV2D-28 /...  Down-Regulated
# 1034                                       IGK /// IGKC  Down-Regulated
# 1035                                               TP63  Down-Regulated
# 1036                                              KRT14  Down-Regulated
#
#          logFC    AveExpr          t       P.Value     adj.P.Val           B
# ...

# %%
out_dir = "/Users/anb/Documents/DR-escc-data/output"


lima_diff_annotated.to_csv(os.path.join(out_dir, "limma_diff_annotated.tsv"), sep='\t', index=False)
