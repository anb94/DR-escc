# %%
import os
import pandas as pd
import numpy as np

# %%
# DEG file

DEG_file = "/Users/anb/Documents/CMEB-Lab/ESCC-Drug-Repositioning/DR-escc-data/output/GSE23400//filtered_de_results_1fc_05pval.tsv"

DEGs = pd.read_csv(
    DEG_file, comment="#", header=0, sep='\t', low_memory=False
)

# %%
DEGs
# Out:
#               ID    Gene.Symbol ENTREZ_GENE_ID  \
# 0    202311_s_at         COL1A1           1277
# 1    219787_s_at           ECT2           1894
# 2    201897_s_at          CKS1B           1163
# 3      204023_at           RFC4           5984
# 4      203417_at          MFAP2           4237
# ..           ...            ...            ...
# 667  214414_x_at  HBA1 /// HBA2  3039 /// 3040
# 668    205623_at        ALDH3A1            218
# 669  218002_s_at         CXCL14           9547
# 670  202222_s_at            DES           1674
# 671    213796_at         SPRR1A           6698
#
#                                       Gene.Title  \
# 0                      collagen, type I, alpha 1
# 1                 epithelial cell transforming 2
# 2     CDC28 protein kinase regulatory subunit 1B
# 3    replication factor C (activator 1) 4, 37kDa
# 4            microfibrillar-associated protein 2
# ..                                           ...
# ...

# %%
DEGS_mini = DEGs[['Gene.Symbol', 'logFC', 'P.Value']]

# %%
DEGS_mini
# Out:
#        Gene.Symbol     logFC       P.Value
# 0           COL1A1  2.989800  5.885295e-32
# 1             ECT2  2.112317  2.296755e-31
# 2            CKS1B  1.528879  5.201664e-31
# 3             RFC4  1.716516  2.208688e-30
# 4            MFAP2  1.691285  4.685839e-30
# ..             ...       ...           ...
# 667  HBA1 /// HBA2 -1.001693  7.279271e-05
# 668        ALDH3A1 -1.297811  9.279016e-05
# 669         CXCL14  1.038378  1.270588e-04
# 670            DES -1.180520  1.309680e-04
# 671         SPRR1A -1.106883  3.416290e-04
#
# [672 rows x 3 columns]

# %%
DEGS_mini['abslogfc'] = DEGS_mini['logFC'].abs()
# Out:
# /var/folders/_n/s_910cbn0dg5t1lpsjv2h90w0000gn/T/ipykernel_54157/4075167138.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DEGS_mini['abslogfc'] = DEGS_mini['logFC'].abs()

# %%
DEGS_mini
# Out:
#        Gene.Symbol     logFC       P.Value  abslogfc
# 0           COL1A1  2.989800  5.885295e-32  2.989800
# 1             ECT2  2.112317  2.296755e-31  2.112317
# 2            CKS1B  1.528879  5.201664e-31  1.528879
# 3             RFC4  1.716516  2.208688e-30  1.716516
# 4            MFAP2  1.691285  4.685839e-30  1.691285
# ..             ...       ...           ...       ...
# 667  HBA1 /// HBA2 -1.001693  7.279271e-05  1.001693
# 668        ALDH3A1 -1.297811  9.279016e-05  1.297811
# 669         CXCL14  1.038378  1.270588e-04  1.038378
# 670            DES -1.180520  1.309680e-04  1.180520
# 671         SPRR1A -1.106883  3.416290e-04  1.106883
#
# [672 rows x 4 columns]

# %%
DEGS_mini.sort_values(['Gene.Symbol', 'abslogfc', 'P.Value'], ascending=False, inplace=True)
DEGS_mini.drop_duplicates(subset = ["Gene.Symbol"], inplace=True)
# Out:
# /var/folders/_n/s_910cbn0dg5t1lpsjv2h90w0000gn/T/ipykernel_54157/3332401329.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DEGS_mini.sort_values(['Gene.Symbol', 'abslogfc', 'P.Value'], ascending=False, inplace=True)
# /var/folders/_n/s_910cbn0dg5t1lpsjv2h90w0000gn/T/ipykernel_54157/3332401329.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DEGS_mini.drop_duplicates(subset = ["Gene.Symbol"], inplace=True)

# %%
DEGS_mini.sort_values(['abslogfc', 'P.Value'], ascending=False, inplace=True)
# Out:
# /var/folders/_n/s_910cbn0dg5t1lpsjv2h90w0000gn/T/ipykernel_54157/2564628457.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DEGS_mini.sort_values(['abslogfc', 'P.Value'], ascending=False, inplace=True)

# %%
DEGS_mini
# Out:
#        Gene.Symbol     logFC       P.Value  abslogfc
# 6             MMP1  4.442564  8.645952e-29  4.442564
# 110         CRISP3 -4.246975  8.533328e-21  4.246975
# 143            MAL -3.968327  8.650061e-20  3.968327
# 298           CRNN -3.654040  3.309579e-16  3.654040
# 254           SCEL -3.496086  4.159160e-17  3.496086
# ..             ...       ...           ...       ...
# 637          ACKR3  1.007208  1.498846e-06  1.007208
# 201           COBL -1.004592  1.908805e-18  1.004592
# 541         HS3ST1 -1.001725  5.010626e-10  1.001725
# 667  HBA1 /// HBA2 -1.001693  7.279271e-05  1.001693
# 630           TNS1 -1.001215  6.067785e-07  1.001215
#
# [522 rows x 4 columns]

# %%
DEGS_mini.reset_index(inplace=True,drop=True)

# %%
DEGS_mini_sort_pval = DEGS_mini.copy()
DEGS_mini_sort_pval.sort_values(['P.Value'], ascending=True, inplace=True)
DEGS_mini_sort_pval.reset_index(inplace=True,drop=True)

# %%
DEGS_mini_sort_pval
# Out:
#        Gene.Symbol     logFC       P.Value  abslogfc
# 0             ECT2  2.112317  2.296755e-31  2.112317
# 1            CKS1B  1.528879  5.201664e-31  1.528879
# 2             RFC4  1.716516  2.208688e-30  1.716516
# 3            MFAP2  1.691285  4.685839e-30  1.691285
# 4             MMP1  4.442564  8.645952e-29  4.442564
# ..             ...       ...           ...       ...
# 517          KRT14  1.321544  6.436790e-05  1.321544
# 518  HBA1 /// HBA2 -1.001693  7.279271e-05  1.001693
# 519        ALDH3A1 -1.297811  9.279016e-05  1.297811
# 520         CXCL14  1.038378  1.270588e-04  1.038378
# 521            DES -1.180520  1.309680e-04  1.180520
#
# [522 rows x 4 columns]

# %%
DEGS_mini = DEGS_mini[['Gene.Symbol', 'logFC', 'P.Value']]

# %%
DEGS_mini
# Out:
#        Gene.Symbol     logFC       P.Value
# 0             MMP1  4.442564  8.645952e-29
# 1           CRISP3 -4.246975  8.533328e-21
# 2              MAL -3.968327  8.650061e-20
# 3             CRNN -3.654040  3.309579e-16
# 4             SCEL -3.496086  4.159160e-17
# ..             ...       ...           ...
# 517          ACKR3  1.007208  1.498846e-06
# 518           COBL -1.004592  1.908805e-18
# 519         HS3ST1 -1.001725  5.010626e-10
# 520  HBA1 /// HBA2 -1.001693  7.279271e-05
# 521           TNS1 -1.001215  6.067785e-07
#
# [522 rows x 3 columns]

# %%
DEGS_mini.head(20)

# %%
DEGs_sorted_logfc_pval = DEGS_mini.copy()
DEGs_sorted_logfc_pval_top20 = DEGS_mini.head(20).copy()

# %%
out_dir = "/Users/anb/Documents/CMEB-Lab/ESCC-Drug-Repositioning/DR-escc-data/output/GSE23400/DEG-analysis"

DEGs_sorted_logfc_pval.to_csv(os.path.join(out_dir, "DEGs_sorted_logfc_pval.tsv"), sep='\t', index=False)
DEGs_sorted_logfc_pval['Gene.Symbol'].to_csv(os.path.join(out_dir, "DEGs_sorted_logfc_pval_genes.tsv"), sep='\t', index=False)

DEGS_mini_sort_pval.to_csv(os.path.join(out_dir, "DEGs_sorted_pval.tsv"), sep='\t', index=False)
DEGS_mini_sort_pval[['Gene.Symbol']].to_csv(os.path.join(out_dir, "DEGs_sorted_pval_genes.tsv"), sep='\t', index=False)



DEGs_sorted_logfc_pval_top20.to_csv(os.path.join(out_dir, "DEGs_sorted_logfc_pval_top20.tsv"), sep='\t', index=False)

# %%
DEGs_sorted_logfc_pval_top20

# %%
DEGs_sorted_logfc_pval[DEGs_sorted_logfc_pval['logFC'] > 0].head(30)

# %%
DEGs_sorted_logfc_pval[DEGs_sorted_logfc_pval['logFC'] < 0].head(30)
