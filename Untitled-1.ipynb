# %%
newdtst = "/Users/anb/Documents/CMEB-Lab/DR-escc-data/output/GSE44021/paired-limma/drug-repositioning/qQv61KBBj8/qQv61KBBj8_app2result.txt"

dataset3_df = pd.read_csv(
    newdtst, comment="#", header=0, sep='\t', low_memory=False
)

# %%
dataset3_df
# Out:
#                                         Drug       Species  \
# 0                                Oxaliplatin  Mus musculus
# 1                                 Citalopram  Mus musculus
# 2                      Cell growth inhibitor  Mus musculus
# 3                             Antidepressant  Mus musculus
# 4     Selective serotonin reuptake inhibitor  Mus musculus
# ...                                      ...           ...
# 1691                 Janus kinase  inhibitor  Mus musculus
# 1692                            Antifibrosis  Mus musculus
# 1693         Sodium reabsorption accelerator  Mus musculus
# 1694      Mineralocorticoid receptor agonist  Mus musculus
# 1695      Mineralocorticoid receptor agonist  Mus musculus
#
#                        Tissue  \
# 0     gastrointestinal system
# 1             skeletal system
# 2     gastrointestinal system
# 3             skeletal system
# 4             skeletal system
# ...                       ...
# 1691               integument
# ...

# %%
df3_gi = dataset3_df[dataset3_df['Tissue'] == 'gastrointestinal system']
df3_gi.reset_index(inplace=True,drop=True)
df3_gi
# Out:
#                                         Drug            Species  \
# 0                                Oxaliplatin       Mus musculus
# 1                      Cell growth inhibitor       Mus musculus
# 2                     Dextran sulfate sodium       Mus musculus
# 3                Antidyslipidemia  activator       Mus musculus
# 4                             Antineoplastic       Mus musculus
# 5                                Doxorubicin       Mus musculus
# 6                                   Imatinib       Mus musculus
# 7                  Tyrosine kinase inhibitor       Mus musculus
# 8                 Topoisomerase II inhibitor       Mus musculus
# 9                                Aldosterone  Rattus norvegicus
# 10           Sodium reabsorption accelerator  Rattus norvegicus
# 11        Mineralocorticoid receptor agonist  Rattus norvegicus
# 12                                   Dextran       Mus musculus
# 13                                   Dextran  Rattus norvegicus
# ...

# %%
df3_sorted = dataset3_df.sort_values(['Drug', 'Rank'], axis=0, ascending=False, inplace=False)

# %%
df3_sorted.drop_duplicates(subset = ["Drug"], inplace=True)

# %%
df3_sorted.sort_values(['Rank'], axis=0, ascending=False, inplace=True)

# %%
overlap2 = pd.merge(left=df3_sorted[['Drug', 'Species', 'Tissue', 'Pvalue', 'Rank']], right=datasets[['Drug', 'SpeciesDEG2Pharm', 'Tissue_DEG2Pharm', 'Pvalue_DEG2Pharm', 'Rank_DEG2Pharm', 'Species_kda2Pharm', 'Tissue_kda2Pharm', 'Pvalue_kda2Pharm', 'Rank_kda2Pharm']], how='right', left_on='Drug', right_on='Drug')

# %%
overlap2_test = pd.merge(left=df3_sorted[['Drug', 'Species', 'Tissue', 'Pvalue', 'Rank']], right=datasets[['Drug', 'SpeciesDEG2Pharm', 'Tissue_DEG2Pharm', 'Pvalue_DEG2Pharm', 'Rank_DEG2Pharm', 'Species_kda2Pharm', 'Tissue_kda2Pharm', 'Pvalue_kda2Pharm', 'Rank_kda2Pharm']], how='inner', left_on='Drug', right_on='Drug')

# %%
overlap2_test
# Out:
#                                        Drug            Species  \
# 0                               Oxaliplatin       Mus musculus
# 1                     Cell growth inhibitor       Mus musculus
# 2                            Antidepressant       Mus musculus
# 3    Selective serotonin reuptake inhibitor       Mus musculus
# 4                               Anastrozole  Rattus norvegicus
# ..                                      ...                ...
# 389                                 Danazol  Rattus norvegicus
# 390                             Insecticide  Rattus norvegicus
# 391                 Janus kinase  inhibitor       Mus musculus
# 392              Toll-like receptor agonist       Mus musculus
# 393                               Imiquimod       Mus musculus
#
#                       Tissue        Pvalue      Rank SpeciesDEG2Pharm  \
# 0    gastrointestinal system  1.442954e-09  1.000000     Homo sapiens
# ...

# %%
overlap2
# Out:
#                   Drug            Species                   Tissue  \
# 0             Imatinib       Mus musculus  gastrointestinal system
# 1     Cyclophosphamide  Rattus norvegicus    cardiovascular system
# 2       Antidepressant       Mus musculus          skeletal system
# 3     Alkylating agent       Mus musculus     hematopoietic system
# 4    Immunosuppressant       Mus musculus                 pancreas
# ..                 ...                ...                      ...
# 535         Tipranavir                NaN                      NaN
# 536         Eplerenone       Mus musculus          skeletal system
# 537   Ingenol mebutate                NaN                      NaN
# 538        Azacitidine       Mus musculus            immune system
# 539             Helium                NaN                      NaN
#
#            Pvalue      Rank SpeciesDEG2Pharm      Tissue_DEG2Pharm  \
# 0    9.184886e-01  0.948113     Homo sapiens  hematopoietic system
# ...

# %%
comparison3 = overlap2.rename(columns={"Species" : "Species_netoverlap", "Tissue" : "Tissue_netoverlap", "Pvalue" : "Pvalue_netoverlap", "Rank" : "Rank_netoverlap"})

# %%
comparison3_test = overlap2_test.rename(columns={"Species" : "Species_netoverlap", "Tissue" : "Tissue_netoverlap", "Pvalue" : "Pvalue_netoverlap", "Rank" : "Rank_netoverlap"})

# %%
comparison3.head(25)
# Out:
#                                   Drug Species_netoverlap  \
# 0                             Imatinib       Mus musculus
# 1                     Cyclophosphamide  Rattus norvegicus
# 2                       Antidepressant       Mus musculus
# 3                     Alkylating agent       Mus musculus
# 4                    Immunosuppressant       Mus musculus
# 5            Estrogen receptor agonist  Rattus norvegicus
# 6                        Contraceptive  Rattus norvegicus
# 7          HMG-CoA reductase inhibitor  Rattus norvegicus
# 8           Topoisomerase II inhibitor       Mus musculus
# 9                          Doxorubicin       Mus musculus
# 10           Tyrosine kinase inhibitor       Mus musculus
# 11                         Fluvastatin  Rattus norvegicus
# 12                 Medroxyprogesterone       Mus musculus
# 13                  Antihyperlipidemic  Rattus norvegicus
# 14                     PARP1 inhibitor       Mus musculus
# ...

# %%
comparison3_test.head(25)
# Out:
#                                       Drug Species_netoverlap  \
# 0                              Oxaliplatin       Mus musculus
# 1                    Cell growth inhibitor       Mus musculus
# 2                           Antidepressant       Mus musculus
# 3   Selective serotonin reuptake inhibitor       Mus musculus
# 4                              Anastrozole  Rattus norvegicus
# 5                               Nefazodone  Rattus norvegicus
# 6                              Glucosamine  Rattus norvegicus
# 7          Glucocorticoid receptor agonist  Rattus norvegicus
# 8                            Dexamethasone  Rattus norvegicus
# 9                             Antipruritic  Rattus norvegicus
# 10                       Anti-inflammatory  Rattus norvegicus
# 11                             Doxycycline       Mus musculus
# 12                              Antibiotic       Mus musculus
# 13          Protein biosynthesis inhibitor       Mus musculus
# ...

# %%
out_dir = "/Users/anb/Desktop/"

comparison3.to_csv(os.path.join(out_dir, "comparison3-overlap.tsv"), sep='\t', index=False)
comparison3.Drug.to_csv(os.path.join(out_dir, "comparison3-overlap-drugs.tsv"), sep='\t', index=False)




comparison3_test.to_csv(os.path.join(out_dir, "comparison3-inner-overlap.tsv"), sep='\t', index=False)
comparison3_test.Drug.to_csv(os.path.join(out_dir, "comparison3-inner-overlap-drugs.tsv"), sep='\t', index=False)
